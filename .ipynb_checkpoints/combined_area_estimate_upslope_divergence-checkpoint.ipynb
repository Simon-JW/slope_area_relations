# %%
# %%capture
#from jupyterthemes import jtplot
#jtplot.style()
import numpy as np
import operator
import seaborn as sns; sns.set()
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
from scipy import stats
from scipy.stats import sem
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from pylab import show, figure
from landlab.plot.imshow import imshow_grid 

# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure
from matplotlib.lines import Line2D
# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120)
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()
from statsmodels.formula.api import ols
from scipy.stats import t
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def slopeWindowMperM(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_m_per_m = rise_run
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_m_per_m
def catchmentDicts(area_grid, gn, gh_nodes):
    """Creates a dictionary of node ID:catcment area values."""
    area_dict = {}
    nodes = gh_nodes
    x_axis_length = gn.shape[1]
    for i in nodes:
        row = int(np.floor(i / x_axis_length))
        col = int(i - (row*x_axis_length))
        area = area_grid[row,col]
        area_dict[i] = area
    return area_dict
def upslopeDivergence(catchment_area_list, change_detection_factor, step_size, comparison_distance):
    
    """"Looks at whether catchment area is increasing at any point upstream of a gully head.
    
    - 'catchment_area_list' is an ordered list of node catchment areas moving upstream.
    
    - 'change_detection_factor' is the percentage increase required for the function to consider the change
    to represent a point of divergent flow.
    
    - 'step_size' is the number of grid cells to be compared in downstream to upstream groups. E.g. step_size == 1 
    will compare node 1 and node 2, but step_size == 2 will compare node 1 and 2 to node 3 and 4.
    
    - 'comparison_distance' is the distance between the downstream nodes being compared to upstream nodes."""
    
    max_value_length = len(catchment_area_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = catchment_area_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptreat_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = catchment_area_list[start_of_upstream_nodes:end_of_usptreat_nodes]
        
        required_catchment_area_increase = max(downstream_nodes) + (max(downstream_nodes) * change_detection_factor)
        
        if all(nodes >= required_catchment_area_increase for nodes in upstream_nodes):
            divergence = 1
            break
        else:
            divergence = 0
    return divergence
def findGullyHeadNode(gully_heads, grid_nodes, DEM, ca, input_DEM_resolution, 
                      distance_from_node, contributing_fraction, required_ca):
    
    catchment_area_dict = {}
    catchment_area_node_list = []
    distance_from_node = int(np.ceil(distance_from_node/input_DEM_resolution))

    for i in gully_heads:

        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset = DEM[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        #################################################################################################
        ca_subset = ca[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        print('max ca: ', np.amax(ca_subset))
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');

        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');
        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);
        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        for j in range(0, distance_from_node):
            # Begin at the point (node) digitized as the intersection between the central flow line and the gully head.
            if j == 0:
                candidate_gridcell = catchment_outlet_id;
            else:
                candidate_gridcell = next_cell_downstream;
            # Get all receiver nodes of the current node.
            grid_cell_receiver_nodes = frp[candidate_gridcell,:];
            # Check if there is a node that receives >= 'contributing_fraction' from the current node.
            candidate_gridcell_list = [candidate_gridcell]
            node_ca_int = catchmentDicts(ca_subset, grid_nodes_sub, candidate_gridcell_list) # Find the node's contributing area.
            node_ca = node_ca_int[candidate_gridcell]
            print('Node id: ', candidate_gridcell, 'Catchment area: ', node_ca)
            if np.amax(grid_cell_receiver_nodes) < contributing_fraction or node_ca < required_ca:
                # Check if this is the last possible grid cell in the subset that could meet the criteria. If so, then there
                # is no suitable grid cell (node).
                if j == distance_from_node - 1:
                    catchment_area_dict[i] = 'No grid cell found'
                else:
                    # Otherwise, find the next downslope grid cell receiving the highest proportion of flow and check that 
                    # in the next iteration.
                    index_next_cell_downstream = np.where(grid_cell_receiver_nodes == np.amax(grid_cell_receiver_nodes))[0][0];
                    next_cell_downstream = frn[candidate_gridcell, index_next_cell_downstream];
            else:
                # Find the position of the gridcell (node) that meets the criteria both in the subset and in the whole DEM
                # and record the node ID.
                final_node_index_lat =  np.where(grid_nodes_sub == candidate_gridcell)[0][0]
                final_node_index_lon =  np.where(grid_nodes_sub == candidate_gridcell)[1][0]
                
                # Find the offest between the index position of the node the loop ends on, and the index position of
                # the node that it started on. 
                final_lat_offset = final_node_index_lat - node_lat
                final_lon_offset = final_node_index_lon - node_lon
                # Then apply this offest to the index position of the starting node with respect top the whole DEM to find the 
                # node ID of the grid cell that met the criteria above.
                final_row_index = row_index + final_lat_offset
                final_col_index = col_index + final_lon_offset
                node_of_area_record = grid_nodes[final_row_index, final_col_index] # - this range is more than 1
                catchment_area_dict[i] = node_of_area_record
                catchment_area_node_list.append(node_of_area_record)
                break
                             
    return catchment_area_dict, catchment_area_node_list
def upstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, catchment_outlet_ids, 
                         step_size_m, comparison_distance_m, change_detection_factor, slope_above_head):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        print(target_distance, ' ', target_distance * input_DEM_resolution)
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        area_along_central_drainage_line = []
        for key, value in node_area_dict.items():
            area_along_central_drainage_line.append(value)
        median_area_along_central_drainage_line = ndimage.median_filter(area_along_central_drainage_line, size=step_size_m)
        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_area_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            divergence_occuring = upslopeDivergence(median_area_along_central_drainage_line, change_detection_factor, 
                                                    step_size, comparison_distance)
            upslope_divergence_dict[i] = divergence_occuring
            
    return upslope_divergence_dict, slope_dict, slope_at_head

# %%
input_DEM_resolution = 2

location = (r'C:\PhD\manuscript\flow_routing_algorithms\data')
os.chdir(location)

input_geotiff = gdal.Open('fann_2013_' + str(input_DEM_resolution) + 'm.tif')
input_DEM = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())

gully_head_layer = gdal.Open('core_nodes_' + str(input_DEM_resolution) + 'm.tif')
gh = np.array(gully_head_layer.GetRasterBand(1).ReadAsArray()).astype('uint8')

input_ca_grid = gdal.Open('fann_M8_' + str(input_DEM_resolution) +  'm.tif')
ca_grid = np.array(input_ca_grid.GetRasterBand(1).ReadAsArray())

# %%
flow_acc_surf = np.copy(input_DEM).astype('float64');
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

# %%
grid_nodes = np.array(mg.nodes.reshape(mg.shape))

# %%
grid_nodes_float = grid_nodes.astype('float64')

# %%
plt.imshow(grid_nodes_float, cmap="terrain");
plt.colorbar();

# %% [markdown]
# ## Isolate all gully head nodes

# %%
find_nodes = np.multiply(gh, grid_nodes);

# %% [markdown]
# ## Create array of only gully head nodes

# %%
gh_array = np.unique(find_nodes);

# %% [markdown]
# ## Turn gully head node array into a list and remove the value 0

# %%
gh_list = gh_array.tolist();
gh_list.remove(0);

# %%
len(gh_list)
# Out:
# 484

# %% [markdown]
# ## Work through list finding index positions of each node

# %%
catchment_area_dict, catchment_area_node_list = findGullyHeadNode(gh_list, grid_nodes, input_DEM, ca_grid,
                                                                  input_DEM_resolution, 10, 0.9, 0.25)
# Out:
# max ca:  0.559369
# Node id:  60 Catchment area:  0.378459
# Node id:  48 Catchment area:  0.381476
# Node id:  47 Catchment area:  0.346519
# max ca:  1.37947
# Node id:  60 Catchment area:  1.0095
# max ca:  0.683851
# Node id:  60 Catchment area:  0.129909
# Node id:  70 Catchment area:  0.372285
# max ca:  0.685775
# Node id:  60 Catchment area:  0.622898
# Node id:  71 Catchment area:  0.385223
# max ca:  0.863865
# Node id:  60 Catchment area:  0.440305
# Node id:  59 Catchment area:  0.393778
# Node id:  69 Catchment area:  0.66385
# max ca:  0.762294
# Node id:  60 Catchment area:  0.377539
# Node id:  61 Catchment area:  0.449883
# max ca:  1.29883
# Node id:  60 Catchment area:  0.814113
# Node id:  70 Catchment area:  0.941026
# Node id:  80 Catchment area:  1.03281
# max ca:  1.06324
# Node id:  60 Catchment area:  0.0257349
# Node id:  59 Catchment area:  0.263743
# Node id:  47 Catchment area:  0.155522
# Node id:  36 Catchment area:  0.291443
# Node id:  24 Catchment area:  0.993797
# max ca:  0.733469
# Node id:  60 Catchment area:  0.273889
# max ca:  1.85669
# Node id:  60 Catchment area:  0.289887
# max ca:  0.71308
# Node id:  60 Catchment area:  0.523078
# Node id:  59 Catchment area:  0.532421
# max ca:  0.600503
# Node id:  60 Catchment area:  0.320648
# Node id:  59 Catchment area:  0.451
# max ca:  0.79038
# Node id:  60 Catchment area:  0.391322
# Node id:  48 Catchment area:  0.385312
# max ca:  0.428696
# Node id:  60 Catchment area:  0.280297
# max ca:  1.5688
# Node id:  60 Catchment area:  0.473742
# Node id:  50 Catchment area:  0.696548
# Node id:  51 Catchment area:  1.14704
# max ca:  0.806699
# Node id:  60 Catchment area:  0.512417
# Node id:  59 Catchment area:  0.42853
# Node id:  58 Catchment area:  0.470894
# Node id:  46 Catchment area:  0.676787
# max ca:  2.2744
# Node id:  60 Catchment area:  0.598052
# Node id:  50 Catchment area:  1.07491
# max ca:  0.418874
# Node id:  60 Catchment area:  0.377563
# Node id:  48 Catchment area:  0.26253
# max ca:  1.23902
# Node id:  60 Catchment area:  0.875313
# Node id:  59 Catchment area:  0.640244
# max ca:  0.436547
# Node id:  60 Catchment area:  0.327347
# max ca:  0.833578
# Node id:  60 Catchment area:  0.648403
# max ca:  1.09235
# Node id:  60 Catchment area:  0.4041
# Node id:  49 Catchment area:  0.510806
# Node id:  38 Catchment area:  0.428538
# max ca:  3.95814
# Node id:  60 Catchment area:  0.391621
# Node id:  50 Catchment area:  0.628665
# Node id:  40 Catchment area:  0.853269
# max ca:  0.608555
# Node id:  60 Catchment area:  0.283069
# Node id:  50 Catchment area:  0.384232
# max ca:  0.45231
# Node id:  60 Catchment area:  0.202311
# Node id:  71 Catchment area:  0.296644
# Node id:  81 Catchment area:  0.282416
# Node id:  91 Catchment area:  0.443494
# max ca:  2.31303
# Node id:  60 Catchment area:  0.113738
# Node id:  70 Catchment area:  1.34929
# Node id:  69 Catchment area:  0.934148
# max ca:  0.421601
# Node id:  60 Catchment area:  0.220066
# Node id:  49 Catchment area:  0.25476
# max ca:  2.23629
# Node id:  60 Catchment area:  1.56251
# Node id:  59 Catchment area:  1.07772
# Node id:  48 Catchment area:  1.54582
# max ca:  3.81247
# Node id:  60 Catchment area:  0.63719
# Node id:  59 Catchment area:  0.66091
# max ca:  0.692238
# Node id:  60 Catchment area:  0.339637
# Node id:  49 Catchment area:  0.435036
# Node id:  38 Catchment area:  0.345888
# Node id:  26 Catchment area:  0.692238
# Node id:  15 Catchment area:  0.426808
# max ca:  0.41714
# Node id:  60 Catchment area:  0.254662
# max ca:  2.29075
# Node id:  60 Catchment area:  1.62478
# max ca:  0.512749
# Node id:  60 Catchment area:  0.302541
# max ca:  0.987403
# Node id:  60 Catchment area:  0.600381
# Node id:  49 Catchment area:  0.590083
# max ca:  1.1971
# Node id:  60 Catchment area:  0.64009
# Node id:  50 Catchment area:  0.63155
# Node id:  39 Catchment area:  0.497234
# Node id:  27 Catchment area:  1.06838
# Node id:  17 Catchment area:  0.690581
# max ca:  0.725198
# Node id:  60 Catchment area:  0.264235
# max ca:  1.69675
# Node id:  60 Catchment area:  0.636162
# Node id:  70 Catchment area:  0.948946
# max ca:  1.07175
# Node id:  60 Catchment area:  0.335006
# Node id:  72 Catchment area:  0.578589
# Node id:  84 Catchment area:  0.628901
# Node id:  96 Catchment area:  0.739708
# Node id:  108 Catchment area:  0.805583
# max ca:  1.85959
# Node id:  60 Catchment area:  0.554235
# Node id:  72 Catchment area:  0.979272
# max ca:  12.1125
# Node id:  60 Catchment area:  9.91348
# Node id:  49 Catchment area:  10.1133
# Node id:  38 Catchment area:  6.4783
# max ca:  1.02987
# Node id:  60 Catchment area:  0.473923
# max ca:  0.38672
# Node id:  60 Catchment area:  0.344107
# Node id:  49 Catchment area:  0.316147
# Node id:  39 Catchment area:  0.38672
# Node id:  27 Catchment area:  0.260072
# Node id:  17 Catchment area:  0.278058
# max ca:  0.985929
# Node id:  60 Catchment area:  0.529948
# Node id:  71 Catchment area:  0.711092
# max ca:  0.423657
# Node id:  60 Catchment area:  0.151212
# Node id:  59 Catchment area:  0.35975
# Node id:  69 Catchment area:  0.215116
# Node id:  68 Catchment area:  0.403596
# Node id:  78 Catchment area:  0.239954
# max ca:  14.175
# Node id:  60 Catchment area:  14.0105
# max ca:  0.513727
# Node id:  60 Catchment area:  0.47344
# max ca:  0.513528
# Node id:  60 Catchment area:  0.442701
# max ca:  0.29221
# Node id:  60 Catchment area:  0.149135
# Node id:  50 Catchment area:  0.269554
# Node id:  40 Catchment area:  0.181471
# Node id:  41 Catchment area:  0.29221
# Node id:  42 Catchment area:  0.202812
# max ca:  1.21978
# Node id:  60 Catchment area:  0.00082652
# Node id:  49 Catchment area:  1.19291
# max ca:  2.68006
# Node id:  60 Catchment area:  0.404309
# Node id:  49 Catchment area:  0.571075
# max ca:  0.677352
# Node id:  60 Catchment area:  0.163544
# Node id:  71 Catchment area:  0.345342
# Node id:  82 Catchment area:  0.472497
# max ca:  1.53271
# Node id:  60 Catchment area:  1.37409
# max ca:  0.979965
# Node id:  60 Catchment area:  0.401363
# Node id:  61 Catchment area:  0.665624
# Node id:  62 Catchment area:  0.763537
# max ca:  0.557128
# Node id:  60 Catchment area:  0.310218
# Node id:  50 Catchment area:  0.328357
# Node id:  51 Catchment area:  0.392329
# max ca:  3.48466
# Node id:  60 Catchment area:  0.576571
# Node id:  59 Catchment area:  0.648945
# Node id:  47 Catchment area:  0.709084
# Node id:  46 Catchment area:  3.11981
# max ca:  3.48466
# Node id:  60 Catchment area:  0.335697
# max ca:  3.42814
# Node id:  60 Catchment area:  0.94499
# Node id:  50 Catchment area:  1.24053
# Node id:  39 Catchment area:  2.27741
# max ca:  0.932826
# Node id:  60 Catchment area:  0.379468
# Node id:  50 Catchment area:  0.720123
# Node id:  40 Catchment area:  0.595126
# max ca:  0.795046
# Node id:  60 Catchment area:  0.251154
# Node id:  61 Catchment area:  0.206488
# Node id:  73 Catchment area:  0.355225
# Node id:  74 Catchment area:  0.272505
# max ca:  1.82448
# Node id:  60 Catchment area:  1.65261
# Node id:  48 Catchment area:  1.5468
# max ca:  2.16685
# Node id:  60 Catchment area:  1.41809
# Node id:  50 Catchment area:  1.89049
# max ca:  1.05736
# Node id:  60 Catchment area:  0.532463
# max ca:  0.543433
# Node id:  60 Catchment area:  0.232315
# Node id:  59 Catchment area:  0.430027
# max ca:  0.482397
# Node id:  60 Catchment area:  0.328534
# Node id:  71 Catchment area:  0.272447
# Node id:  81 Catchment area:  0.293951
# max ca:  17.2429
# Node id:  60 Catchment area:  0.975483
# max ca:  0.749554
# Node id:  60 Catchment area:  0.402658
# max ca:  0.620391
# Node id:  60 Catchment area:  0.461405
# max ca:  0.852629
# Node id:  60 Catchment area:  0.610641
# max ca:  3.34042
# Node id:  60 Catchment area:  0.131463
# Node id:  70 Catchment area:  0.181916
# Node id:  80 Catchment area:  1.99557
# max ca:  2.71654
# Node id:  60 Catchment area:  0.6703
# Node id:  59 Catchment area:  0.884138
# Node id:  58 Catchment area:  1.20136
# Node id:  57 Catchment area:  1.35959
# Node id:  56 Catchment area:  2.22903
# max ca:  2.80557
# Node id:  60 Catchment area:  0.28907
# Node id:  49 Catchment area:  1.13194
# Node id:  37 Catchment area:  2.22903
# max ca:  1.75257
# Node id:  60 Catchment area:  1.02227
# Node id:  49 Catchment area:  0.736968
# Node id:  48 Catchment area:  1.06696
# max ca:  6.52679
# Node id:  60 Catchment area:  1.20872
# Node id:  59 Catchment area:  3.49772
# max ca:  0.499139
# Node id:  60 Catchment area:  0.160433
# Node id:  48 Catchment area:  0.333947
# max ca:  0.897765
# Node id:  60 Catchment area:  0.679011
# Node id:  48 Catchment area:  0.401543
# max ca:  0.489537
# Node id:  60 Catchment area:  0.335097
# max ca:  0.836955
# Node id:  60 Catchment area:  0.275473
# Node id:  59 Catchment area:  0.404279
# Node id:  58 Catchment area:  0.543615
# Node id:  46 Catchment area:  0.446908
# Node id:  45 Catchment area:  0.565507
# max ca:  0.393612
# Node id:  60 Catchment area:  0.196962
# Node id:  59 Catchment area:  0.261502
# max ca:  0.695425
# Node id:  60 Catchment area:  0.451282
# max ca:  0.893484
# Node id:  60 Catchment area:  0.397502
# Node id:  49 Catchment area:  0.450591
# Node id:  37 Catchment area:  0.630776
# Node id:  26 Catchment area:  0.801941
# max ca:  0.523545
# Node id:  60 Catchment area:  0.255099
# max ca:  1.01775
# Node id:  60 Catchment area:  0.108804
# Node id:  59 Catchment area:  0.243587
# Node id:  69 Catchment area:  0.342331
# Node id:  68 Catchment area:  0.563834
# Node id:  56 Catchment area:  0.752869
# max ca:  0.746138
# Node id:  60 Catchment area:  0.388762
# Node id:  72 Catchment area:  0.538465
# max ca:  1.12943
# Node id:  60 Catchment area:  0.287806
# Node id:  48 Catchment area:  0.353419
# max ca:  0.953132
# Node id:  60 Catchment area:  0.278896
# max ca:  0.699145
# Node id:  60 Catchment area:  0.344575
# Node id:  48 Catchment area:  0.549873
# Node id:  36 Catchment area:  0.34384
# Node id:  25 Catchment area:  0.632599
# max ca:  0.767043
# Node id:  60 Catchment area:  0.619727
# max ca:  1.73114
# Node id:  60 Catchment area:  0.781871
# Node id:  48 Catchment area:  0.781355
# max ca:  1.17365
# Node id:  60 Catchment area:  0.686356
# Node id:  49 Catchment area:  0.772878
# max ca:  0.379802
# Node id:  60 Catchment area:  0.314703
# Node id:  59 Catchment area:  0.206155
# Node id:  69 Catchment area:  0.303558
# max ca:  1.56209
# Node id:  60 Catchment area:  0.820161
# Node id:  50 Catchment area:  0.943436
# max ca:  0.439634
# Node id:  60 Catchment area:  0.179133
# Node id:  50 Catchment area:  0.329365
# Node id:  51 Catchment area:  0.256595
# Node id:  41 Catchment area:  0.155725
# Node id:  30 Catchment area:  0.418839
# max ca:  1.4803
# Node id:  60 Catchment area:  0.456632
# Node id:  70 Catchment area:  0.446996
# Node id:  81 Catchment area:  0.512258
# Node id:  91 Catchment area:  0.612989
# Node id:  102 Catchment area:  1.43047
# max ca:  0.688536
# Node id:  60 Catchment area:  0.448977
# max ca:  15.9315
# Node id:  60 Catchment area:  1.08057
# Node id:  49 Catchment area:  1.59952
# Node id:  38 Catchment area:  1.78056
# max ca:  1.60584
# Node id:  60 Catchment area:  0.494608
# Node id:  49 Catchment area:  0.716932
# Node id:  48 Catchment area:  0.855908
# Node id:  36 Catchment area:  0.88995
# max ca:  0.668153
# Node id:  60 Catchment area:  0.210964
# Node id:  49 Catchment area:  0.213563
# Node id:  38 Catchment area:  0.253277
# Node id:  28 Catchment area:  0.31453
# Node id:  18 Catchment area:  0.380911
# max ca:  0.287189
# Node id:  60 Catchment area:  0.19476
# Node id:  59 Catchment area:  0.236838
# Node id:  58 Catchment area:  0.270191
# max ca:  1.61345
# Node id:  60 Catchment area:  0.437501
# Node id:  71 Catchment area:  0.58326
# Node id:  82 Catchment area:  0.645075
# max ca:  8.37335
# Node id:  60 Catchment area:  0.306599
# Node id:  59 Catchment area:  0.245095
# Node id:  58 Catchment area:  0.437004
# Node id:  57 Catchment area:  0.389178
# Node id:  56 Catchment area:  8.13061
# max ca:  8.37335
# Node id:  60 Catchment area:  0.392689
# Node id:  59 Catchment area:  0.582541
# Node id:  58 Catchment area:  0.677088
# max ca:  0.437169
# Node id:  60 Catchment area:  0.3336
# max ca:  0.371058
# Node id:  60 Catchment area:  0.195832
# Node id:  48 Catchment area:  0.237827
# Node id:  36 Catchment area:  0.142303
# Node id:  25 Catchment area:  0.270181
# max ca:  0.615907
# Node id:  60 Catchment area:  0.214589
# Node id:  71 Catchment area:  0.463476
# max ca:  0.516509
# Node id:  60 Catchment area:  0.163443
# Node id:  50 Catchment area:  0.472083
# Node id:  39 Catchment area:  0.349306
# Node id:  28 Catchment area:  0.256608
# Node id:  18 Catchment area:  0.369549
# max ca:  0.353873
# Node id:  60 Catchment area:  0.160422
# Node id:  70 Catchment area:  0.282979
# Node id:  80 Catchment area:  0.282235
# max ca:  1.21939
# Node id:  60 Catchment area:  0.323238
# max ca:  1.56432
# Node id:  60 Catchment area:  0.949503
# max ca:  0.523867
# Node id:  60 Catchment area:  0.259241
# Node id:  61 Catchment area:  0.261253
# max ca:  1.1187
# Node id:  60 Catchment area:  0.511742
# Node id:  49 Catchment area:  0.826942
# max ca:  0.66725
# Node id:  60 Catchment area:  0.17629
# Node id:  50 Catchment area:  0.48415
# max ca:  0.452553
# Node id:  60 Catchment area:  0.322216
# Node id:  70 Catchment area:  0.198326
# Node id:  81 Catchment area:  0.322259
# max ca:  0.752046
# Node id:  60 Catchment area:  0.411278
# Node id:  70 Catchment area:  0.561116
# Node id:  80 Catchment area:  0.725901
# Node id:  90 Catchment area:  0.752046
# Node id:  100 Catchment area:  0.727466
# max ca:  0.744361
# Node id:  60 Catchment area:  0.199528
# Node id:  50 Catchment area:  0.332323
# Node id:  40 Catchment area:  0.457877
# max ca:  0.636241
# Node id:  60 Catchment area:  0.235644
# Node id:  70 Catchment area:  0.349315
# max ca:  0.744361
# Node id:  60 Catchment area:  0.299802
# max ca:  5.47209
# Node id:  60 Catchment area:  0.275495
# max ca:  0.611494
# Node id:  60 Catchment area:  0.484555
# Node id:  48 Catchment area:  0.289174
# max ca:  1.13616
# Node id:  60 Catchment area:  0.365327
# Node id:  71 Catchment area:  0.890931
# max ca:  10.7627
# Node id:  60 Catchment area:  1.54815
# max ca:  0.483203
# Node id:  60 Catchment area:  0.27013
# max ca:  0.907841
# Node id:  60 Catchment area:  0.720796
# max ca:  0.791852
# Node id:  60 Catchment area:  0.311318
# Node id:  71 Catchment area:  0.38926
# Node id:  82 Catchment area:  0.530616
# max ca:  0.405777
# Node id:  60 Catchment area:  0.136284
# Node id:  59 Catchment area:  0.244136
# Node id:  47 Catchment area:  0.2837
# max ca:  0.491666
# Node id:  60 Catchment area:  0.396041
# max ca:  5.4844
# Node id:  60 Catchment area:  0.103454
# Node id:  59 Catchment area:  0.140806
# Node id:  58 Catchment area:  0.177368
# Node id:  57 Catchment area:  0.189591
# Node id:  56 Catchment area:  0.19329
# max ca:  0.578962
# Node id:  60 Catchment area:  0.319203
# max ca:  0.540254
# Node id:  60 Catchment area:  0.16783
# Node id:  72 Catchment area:  0.471656
# max ca:  0.626756
# Node id:  60 Catchment area:  0.464924
# Node id:  70 Catchment area:  0.53681
# max ca:  0.294541
# Node id:  60 Catchment area:  0.151408
# Node id:  49 Catchment area:  0.174528
# Node id:  37 Catchment area:  0.218649
# Node id:  36 Catchment area:  0.157488
# Node id:  24 Catchment area:  0.211971
# max ca:  1.67805
# Node id:  60 Catchment area:  0.710462
# Node id:  71 Catchment area:  1.20569
# Node id:  70 Catchment area:  1.06449
# Node id:  80 Catchment area:  1.05646
# max ca:  34.2767
# Node id:  60 Catchment area:  0.300436
# max ca:  4.01712
# Node id:  60 Catchment area:  0.302278
# Node id:  59 Catchment area:  0.278941
# Node id:  69 Catchment area:  0.461199
# max ca:  3.44037
# Node id:  60 Catchment area:  0.938926
# max ca:  0.856677
# Node id:  60 Catchment area:  0.47318
# Node id:  50 Catchment area:  0.591514
# max ca:  2.34741
# Node id:  60 Catchment area:  1.59715
# max ca:  0.867809
# Node id:  60 Catchment area:  0.262548
# Node id:  70 Catchment area:  0.528605
# max ca:  0.705611
# Node id:  60 Catchment area:  0.149957
# Node id:  72 Catchment area:  0.344082
# Node id:  83 Catchment area:  0.396248
# Node id:  94 Catchment area:  0.301796
# Node id:  105 Catchment area:  0.348164
# max ca:  4.73933
# Node id:  60 Catchment area:  2.5512
# max ca:  0.551211
# Node id:  60 Catchment area:  0.33183
# max ca:  0.297666
# Node id:  60 Catchment area:  0.00352568
# Node id:  71 Catchment area:  0.0604722
# Node id:  82 Catchment area:  0.283451
# Node id:  94 Catchment area:  0.223434
# Node id:  105 Catchment area:  0.23467
# max ca:  1.2488
# Node id:  60 Catchment area:  0.487581
# Node id:  50 Catchment area:  1.0466
# max ca:  0.411159
# Node id:  60 Catchment area:  0.377857
# max ca:  0.882906
# Node id:  60 Catchment area:  0.21482
# Node id:  72 Catchment area:  0.257507
# max ca:  0.467635
# Node id:  60 Catchment area:  0.273006
# Node id:  71 Catchment area:  0.2984
# max ca:  0.343047
# Node id:  60 Catchment area:  0.330484
# max ca:  0.539722
# Node id:  60 Catchment area:  0.34531
# max ca:  0.382753
# Node id:  60 Catchment area:  0.278123
# max ca:  1.97647
# Node id:  60 Catchment area:  1.7042
# Node id:  59 Catchment area:  1.57449
# max ca:  2.53143
# Node id:  60 Catchment area:  1.35965
# Node id:  71 Catchment area:  1.93938
# Node id:  81 Catchment area:  1.2243
# Node id:  92 Catchment area:  1.65358
# max ca:  0.622248
# Node id:  60 Catchment area:  0.101154
# Node id:  48 Catchment area:  0.24409
# Node id:  36 Catchment area:  0.478764
# Node id:  24 Catchment area:  0.509099
# max ca:  0.986015
# Node id:  60 Catchment area:  0.416037
# max ca:  1.95049
# Node id:  60 Catchment area:  1.4354
# max ca:  2.08389
# Node id:  60 Catchment area:  1.38591
# max ca:  0.908832
# Node id:  60 Catchment area:  0.746675
# Node id:  49 Catchment area:  0.499896
# max ca:  0.528627
# Node id:  60 Catchment area:  0.0752929
# Node id:  71 Catchment area:  0.372546
# max ca:  0.503232
# Node id:  60 Catchment area:  0.36598
# max ca:  0.414036
# Node id:  60 Catchment area:  0.295244
# max ca:  0.35402
# Node id:  60 Catchment area:  0.229486
# Node id:  71 Catchment area:  0.186125
# Node id:  81 Catchment area:  0.333562
# Node id:  92 Catchment area:  0.202206
# Node id:  102 Catchment area:  0.35402
# max ca:  0.834829
# Node id:  60 Catchment area:  0.429487
# Node id:  70 Catchment area:  0.724065
# max ca:  1.04515
# Node id:  60 Catchment area:  0.315056
# Node id:  71 Catchment area:  0.389447
# Node id:  82 Catchment area:  0.847867
# max ca:  0.93554
# Node id:  60 Catchment area:  0.289027
# Node id:  48 Catchment area:  0.618495
# max ca:  3.53759
# Node id:  60 Catchment area:  0.223324
# Node id:  70 Catchment area:  0.802633
# Node id:  81 Catchment area:  0.814333
# Node id:  92 Catchment area:  0.645857
# Node id:  102 Catchment area:  0.9099
# max ca:  0.382892
# Node id:  60 Catchment area:  0.282018
# max ca:  0.798025
# Node id:  60 Catchment area:  0.125198
# Node id:  48 Catchment area:  0.782634
# max ca:  0.679185
# Node id:  60 Catchment area:  0.372679
# max ca:  0.530037
# Node id:  60 Catchment area:  0.213483
# Node id:  70 Catchment area:  0.244865
# Node id:  81 Catchment area:  0.322061
# max ca:  0.530037
# Node id:  60 Catchment area:  0.493454
# Node id:  72 Catchment area:  0.290953
# Node id:  83 Catchment area:  0.459563
# max ca:  1.22599
# Node id:  60 Catchment area:  0.848751
# max ca:  0.459948
# Node id:  60 Catchment area:  0.214575
# Node id:  70 Catchment area:  0.22949
# Node id:  80 Catchment area:  0.316271
# Node id:  90 Catchment area:  0.314423
# max ca:  6.1401
# Node id:  60 Catchment area:  0.911652
# Node id:  48 Catchment area:  1.29497
# max ca:  4.04895
# Node id:  60 Catchment area:  3.02467
# max ca:  8.28059
# Node id:  60 Catchment area:  8.21783
# Node id:  59 Catchment area:  4.81833
# max ca:  1.83658
# Node id:  60 Catchment area:  0.611299
# Node id:  48 Catchment area:  1.69401
# max ca:  1.3296
# Node id:  60 Catchment area:  0.831794
# Node id:  72 Catchment area:  1.0026
# Node id:  83 Catchment area:  0.885082
# max ca:  0.559304
# Node id:  60 Catchment area:  0.332386
# Node id:  72 Catchment area:  0.457738
# max ca:  0.528695
# Node id:  60 Catchment area:  0.434835
# Node id:  59 Catchment area:  0.331986
# max ca:  1.1052
# Node id:  60 Catchment area:  0.142506
# Node id:  50 Catchment area:  0.637737
# Node id:  40 Catchment area:  0.727349
# max ca:  0.638175
# Node id:  60 Catchment area:  0.194793
# Node id:  50 Catchment area:  0.482786
# Node id:  39 Catchment area:  0.355159
# max ca:  0.635095
# Node id:  60 Catchment area:  0.582071
# Node id:  72 Catchment area:  0.449441
# max ca:  0.937562
# Node id:  60 Catchment area:  0.369962
# Node id:  72 Catchment area:  0.574856
# Node id:  84 Catchment area:  0.379282
# max ca:  3.61916
# Node id:  60 Catchment area:  0.925798
# max ca:  1.90952
# Node id:  60 Catchment area:  0.904324
# Node id:  48 Catchment area:  1.20147
# max ca:  0.534164
# Node id:  60 Catchment area:  0.391292
# max ca:  2.97858
# Node id:  60 Catchment area:  2.45056
# max ca:  0.996747
# Node id:  60 Catchment area:  0.0898164
# Node id:  71 Catchment area:  0.215084
# Node id:  81 Catchment area:  0.271106
# max ca:  2.05349
# Node id:  60 Catchment area:  0.963253
# max ca:  2.76358
# Node id:  60 Catchment area:  1.59525
# max ca:  1.0044
# Node id:  60 Catchment area:  0.492128
# max ca:  0.417335
# Node id:  60 Catchment area:  0.343034
# Node id:  59 Catchment area:  0.30512
# Node id:  69 Catchment area:  0.340258
# max ca:  1.90929
# Node id:  60 Catchment area:  0.46522
# Node id:  70 Catchment area:  0.908668
# max ca:  2.97041
# Node id:  60 Catchment area:  0.989145
# max ca:  0.508226
# Node id:  60 Catchment area:  0.354846
# Node id:  71 Catchment area:  0.346602
# max ca:  0.528891
# Node id:  60 Catchment area:  0.353162
# Node id:  59 Catchment area:  0.2967
# Node id:  69 Catchment area:  0.47459
# Node id:  68 Catchment area:  0.528891
# Node id:  67 Catchment area:  0.468831
# max ca:  0.439951
# Node id:  60 Catchment area:  0.289778
# Node id:  49 Catchment area:  0.305556
# max ca:  1.33865
# Node id:  60 Catchment area:  1.16787
# Node id:  70 Catchment area:  0.699115
# Node id:  69 Catchment area:  1.08471
# max ca:  1.06157
# Node id:  60 Catchment area:  0.524607
# Node id:  59 Catchment area:  0.774664
# max ca:  0.883479
# Node id:  60 Catchment area:  0.298219
# Node id:  48 Catchment area:  0.293548
# max ca:  0.556662
# Node id:  60 Catchment area:  0.222705
# Node id:  70 Catchment area:  0.367573
# Node id:  81 Catchment area:  0.449062
# Node id:  91 Catchment area:  0.424643
# Node id:  101 Catchment area:  0.41878
# max ca:  0.560883
# Node id:  60 Catchment area:  0.363472
# max ca:  1.288
# Node id:  60 Catchment area:  1.07995
# Node id:  59 Catchment area:  0.931613
# Node id:  47 Catchment area:  1.11935
# max ca:  0.624484
# Node id:  60 Catchment area:  0.515506
# Node id:  48 Catchment area:  0.423051
# max ca:  0.566864
# Node id:  60 Catchment area:  0.327164
# Node id:  71 Catchment area:  0.430298
# max ca:  0.55526
# Node id:  60 Catchment area:  0.301162
# Node id:  70 Catchment area:  0.465308
# max ca:  0.349008
# Node id:  60 Catchment area:  0.25585
# max ca:  0.945001
# Node id:  60 Catchment area:  0.733114
# Node id:  50 Catchment area:  0.826068
# Node id:  39 Catchment area:  0.701821
# max ca:  2.75227
# Node id:  60 Catchment area:  0.308305
# Node id:  50 Catchment area:  0.415129
# max ca:  9.83599
# Node id:  60 Catchment area:  0.330655
# Node id:  59 Catchment area:  0.570259
# max ca:  1.0708
# Node id:  60 Catchment area:  0.776433
# Node id:  59 Catchment area:  0.954417
# Node id:  69 Catchment area:  0.936117
# Node id:  68 Catchment area:  0.837155
# max ca:  1.07109
# Node id:  60 Catchment area:  0.301716
# max ca:  2.37374
# Node id:  60 Catchment area:  1.39801
# Node id:  48 Catchment area:  1.47914
# max ca:  0.534241
# Node id:  60 Catchment area:  0.232437
# Node id:  71 Catchment area:  0.349384
# Node id:  81 Catchment area:  0.390402
# max ca:  4.68032
# Node id:  60 Catchment area:  0.933474
# Node id:  71 Catchment area:  2.21282
# max ca:  58.8442
# Node id:  60 Catchment area:  3.42844
# max ca:  1.98775
# Node id:  60 Catchment area:  0.135208
# Node id:  72 Catchment area:  0.138691
# Node id:  73 Catchment area:  0.155394
# Node id:  74 Catchment area:  0.184842
# Node id:  75 Catchment area:  1.86435
# max ca:  1.02699
# Node id:  60 Catchment area:  0.393282
# max ca:  1.48251
# Node id:  60 Catchment area:  0.445942
# Node id:  49 Catchment area:  1.20555
# Node id:  39 Catchment area:  0.719366
# max ca:  0.943176
# Node id:  60 Catchment area:  0.375694
# Node id:  50 Catchment area:  0.552065
# Node id:  40 Catchment area:  0.652122
# Node id:  30 Catchment area:  0.704768
# Node id:  19 Catchment area:  0.796621
# max ca:  14.9308
# Node id:  60 Catchment area:  2.25194
# max ca:  2.23608
# Node id:  60 Catchment area:  0.946353
# Node id:  49 Catchment area:  1.92596
# Node id:  38 Catchment area:  1.37964
# max ca:  2.94172
# Node id:  60 Catchment area:  0.530065
# Node id:  49 Catchment area:  0.451576
# Node id:  39 Catchment area:  0.45904
# max ca:  68.1325
# Node id:  60 Catchment area:  2.87788
# max ca:  6.85566
# Node id:  60 Catchment area:  0.0683661
# Node id:  59 Catchment area:  0.905299
# max ca:  2.78705
# Node id:  60 Catchment area:  1.03441
# Node id:  49 Catchment area:  1.14448
# Node id:  38 Catchment area:  1.11584
# Node id:  27 Catchment area:  1.29829
# max ca:  3.27389
# Node id:  60 Catchment area:  1.5256
# max ca:  4.85215
# Node id:  60 Catchment area:  0.769055
# Node id:  71 Catchment area:  4.50888
# Node id:  83 Catchment area:  2.64408
# Node id:  84 Catchment area:  4.44755
# max ca:  0.535856
# Node id:  60 Catchment area:  0.164751
# Node id:  49 Catchment area:  0.332551
# max ca:  0.996047
# Node id:  60 Catchment area:  0.405007
# Node id:  49 Catchment area:  0.704998
# max ca:  0.905282
# Node id:  60 Catchment area:  0.688776
# max ca:  1.20342
# Node id:  60 Catchment area:  0.657563
# Node id:  71 Catchment area:  0.970002
# max ca:  0.956478
# Node id:  60 Catchment area:  0.466264
# Node id:  61 Catchment area:  0.597074
# max ca:  1.07684
# Node id:  60 Catchment area:  0.0869579
# Node id:  71 Catchment area:  0.862846
# max ca:  13.0402
# Node id:  60 Catchment area:  0.779352
# Node id:  71 Catchment area:  0.937527
# max ca:  1.86451
# Node id:  60 Catchment area:  1.84341
# max ca:  1.47088
# Node id:  60 Catchment area:  0.848403
# Node id:  49 Catchment area:  0.685744
# max ca:  1.29727
# Node id:  60 Catchment area:  0.365355
# Node id:  71 Catchment area:  0.455794
# Node id:  81 Catchment area:  0.864138
# max ca:  1.01868
# Node id:  60 Catchment area:  0.776972
# Node id:  48 Catchment area:  0.744814
# Node id:  36 Catchment area:  0.99948
# max ca:  0.868849
# Node id:  60 Catchment area:  0.407659
# Node id:  49 Catchment area:  0.551115
# max ca:  2.72622
# Node id:  60 Catchment area:  0.509232
# Node id:  71 Catchment area:  1.26059
# Node id:  82 Catchment area:  2.25716
# max ca:  2.26915
# Node id:  60 Catchment area:  0.988378
# Node id:  49 Catchment area:  0.742875
# Node id:  39 Catchment area:  0.946594
# Node id:  40 Catchment area:  1.4834
# Node id:  30 Catchment area:  2.09208
# max ca:  1.00774
# Node id:  60 Catchment area:  0.0042562
# Node id:  71 Catchment area:  0.992431
# max ca:  1.11448
# Node id:  60 Catchment area:  0.218468
# Node id:  70 Catchment area:  0.637215
# Node id:  69 Catchment area:  0.671764
# max ca:  1.58231
# Node id:  60 Catchment area:  0.383166
# Node id:  59 Catchment area:  0.350733
# max ca:  4.17
# Node id:  60 Catchment area:  0.0152595
# Node id:  49 Catchment area:  3.88964
# Node id:  39 Catchment area:  2.75691
# max ca:  2.17516
# Node id:  60 Catchment area:  2.07917
# max ca:  3.59747
# Node id:  60 Catchment area:  3.53272
# Node id:  70 Catchment area:  2.07939
# max ca:  0.957404
# Node id:  60 Catchment area:  0.444092
# Node id:  71 Catchment area:  0.474735
# Node id:  81 Catchment area:  0.509451
# Node id:  92 Catchment area:  0.750839
# max ca:  1.13232
# Node id:  60 Catchment area:  0.193294
# Node id:  61 Catchment area:  0.478021
# Node id:  62 Catchment area:  0.546474
# Node id:  63 Catchment area:  0.477676
# max ca:  0.978881
# Node id:  60 Catchment area:  0.594807
# Node id:  59 Catchment area:  0.330794
# Node id:  47 Catchment area:  0.728831
# Node id:  46 Catchment area:  0.739082
# max ca:  1.23076
# Node id:  60 Catchment area:  0.657037
# Node id:  70 Catchment area:  0.421204
# Node id:  69 Catchment area:  1.01639
# max ca:  0.710457
# Node id:  60 Catchment area:  0.284376
# Node id:  49 Catchment area:  0.267258
# Node id:  38 Catchment area:  0.539943
# max ca:  0.708363
# Node id:  60 Catchment area:  0.163891
# Node id:  70 Catchment area:  0.206046
# Node id:  82 Catchment area:  0.3747
# Node id:  92 Catchment area:  0.673173
# max ca:  0.707031
# Node id:  60 Catchment area:  0.280397
# Node id:  70 Catchment area:  0.373427
# Node id:  80 Catchment area:  0.447373
# max ca:  3.44596
# Node id:  60 Catchment area:  1.33631
# Node id:  70 Catchment area:  1.44488
# Node id:  69 Catchment area:  1.48416
# Node id:  68 Catchment area:  2.10679
# Node id:  57 Catchment area:  2.36792
# max ca:  3.42808
# Node id:  60 Catchment area:  0.406095
# Node id:  59 Catchment area:  0.535255
# Node id:  47 Catchment area:  0.900652
# Node id:  46 Catchment area:  1.15241
# max ca:  0.718788
# Node id:  60 Catchment area:  0.0914556
# Node id:  70 Catchment area:  0.133651
# Node id:  80 Catchment area:  0.145486
# Node id:  90 Catchment area:  0.171859
# Node id:  101 Catchment area:  0.252698
# max ca:  28.893
# Node id:  60 Catchment area:  0.287527
# Node id:  61 Catchment area:  0.580533
# max ca:  1.37986
# Node id:  60 Catchment area:  0.712436
# Node id:  50 Catchment area:  0.918953
# max ca:  59.0197
# Node id:  60 Catchment area:  0.330607
# Node id:  70 Catchment area:  0.831001
# Node id:  80 Catchment area:  0.498139
# max ca:  0.666452
# Node id:  60 Catchment area:  0.426986
# max ca:  1.03159
# Node id:  60 Catchment area:  0.676866
# Node id:  50 Catchment area:  0.408526
# Node id:  51 Catchment area:  0.911848
# max ca:  0.451605
# Node id:  60 Catchment area:  0.234844
# Node id:  48 Catchment area:  0.140653
# Node id:  47 Catchment area:  0.392616
# max ca:  0.296879
# Node id:  60 Catchment area:  0.00112536
# Node id:  61 Catchment area:  0.258479
# max ca:  0.528257
# Node id:  60 Catchment area:  0.444212
# Node id:  71 Catchment area:  0.46986
# Node id:  81 Catchment area:  0.459836
# Node id:  92 Catchment area:  0.377452
# Node id:  104 Catchment area:  0.508513
# max ca:  2.10639
# Node id:  60 Catchment area:  1.51661
# Node id:  48 Catchment area:  1.44822
# Node id:  36 Catchment area:  2.10639
# Node id:  35 Catchment area:  1.24997
# Node id:  34 Catchment area:  1.12996
# max ca:  0.99441
# Node id:  60 Catchment area:  0.237781
# Node id:  49 Catchment area:  0.342216
# max ca:  1.01889
# Node id:  60 Catchment area:  0.350959
# Node id:  48 Catchment area:  0.560637
# Node id:  37 Catchment area:  0.562715
# max ca:  1.21943
# Node id:  60 Catchment area:  0.568413
# Node id:  49 Catchment area:  0.613129
# max ca:  4.23527
# Node id:  60 Catchment area:  3.51144
# Node id:  49 Catchment area:  3.30027
# max ca:  1.91258
# Node id:  60 Catchment area:  1.35919
# Node id:  49 Catchment area:  1.05074
# max ca:  0.876163
# Node id:  60 Catchment area:  0.622661
# Node id:  49 Catchment area:  0.500579
# max ca:  82.7004
# Node id:  60 Catchment area:  2.87737
# max ca:  1.35912
# Node id:  60 Catchment area:  0.29561
# max ca:  1.17869
# Node id:  60 Catchment area:  0.514394
# max ca:  1.73285
# Node id:  60 Catchment area:  0.43025
# Node id:  59 Catchment area:  0.214903
# Node id:  48 Catchment area:  0.710874
# Node id:  36 Catchment area:  0.86138
# Node id:  24 Catchment area:  1.24098
# max ca:  0.623008
# Node id:  60 Catchment area:  0.409742
# max ca:  1.7043
# Node id:  60 Catchment area:  0.642444
# Node id:  70 Catchment area:  1.45776
# max ca:  0.51529
# Node id:  60 Catchment area:  0.417268
# max ca:  0.749827
# Node id:  60 Catchment area:  0.345567
# Node id:  59 Catchment area:  0.303834
# Node id:  58 Catchment area:  0.469273
# max ca:  4.16329
# Node id:  60 Catchment area:  3.72351
# max ca:  0.567084
# Node id:  60 Catchment area:  0.341374
# Node id:  72 Catchment area:  0.551856
# max ca:  2.69353
# Node id:  60 Catchment area:  1.23513
# Node id:  49 Catchment area:  1.8114
# Node id:  37 Catchment area:  1.40276
# Node id:  26 Catchment area:  1.85068
# Node id:  25 Catchment area:  1.88204
# max ca:  5.52971
# Node id:  60 Catchment area:  0.302141
# Node id:  48 Catchment area:  0.375963
# max ca:  0.402233
# Node id:  60 Catchment area:  0.0736943
# Node id:  49 Catchment area:  0.218344
# Node id:  38 Catchment area:  0.261951
# Node id:  27 Catchment area:  0.331491
# max ca:  0.750503
# Node id:  60 Catchment area:  0.356086
# max ca:  0.551951
# Node id:  60 Catchment area:  0.0488188
# Node id:  49 Catchment area:  0.293409
# max ca:  0.89229
# Node id:  60 Catchment area:  0.264142
# Node id:  49 Catchment area:  0.536251
# Node id:  39 Catchment area:  0.603211
# max ca:  0.883007
# Node id:  60 Catchment area:  0.386667
# Node id:  48 Catchment area:  0.48174
# max ca:  1.20689
# Node id:  60 Catchment area:  0.386175
# max ca:  0.943513
# Node id:  60 Catchment area:  0.415139
# Node id:  48 Catchment area:  0.608414
# Node id:  47 Catchment area:  0.623927
# Node id:  35 Catchment area:  0.694438
# max ca:  0.616653
# Node id:  60 Catchment area:  0.280451
# Node id:  59 Catchment area:  0.286644
# Node id:  58 Catchment area:  0.203285
# Node id:  57 Catchment area:  0.162824
# Node id:  67 Catchment area:  0.441248
# max ca:  1.75694
# Node id:  60 Catchment area:  0.295095
# Node id:  49 Catchment area:  0.499628
# Node id:  38 Catchment area:  0.727759
# Node id:  28 Catchment area:  0.704868
# max ca:  0.635135
# Node id:  60 Catchment area:  0.384587
# max ca:  0.587971
# Node id:  60 Catchment area:  0.331272
# Node id:  49 Catchment area:  0.319943
# max ca:  0.702826
# Node id:  60 Catchment area:  0.0786974
# Node id:  49 Catchment area:  0.260362
# max ca:  1.47473
# Node id:  60 Catchment area:  0.976909
# max ca:  3.11111
# Node id:  60 Catchment area:  1.11626
# Node id:  71 Catchment area:  2.96092
# Node id:  82 Catchment area:  2.00148
# max ca:  16.1574
# Node id:  60 Catchment area:  1.94184
# Node id:  61 Catchment area:  7.30681
# Node id:  51 Catchment area:  10.364
# max ca:  2.53189
# Node id:  60 Catchment area:  1.19968
# Node id:  48 Catchment area:  2.11633
# max ca:  16.6357
# Node id:  60 Catchment area:  0.172807
# Node id:  50 Catchment area:  0.451179
# Node id:  51 Catchment area:  0.445097
# max ca:  2.24652
# Node id:  60 Catchment area:  0.560938
# max ca:  0.493538
# Node id:  60 Catchment area:  0.384162
# max ca:  0.680638
# Node id:  60 Catchment area:  0.239913
# Node id:  49 Catchment area:  0.527548
# max ca:  1.65388
# Node id:  60 Catchment area:  0.898703
# max ca:  0.647686
# Node id:  60 Catchment area:  0.38567
# Node id:  61 Catchment area:  0.27538
# Node id:  51 Catchment area:  0.513194
# Node id:  41 Catchment area:  0.410001
# Node id:  42 Catchment area:  0.62349
# max ca:  1.96096
# Node id:  60 Catchment area:  0.949194
# Node id:  70 Catchment area:  1.09269
# Node id:  80 Catchment area:  1.52529
# Node id:  79 Catchment area:  1.0339
# Node id:  89 Catchment area:  1.62972
# max ca:  1.52529
# Node id:  60 Catchment area:  0.424477
# max ca:  1.41492
# Node id:  60 Catchment area:  0.934027
# Node id:  61 Catchment area:  1.04431
# max ca:  0.544529
# Node id:  60 Catchment area:  0.483174
# max ca:  0.846638
# Node id:  60 Catchment area:  0.407248
# Node id:  70 Catchment area:  0.641812
# Node id:  81 Catchment area:  0.49527
# max ca:  1.31721
# Node id:  60 Catchment area:  1.19296
# max ca:  16.3226
# Node id:  60 Catchment area:  7.59403
# Node id:  71 Catchment area:  14.6848
# Node id:  83 Catchment area:  13.0671
# max ca:  0.699745
# Node id:  60 Catchment area:  0.382353
# Node id:  49 Catchment area:  0.530677
# max ca:  0.504384
# Node id:  60 Catchment area:  0.245348
# Node id:  59 Catchment area:  0.252576
# max ca:  3.10761
# Node id:  60 Catchment area:  2.46938
# max ca:  0.654868
# Node id:  60 Catchment area:  0.306678
# Node id:  71 Catchment area:  0.437348
# max ca:  0.498888
# Node id:  60 Catchment area:  0.320914
# max ca:  9.07347
# Node id:  60 Catchment area:  3.4934
# Node id:  70 Catchment area:  3.0779
# Node id:  81 Catchment area:  2.66684
# max ca:  9.08362
# Node id:  60 Catchment area:  2.07614
# Node id:  59 Catchment area:  3.44842
# Node id:  70 Catchment area:  3.98428
# Node id:  80 Catchment area:  9.03496
# max ca:  2.30562
# Node id:  60 Catchment area:  2.23658
# max ca:  0.531917
# Node id:  60 Catchment area:  0.355586
# Node id:  59 Catchment area:  0.339902
# max ca:  1.34748
# Node id:  60 Catchment area:  0.959544
# max ca:  1.50641
# Node id:  60 Catchment area:  0.444768
# Node id:  59 Catchment area:  0.57326
# Node id:  58 Catchment area:  1.20053
# max ca:  2.13609
# Node id:  60 Catchment area:  0.929925
# Node id:  59 Catchment area:  1.61693
# max ca:  44.679
# Node id:  60 Catchment area:  1.18267
# Node id:  71 Catchment area:  1.4999
# max ca:  1.42466
# Node id:  60 Catchment area:  1.01113
# Node id:  48 Catchment area:  1.22496
# max ca:  0.864264
# Node id:  60 Catchment area:  0.654951
# max ca:  52.0085
# Node id:  60 Catchment area:  4.38041
# Node id:  72 Catchment area:  2.56774
# max ca:  2.20147
# Node id:  60 Catchment area:  0.221075
# Node id:  71 Catchment area:  1.74712
# max ca:  1.90997
# Node id:  60 Catchment area:  0.40035
# Node id:  70 Catchment area:  0.4456
# max ca:  0.67689
# Node id:  60 Catchment area:  0.40397
# max ca:  0.556334
# Node id:  60 Catchment area:  0.319261
# Node id:  70 Catchment area:  0.196217
# Node id:  69 Catchment area:  0.516854
# max ca:  15.2372
# Node id:  60 Catchment area:  1.6788
# max ca:  0.760659
# Node id:  60 Catchment area:  0.332311
# Node id:  59 Catchment area:  0.435032
# max ca:  34.364
# Node id:  60 Catchment area:  1.33866
# max ca:  0.241708
# Node id:  60 Catchment area:  0.20866
# Node id:  71 Catchment area:  0.241708
# Node id:  82 Catchment area:  0.23701
# Node id:  92 Catchment area:  0.208294
# Node id:  103 Catchment area:  0.169412
# max ca:  0.631009
# Node id:  60 Catchment area:  0.294549
# Node id:  72 Catchment area:  0.423883
# max ca:  0.579081
# Node id:  60 Catchment area:  0.309303
# Node id:  71 Catchment area:  0.362159
# Node id:  82 Catchment area:  0.286937
# max ca:  1.12075
# Node id:  60 Catchment area:  0.400542
# max ca:  0.617457
# Node id:  60 Catchment area:  0.153464
# Node id:  72 Catchment area:  0.245033
# Node id:  84 Catchment area:  0.233417
# Node id:  95 Catchment area:  0.165821
# Node id:  107 Catchment area:  0.378839
# max ca:  0.543425
# Node id:  60 Catchment area:  0.00930556
# Node id:  70 Catchment area:  0.407523
# max ca:  1.96284
# Node id:  60 Catchment area:  1.00283
# Node id:  71 Catchment area:  1.35653
# max ca:  46.4424
# Node id:  60 Catchment area:  0.0004556
# Node id:  49 Catchment area:  2.99887
# max ca:  1.27305
# Node id:  60 Catchment area:  0.243264
# Node id:  59 Catchment area:  0.235308
# Node id:  70 Catchment area:  0.653447
# max ca:  3.45857
# Node id:  60 Catchment area:  0.786459
# Node id:  59 Catchment area:  0.673752
# max ca:  0.673563
# Node id:  60 Catchment area:  0.577574
# max ca:  0.762803
# Node id:  60 Catchment area:  0.43303
# Node id:  71 Catchment area:  0.540743
# Node id:  82 Catchment area:  0.370458
# max ca:  11.9811
# Node id:  60 Catchment area:  2.71684
# Node id:  49 Catchment area:  1.78898
# Node id:  37 Catchment area:  3.45857
# Node id:  36 Catchment area:  1.69277
# max ca:  2.03502
# Node id:  60 Catchment area:  0.365088
# max ca:  2.04016
# Node id:  60 Catchment area:  1.44424
# max ca:  4.49929
# Node id:  60 Catchment area:  0.239156
# Node id:  71 Catchment area:  1.7414
# max ca:  0.500299
# Node id:  60 Catchment area:  0.18297
# Node id:  49 Catchment area:  0.251705
# Node id:  39 Catchment area:  0.491088
# max ca:  1.4129
# Node id:  60 Catchment area:  1.17923
# max ca:  2.51417
# Node id:  60 Catchment area:  0.958324
# Node id:  59 Catchment area:  2.06474
# Node id:  69 Catchment area:  1.75572
# max ca:  2.95547
# Node id:  60 Catchment area:  0.923597
# Node id:  71 Catchment area:  2.16431
# max ca:  0.432579
# Node id:  60 Catchment area:  0.0238036
# Node id:  49 Catchment area:  0.0430804
# Node id:  38 Catchment area:  0.189241
# Node id:  27 Catchment area:  0.320176
# max ca:  1.85986
# Node id:  60 Catchment area:  0.013894
# Node id:  48 Catchment area:  1.85986
# Node id:  58 Catchment area:  1.28812
# Node id:  57 Catchment area:  1.32442
# max ca:  1.32192
# Node id:  60 Catchment area:  0.345344
# Node id:  49 Catchment area:  0.575312
# Node id:  39 Catchment area:  0.828447
# Node id:  28 Catchment area:  0.747864
# max ca:  0.517875
# Node id:  60 Catchment area:  0.25469
# Node id:  49 Catchment area:  0.197346
# Node id:  37 Catchment area:  0.339362
# max ca:  1.89242
# Node id:  60 Catchment area:  1.69887
# max ca:  1.13194
# Node id:  60 Catchment area:  0.930915
# Node id:  71 Catchment area:  0.734496
# max ca:  2.35809
# Node id:  60 Catchment area:  1.7881
# Node id:  71 Catchment area:  1.3979
# max ca:  0.523728
# Node id:  60 Catchment area:  0.246464
# Node id:  71 Catchment area:  0.313424
# Node id:  83 Catchment area:  0.202373
# Node id:  84 Catchment area:  0.423653
# max ca:  5.91029
# Node id:  60 Catchment area:  0.135685
# Node id:  49 Catchment area:  0.105763
# Node id:  38 Catchment area:  0.0810082
# Node id:  27 Catchment area:  5.61816
# max ca:  6.5103
# Node id:  60 Catchment area:  5.62199
# Node id:  72 Catchment area:  6.49727
# max ca:  0.607836
# Node id:  60 Catchment area:  0.344951
# Node id:  61 Catchment area:  0.35368
# Node id:  51 Catchment area:  0.435808
# Node id:  41 Catchment area:  0.379049
# Node id:  30 Catchment area:  0.571965
# max ca:  3.58238
# Node id:  60 Catchment area:  0.11529
# Node id:  48 Catchment area:  0.129559
# Node id:  37 Catchment area:  0.130397
# Node id:  27 Catchment area:  0.173139
# Node id:  16 Catchment area:  3.58238
# max ca:  2.50109
# Node id:  60 Catchment area:  2.08059
# Node id:  59 Catchment area:  1.8962
# Node id:  47 Catchment area:  1.63053
# Node id:  46 Catchment area:  1.49038
# Node id:  34 Catchment area:  1.64864
# max ca:  7.81323
# Node id:  60 Catchment area:  5.83356
# Node id:  49 Catchment area:  4.663
# max ca:  0.787887
# Node id:  60 Catchment area:  0.360645
# Node id:  50 Catchment area:  0.427229
# Node id:  39 Catchment area:  0.523404
# max ca:  1.75314
# Node id:  60 Catchment area:  0.996416
# Node id:  59 Catchment area:  0.967222
# Node id:  47 Catchment area:  1.36143
# Node id:  35 Catchment area:  1.30505
# max ca:  2.79668
# Node id:  60 Catchment area:  0.898939
# Node id:  59 Catchment area:  2.59594
# max ca:  0.577555
# Node id:  60 Catchment area:  0.294341
# Node id:  48 Catchment area:  0.439904
# Node id:  36 Catchment area:  0.541421
# max ca:  0.700939
# Node id:  60 Catchment area:  0.512455
# Node id:  49 Catchment area:  0.628132
# Node id:  38 Catchment area:  0.439418
# max ca:  0.730374
# Node id:  60 Catchment area:  0.382152
# Node id:  49 Catchment area:  0.480386
# Node id:  38 Catchment area:  0.425678
# max ca:  0.643721
# Node id:  60 Catchment area:  0.477322
# Node id:  59 Catchment area:  0.371028
# max ca:  0.425171
# Node id:  60 Catchment area:  0.139752
# Node id:  48 Catchment area:  0.258026
# Node id:  36 Catchment area:  0.225083
# Node id:  24 Catchment area:  0.303851
# max ca:  5.09204
# Node id:  60 Catchment area:  4.76403
# max ca:  44.5923
# Node id:  60 Catchment area:  0.241091
# Node id:  71 Catchment area:  0.217154
# Node id:  82 Catchment area:  0.268415
# Node id:  94 Catchment area:  0.205004
# Node id:  105 Catchment area:  0.25072
# max ca:  2.07304
# Node id:  60 Catchment area:  0.265798
# Node id:  50 Catchment area:  1.66973
# Node id:  40 Catchment area:  1.48528
# Node id:  30 Catchment area:  0.870931
# Node id:  31 Catchment area:  1.84331
# max ca:  0.469615
# Node id:  60 Catchment area:  0.222623
# Node id:  49 Catchment area:  0.386063
# max ca:  0.709075
# Node id:  60 Catchment area:  0.495232
# Node id:  49 Catchment area:  0.532574
# Node id:  38 Catchment area:  0.589938
# max ca:  0.528527
# Node id:  60 Catchment area:  0.433043
# max ca:  0.930532
# Node id:  60 Catchment area:  0.471888
# max ca:  0.360194
# Node id:  60 Catchment area:  0.265141
# Node id:  71 Catchment area:  0.226079
# Node id:  83 Catchment area:  0.338914
# max ca:  0.825689
# Node id:  60 Catchment area:  0.232173
# Node id:  59 Catchment area:  0.292826
# max ca:  1.01146
# Node id:  60 Catchment area:  0.644631
# max ca:  0.490727
# Node id:  60 Catchment area:  0.289341
# Node id:  49 Catchment area:  0.273738
# max ca:  3.42587
# Node id:  60 Catchment area:  1.91956
# max ca:  32.8023
# Node id:  60 Catchment area:  32.2426
# max ca:  4.3805
# Node id:  60 Catchment area:  3.33553
# Node id:  48 Catchment area:  3.67945
# max ca:  1.25
# Node id:  60 Catchment area:  1.14081
# max ca:  1.63065
# Node id:  60 Catchment area:  0.390329
# Node id:  59 Catchment area:  1.04764
# Node id:  58 Catchment area:  1.133
# max ca:  0.877975
# Node id:  60 Catchment area:  0.3084
# Node id:  59 Catchment area:  0.77358
# Node id:  58 Catchment area:  0.52281
# max ca:  0.928058
# Node id:  60 Catchment area:  0.322583
# Node id:  70 Catchment area:  0.373291
# Node id:  81 Catchment area:  0.667307
# Node id:  92 Catchment area:  0.71792
# Node id:  103 Catchment area:  0.512176
# max ca:  1.96222
# Node id:  60 Catchment area:  1.11059
# max ca:  0.7084
# Node id:  60 Catchment area:  0.433783
# Node id:  59 Catchment area:  0.410525
# max ca:  1.32481
# Node id:  60 Catchment area:  0.653629
# max ca:  1.07601
# Node id:  60 Catchment area:  0.232595
# Node id:  70 Catchment area:  0.906848
# max ca:  10.0923
# Node id:  60 Catchment area:  8.12323
# max ca:  2.87541
# Node id:  60 Catchment area:  0.727031
# Node id:  49 Catchment area:  1.00767
# max ca:  6.83683
# Node id:  60 Catchment area:  0.699195
# max ca:  1.71245
# Node id:  60 Catchment area:  0.244195
# Node id:  72 Catchment area:  0.24762
# Node id:  83 Catchment area:  0.128029
# Node id:  94 Catchment area:  0.228387
# Node id:  105 Catchment area:  1.48938
# max ca:  1.39869
# Node id:  60 Catchment area:  0.690382
# Node id:  59 Catchment area:  0.906113
# max ca:  0.675151
# Node id:  60 Catchment area:  0.49513
# max ca:  1.56192
# Node id:  60 Catchment area:  0.410826
# Node id:  71 Catchment area:  0.436913
# max ca:  1.0385
# Node id:  60 Catchment area:  0.662985
# Node id:  59 Catchment area:  0.673494
# max ca:  0.626201
# Node id:  60 Catchment area:  0.146091
# Node id:  71 Catchment area:  0.384323
# max ca:  0.721417
# Node id:  60 Catchment area:  0.399814
# Node id:  61 Catchment area:  0.377597
# Node id:  73 Catchment area:  0.458034
# max ca:  4.19578
# Node id:  60 Catchment area:  2.64917
# Node id:  71 Catchment area:  2.67123
# Node id:  81 Catchment area:  3.60255
# max ca:  4.17529
# Node id:  60 Catchment area:  0.630613
# Node id:  70 Catchment area:  0.95878
# max ca:  0.4567
# Node id:  60 Catchment area:  0.408975
# Node id:  48 Catchment area:  0.336752
# max ca:  1.75549
# Node id:  60 Catchment area:  0.836963
# Node id:  70 Catchment area:  1.28913
# Node id:  80 Catchment area:  1.64286
# max ca:  0.817896
# Node id:  60 Catchment area:  0.563313
# Node id:  72 Catchment area:  0.646782
# max ca:  1.08209
# Node id:  60 Catchment area:  0.223346
# Node id:  72 Catchment area:  0.292911
# max ca:  1.73491
# Node id:  60 Catchment area:  1.10374
# max ca:  13.1684
# Node id:  60 Catchment area:  1.13765
# max ca:  1.11693
# Node id:  60 Catchment area:  0.770552
# Node id:  72 Catchment area:  0.861979
# max ca:  0.348472
# Node id:  60 Catchment area:  0.0908677
# Node id:  59 Catchment area:  0.23985
# Node id:  58 Catchment area:  0.323631
# Node id:  68 Catchment area:  0.200803
# Node id:  67 Catchment area:  0.345486
# max ca:  1.4781
# Node id:  60 Catchment area:  0.743195
# Node id:  72 Catchment area:  0.985125
# max ca:  0.556582
# Node id:  60 Catchment area:  0.071735
# Node id:  71 Catchment area:  0.0692242
# Node id:  82 Catchment area:  0.176405
# Node id:  94 Catchment area:  0.171917
# Node id:  105 Catchment area:  0.556582
# max ca:  2.0266
# Node id:  60 Catchment area:  0.340768
# Node id:  72 Catchment area:  0.386175
# Node id:  83 Catchment area:  0.690778
# Node id:  95 Catchment area:  0.791214
# Node id:  107 Catchment area:  0.677031
# max ca:  0.978321
# Node id:  60 Catchment area:  0.60205
# max ca:  1.05276
# Node id:  60 Catchment area:  0.0837005
# Node id:  59 Catchment area:  0.586782
# Node id:  69 Catchment area:  0.785653
# max ca:  1.19022
# Node id:  60 Catchment area:  0.28496
# Node id:  72 Catchment area:  0.779159
# max ca:  25.235
# Node id:  60 Catchment area:  0.740196
# Node id:  59 Catchment area:  2.87489
# max ca:  25.2397
# Node id:  60 Catchment area:  0.0135765
# Node id:  70 Catchment area:  0.0566544
# Node id:  81 Catchment area:  0.0586932
# Node id:  91 Catchment area:  0.0607703
# Node id:  102 Catchment area:  0.0641626
# max ca:  0.647149
# Node id:  60 Catchment area:  0.261565
# max ca:  5.37335
# Node id:  60 Catchment area:  0.416545
# Node id:  70 Catchment area:  3.8827
# Node id:  82 Catchment area:  3.15735
# max ca:  2.07102
# Node id:  60 Catchment area:  1.97331
# max ca:  5.68955
# Node id:  60 Catchment area:  0.512989
# max ca:  0.747631
# Node id:  60 Catchment area:  0.304494
# max ca:  2.31137
# Node id:  60 Catchment area:  1.40176
# max ca:  0.746769
# Node id:  60 Catchment area:  0.50447
# Node id:  71 Catchment area:  0.438558
# max ca:  0.718794
# Node id:  60 Catchment area:  0.362039
# Node id:  70 Catchment area:  0.584424
# max ca:  1.19379
# Node id:  60 Catchment area:  0.332855
# Node id:  71 Catchment area:  0.867679
# max ca:  1.86472
# Node id:  60 Catchment area:  0.632203
# Node id:  70 Catchment area:  0.865341
# Node id:  69 Catchment area:  0.674906
# Node id:  80 Catchment area:  1.27687
# Node id:  90 Catchment area:  1.08874
# max ca:  2.14349
# Node id:  60 Catchment area:  0.996955
# max ca:  2.14349
# Node id:  60 Catchment area:  1.35595
# Node id:  71 Catchment area:  1.14236
# max ca:  1.25387
# Node id:  60 Catchment area:  1.12902
# max ca:  1.68759
# Node id:  60 Catchment area:  0.959673
# Node id:  70 Catchment area:  1.13081
# max ca:  1.58703
# Node id:  60 Catchment area:  0.884798
# Node id:  71 Catchment area:  0.693751
# Node id:  82 Catchment area:  1.34631
# max ca:  5.38223
# Node id:  60 Catchment area:  2.25053
# Node id:  70 Catchment area:  1.38487
# Node id:  69 Catchment area:  1.90911
# max ca:  10.8813
# Node id:  60 Catchment area:  0.0004524
# Node id:  59 Catchment area:  7.13147
# Node id:  69 Catchment area:  6.95103
# max ca:  2.30416
# Node id:  60 Catchment area:  1.79302
# max ca:  0.966868
# Node id:  60 Catchment area:  0.8088
# Node id:  61 Catchment area:  0.515519
# max ca:  6.8146
# Node id:  60 Catchment area:  4.0466
# max ca:  1.40281
# Node id:  60 Catchment area:  0.0403882
# Node id:  49 Catchment area:  1.22717
# max ca:  1.36492
# Node id:  60 Catchment area:  0.504212
# Node id:  72 Catchment area:  0.907904
# max ca:  5.98066
# Node id:  60 Catchment area:  2.00588
# Node id:  59 Catchment area:  5.46014
# max ca:  1.71609
# Node id:  60 Catchment area:  1.62494
# max ca:  3.62922
# Node id:  60 Catchment area:  3.62133
# max ca:  0.511377
# Node id:  60 Catchment area:  0.432746
# max ca:  7.42015
# Node id:  60 Catchment area:  6.76764
# max ca:  0.753526
# Node id:  60 Catchment area:  0.115
# Node id:  59 Catchment area:  0.364244
# Node id:  58 Catchment area:  0.536634
# Node id:  46 Catchment area:  0.473953
# max ca:  1.40468
# Node id:  60 Catchment area:  0.896031
# Node id:  71 Catchment area:  0.801197
# Node id:  70 Catchment area:  0.974543
# Node id:  80 Catchment area:  0.595476
# Node id:  91 Catchment area:  1.1194
# max ca:  0.862102
# Node id:  60 Catchment area:  0.108401
# Node id:  61 Catchment area:  0.78932
# max ca:  0.658199
# Node id:  60 Catchment area:  0.383485
# Node id:  72 Catchment area:  0.353001
# Node id:  84 Catchment area:  0.45621
# Node id:  96 Catchment area:  0.484412
# Node id:  97 Catchment area:  0.444801
# max ca:  2.57886
# Node id:  60 Catchment area:  0.581908
# Node id:  61 Catchment area:  2.24109
# max ca:  2.69466
# Node id:  60 Catchment area:  0.832912
# Node id:  59 Catchment area:  2.01961
# Node id:  69 Catchment area:  1.56412
# max ca:  0.887444
# Node id:  60 Catchment area:  0.7504
# max ca:  4.72667
# Node id:  60 Catchment area:  2.15418
# Node id:  61 Catchment area:  2.12801
# Node id:  62 Catchment area:  2.15015
# max ca:  6.23207
# Node id:  60 Catchment area:  5.84869
# max ca:  0.871612
# Node id:  60 Catchment area:  0.216536
# Node id:  59 Catchment area:  0.566425
# Node id:  58 Catchment area:  0.516625
# max ca:  1.10105
# Node id:  60 Catchment area:  0.798757
# max ca:  1.28005
# Node id:  60 Catchment area:  0.827208
# Node id:  59 Catchment area:  1.03555
# Node id:  69 Catchment area:  0.723762
# max ca:  0.317671
# Node id:  60 Catchment area:  0.135333
# Node id:  71 Catchment area:  0.136548
# Node id:  81 Catchment area:  0.177243
# Node id:  92 Catchment area:  0.199311
# Node id:  103 Catchment area:  0.317671
# max ca:  0.601885
# Node id:  60 Catchment area:  0.141127
# Node id:  71 Catchment area:  0.196706
# Node id:  82 Catchment area:  0.185336
# Node id:  93 Catchment area:  0.243747
# Node id:  104 Catchment area:  0.430839
# max ca:  0.72005
# Node id:  60 Catchment area:  0.142003
# Node id:  70 Catchment area:  0.242367
# Node id:  80 Catchment area:  0.386355
# Node id:  90 Catchment area:  0.601885
# max ca:  1.08224
# Node id:  60 Catchment area:  0.278497
# Node id:  70 Catchment area:  0.830935
# max ca:  4.0044
# Node id:  60 Catchment area:  2.09743
# max ca:  4.17211
# Node id:  60 Catchment area:  0.445525
# Node id:  71 Catchment area:  0.398015
# Node id:  82 Catchment area:  0.360824
# Node id:  93 Catchment area:  4.0044
# max ca:  4.17211
# Node id:  60 Catchment area:  0.630102
# Node id:  59 Catchment area:  0.795599
# Node id:  58 Catchment area:  2.97774
# max ca:  1.54667
# Node id:  60 Catchment area:  0.926644
# max ca:  1.03446
# Node id:  60 Catchment area:  0.251484
# Node id:  70 Catchment area:  0.688245
# Node id:  58 Catchment area:  0.76634
# Node id:  57 Catchment area:  0.753446
# max ca:  1.82051
# Node id:  60 Catchment area:  1.51371
# max ca:  4.40615
# Node id:  60 Catchment area:  2.15366
# Node id:  61 Catchment area:  2.48988
# Node id:  72 Catchment area:  2.64512
# max ca:  4.67803
# Node id:  60 Catchment area:  0.757518
# Node id:  71 Catchment area:  4.50842
# max ca:  7.00445
# Node id:  60 Catchment area:  0.959729
# Node id:  50 Catchment area:  5.70132
# max ca:  18.0871
# Node id:  60 Catchment area:  0.120529
# Node id:  70 Catchment area:  0.0985714
# Node id:  80 Catchment area:  0.103967
# Node id:  90 Catchment area:  0.121003
# Node id:  100 Catchment area:  0.185055
# max ca:  0.589517
# Node id:  60 Catchment area:  0.15684
# Node id:  49 Catchment area:  0.314861
# Node id:  37 Catchment area:  0.33744
# Node id:  26 Catchment area:  0.589517
# Node id:  14 Catchment area:  0.508561
# max ca:  2.17847
# Node id:  60 Catchment area:  1.1926
# max ca:  1.71243
# Node id:  60 Catchment area:  1.42213
# max ca:  1.27911
# Node id:  60 Catchment area:  0.561609
# Node id:  71 Catchment area:  0.637094
# Node id:  82 Catchment area:  0.648021

# %%
len(catchment_area_node_list)
# Out:
# 456

# %%
outlet_ids = np.isin(grid_nodes,catchment_area_node_list).astype('uint8')

# %%
input_d4 = gdal.Open('fann_D4_' + str(input_DEM_resolution) +  'm.tif')
D4 = np.array(input_d4.GetRasterBand(1).ReadAsArray())

input_d8 = gdal.Open('fann_D8_' + str(input_DEM_resolution) +  'm.tif')
D8 = np.array(input_d8.GetRasterBand(1).ReadAsArray())

input_dinf = gdal.Open('fann_Dinf_' + str(input_DEM_resolution) +  'm.tif')
Dinf = np.array(input_dinf.GetRasterBand(1).ReadAsArray())

input_m4 = gdal.Open('fann_M4_' + str(input_DEM_resolution) +  'm.tif')
M4 = np.array(input_m4.GetRasterBand(1).ReadAsArray())

input_m8 = gdal.Open('fann_M8_' + str(input_DEM_resolution) +  'm.tif')
M8 = np.array(input_m8.GetRasterBand(1).ReadAsArray())

# %%
D4_dict = catchmentDicts(D4, grid_nodes, catchment_area_node_list)
D8_dict = catchmentDicts(D8, grid_nodes, catchment_area_node_list)
Dinf_dict = catchmentDicts(Dinf, grid_nodes, catchment_area_node_list)
M4_dict = catchmentDicts(M4, grid_nodes, catchment_area_node_list)
M8_dict = catchmentDicts(M8, grid_nodes, catchment_area_node_list)

# %%
ds = [D4_dict, D8_dict, Dinf_dict, M4_dict, M8_dict]
d = {}
for k in D4_dict.keys():
    d[k] = tuple(d[k] for d in ds)

# %%
catchment_areas = pd.DataFrame.from_dict(d, orient='index')

# %%
catchment_areas.rename(columns={0: 'D4', 1: 'D8', 2: 'Dinf', 3: 'M4', 4: 'M8'}, inplace=True)

# %%
node_id_column = np.array(catchment_areas.index)

# %%
catchment_areas['node_id'] = node_id_column

# %%
catchment_areas.head()
# Out:
#              D4      D8      Dinf        M4        M8  node_id
# 1591954  0.5084  0.2724  0.543069  0.596238  0.346519  1591954
# 1999588  0.7520  1.3080  1.193148  1.086997  1.009500  1999588
# 2102956  0.5292  0.6620  0.597545  0.596877  0.372285  2102956
# 2282018  0.8336  0.7320  0.735737  0.761338  0.385223  2282018
# 2297890  0.4788  0.8148  0.726249  0.737846  0.663850  2297890

# %%
divergence_dict, slope_dict, slope_area_data = upstreamDrainageLine(100, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_node_list, 5, 5, 0.5, 10)
# Out:
# 5   10

# %%
len(slope_area_data)

# %%
upstream_divergence = pd.DataFrame.from_dict(divergence_dict, orient='index')

# %%
upstream_divergence.columns = ['DC']

# %%
slope_area_dataframe = pd.DataFrame.from_dict(slope_area_data, orient='index')

# %%
slope_area_dataframe.rename(columns={0: 'SA', 1: 'node_id'}, inplace=True)

# %%
slope_area_dataframe

# %%
mean_slope = pd.DataFrame.from_dict(slope_dict, orient='index')

# %%
mean_slope.columns = ['Slope']

# %%
merge_all = pd.concat([catchment_areas, upstream_divergence, mean_slope, slope_area_dataframe], axis=1, sort=False)

# %%
merge_all['Resolution'] = input_DEM_resolution

# %%
all_data_2m = merge_all

# %%
convergent_gullies = all_data_2m.loc[all_data_2m['DC'] == 0]

# %%
divergent_gullies = all_data_2m.loc[all_data_2m['DC'] == 1]

# %%
convergent_gullies['Flow'] = convergent_gullies.count()[0]

# %%
divergent_gullies['Flow'] = divergent_gullies.count()[0]

# %%
gully_types = [divergent_gullies, convergent_gullies]

# %%
data_with_counts = pd.concat(gully_types)

# %%
all_data_2m_dataframe = data_with_counts.loc[:,~data_with_counts.columns.duplicated()]

# %%
c = all_data_2m_dataframe.loc[all_data_2m_dataframe['DC'] == 0]

# %%
c_id = np.array(c['node_id'])
c_list = c_id.tolist()

# %%
d = all_data_2m_dataframe.loc[all_data_2m_dataframe['DC'] == 1]

# %%
d_id = np.array(d['node_id'])
d_list = d_id.tolist()

# %% [markdown]
# ## Setup regression training data taking the log10 of x and y so that a simple linear regression can be used to estimate the parameters k and a.

# %% [markdown]
# ## Bootstrap regression (one iteration but can be changed to two).

# %%
slope_area_montecarlo_dict = {}
method = 'M8'
gully_ids = np.array(d['node_id'])
gully_head_list = gully_ids.tolist()
sample_size = 30
whole_dataset = all_data_1m_dataframe
cooks_d_cutoff = 4 / sample_size

for i in range(0,1000):
    sample_number = 'Sample' + str(i)
    all_gully_sample = random.sample(gully_head_list, sample_size)
    all_sample_gullies = pd.DataFrame(all_gully_sample) 
    all_sample_gullies.rename(columns={0: 'node_id'}, inplace=True)
    
    all_gully_sample_set = pd.merge(all_sample_gullies, whole_dataset, on=['node_id'], how='inner')
    all_gully_sample_set['log_area'] = np.log10(all_gully_sample_set[method])
    all_gully_sample_set['log_slope'] = np.log10(all_gully_sample_set['SA'])

    m = ols('log_area ~ log_slope',all_gully_sample_set).fit()
    r_intercept = m.params[0]
    r_slope = m.params[1]
            
    above_model_line = []
    for j in range(0, len(all_gully_sample_set)):
        measured_slope = all_gully_sample_set['log_slope'].iloc[j]
        model_slope = r_slope * all_gully_sample_set['log_area'].iloc[j] + r_intercept
        if  measured_slope > model_slope:
            above_model_line.append(j)
        else:
            pass
    
    corrected_set = all_gully_sample_set.drop(above_model_line, axis='index')
 
    if len(corrected_set) < 3:
        pass
    else:
        lowest_points_m = ols('log_slope ~ log_area',corrected_set).fit()
        infl = lowest_points_m.get_influence()
        
        sm_fr = infl.summary_frame()
        if np.any(sm_fr['cooks_d'] > cooks_d_cutoff):
            high_value_list = sm_fr.index[sm_fr['cooks_d'] > cooks_d_cutoff].tolist()
            final_corrected_set = corrected_set.drop(high_value_list, axis='index')

        else:
            final_corrected_set = corrected_set
        if len(final_corrected_set) < 3:
            pass
        else:
            final_m = ols('log_slope ~ log_area',final_corrected_set).fit()
            l_intercept = final_m.params[0]
            l_slope = final_m.params[1]

            intercept = 10**l_intercept

            slope = l_slope * -1
            print(sample_number)

            slope_area_montecarlo_dict[sample_number] = ([slope, intercept])
# Out:
# Sample0
# Sample1
# Sample2
# Sample3
# Sample4
# Sample5
# Sample6
# Sample7
# Sample8
# Sample9
# Sample10
# Sample11
# Sample12
# Sample13
# Sample14
# Sample15
# Sample16
# Sample17
# Sample18
# Sample19
# Sample20
# Sample21
# Sample22
# Sample23
# Sample24
# Sample25
# Sample26
# Sample27
# Sample28
# Sample29
# Sample30
# Sample31
# Sample32
# Sample33
# Sample34
# Sample35
# Sample36
# Sample37
# Sample38
# Sample39
# Sample40
# Sample41
# Sample42
# Sample43
# Sample44
# Sample45
# Sample46
# Sample47
# Sample48
# Sample49
# Sample50
# Sample51
# Sample52
# Sample53
# Sample54
# Sample55
# Sample56
# Sample57
# Sample58
# Sample59
# Sample60
# Sample61
# Sample62
# Sample63
# Sample64
# Sample65
# Sample66
# Sample67
# Sample68
# Sample69
# Sample70
# Sample71
# Sample72
# Sample73
# Sample74
# Sample75
# Sample76
# Sample77
# Sample78
# Sample79
# Sample80
# Sample81
# Sample82
# Sample83
# Sample84
# Sample85
# Sample86
# Sample87
# Sample88
# Sample89
# Sample90
# Sample91
# Sample92
# Sample93
# Sample94
# Sample95
# Sample96
# Sample97
# Sample98
# Sample99
# Sample100
# Sample101
# Sample102
# Sample103
# Sample104
# Sample105
# Sample106
# Sample107
# Sample108
# Sample109
# Sample110
# Sample111
# Sample112
# Sample113
# Sample114
# Sample115
# Sample116
# Sample117
# Sample118
# Sample119
# Sample120
# Sample121
# Sample122
# Sample123
# Sample124
# Sample125
# Sample126
# Sample127
# Sample128
# Sample129
# Sample130
# Sample131
# Sample132
# Sample133
# Sample134
# Sample135
# Sample136
# Sample137
# Sample138
# Sample139
# Sample140
# Sample141
# Sample142
# Sample143
# Sample144
# Sample145
# Sample146
# Sample147
# Sample148
# Sample149
# Sample150
# Sample151
# Sample152
# Sample153
# Sample154
# Sample155
# Sample156
# Sample157
# Sample158
# Sample159
# Sample160
# Sample161
# Sample162
# Sample163
# Sample164
# Sample165
# Sample166
# Sample167
# Sample168
# Sample169
# Sample170
# Sample171
# Sample172
# Sample173
# Sample174
# Sample175
# Sample176
# Sample177
# Sample178
# Sample179
# Sample180
# Sample181
# Sample182
# Sample183
# Sample184
# Sample185
# Sample186
# Sample187
# Sample188
# Sample189
# Sample190
# Sample191
# Sample192
# Sample193
# Sample194
# Sample195
# Sample196
# Sample197
# Sample198
# Sample199
# Sample200
# Sample201
# Sample202
# Sample203
# Sample204
# Sample205
# Sample206
# Sample207
# Sample208
# Sample209
# Sample210
# Sample211
# Sample212
# Sample213
# Sample214
# Sample215
# Sample216
# Sample217
# Sample218
# Sample219
# Sample220
# Sample221
# Sample222
# Sample223
# Sample224
# Sample225
# Sample226
# Sample227
# Sample228
# Sample229
# Sample230
# Sample231
# Sample232
# Sample233
# Sample234
# Sample235
# Sample236
# Sample237
# Sample238
# Sample239
# Sample240
# Sample241
# Sample242
# Sample243
# Sample244
# Sample245
# Sample246
# Sample247
# Sample248
# Sample249
# Sample250
# Sample251
# Sample252
# Sample253
# Sample254
# Sample255
# Sample256
# Sample257
# Sample258
# Sample259
# Sample260
# Sample261
# Sample262
# Sample263
# Sample264
# Sample265
# Sample266
# Sample267
# Sample268
# Sample269
# Sample270
# Sample271
# Sample272
# Sample273
# Sample274
# Sample275
# Sample276
# Sample277
# Sample278
# Sample279
# Sample280
# Sample281
# Sample282
# Sample283
# Sample284
# Sample285
# Sample286
# Sample287
# Sample288
# Sample289
# Sample290
# Sample291
# Sample292
# Sample293
# Sample294
# Sample295
# Sample296
# Sample297
# Sample298
# Sample299
# Sample300
# Sample301
# Sample302
# Sample303
# Sample304
# Sample305
# Sample306
# Sample307
# Sample308
# Sample309
# Sample310
# Sample311
# Sample312
# Sample313
# Sample314
# Sample315
# Sample316
# Sample317
# Sample318
# Sample319
# Sample320
# Sample321
# Sample322
# Sample323
# Sample324
# Sample325
# Sample326
# Sample327
# Sample328
# Sample329
# Sample330
# Sample331
# Sample332
# Sample333
# Sample334
# Sample335
# Sample336
# Sample337
# Sample338
# Sample339
# Sample340
# Sample341
# Sample342
# Sample343
# Sample344
# Sample345
# Sample346
# Sample347
# Sample348
# Sample349
# Sample350
# Sample351
# Sample352
# Sample353
# Sample354
# Sample356
# Sample357
# Sample358
# Sample359
# Sample360
# Sample361
# Sample362
# Sample363
# Sample364
# Sample365
# Sample366
# Sample367
# Sample368
# Sample369
# Sample370
# Sample371
# Sample372
# Sample373
# Sample374
# Sample375
# Sample376
# Sample377
# Sample378
# Sample379
# Sample380
# Sample381
# Sample382
# Sample383
# Sample384
# Sample385
# Sample386
# Sample387
# Sample388
# Sample389
# Sample390
# Sample391
# Sample392
# Sample393
# Sample394
# Sample395
# Sample396
# Sample397
# Sample398
# Sample399
# Sample400
# Sample401
# Sample402
# Sample403
# Sample404
# Sample405
# Sample406
# Sample407
# Sample408
# Sample409
# Sample410
# Sample411
# Sample412
# Sample413
# Sample414
# Sample415
# Sample416
# Sample417
# Sample418
# Sample419
# Sample420
# Sample421
# Sample422
# Sample423
# Sample424
# Sample425
# Sample426
# Sample427
# Sample428
# Sample429
# Sample430
# Sample431
# Sample432
# Sample433
# Sample434
# Sample435
# Sample436
# Sample437
# Sample438
# Sample439
# Sample440
# Sample441
# Sample442
# Sample443
# Sample444
# Sample445
# Sample446
# Sample447
# Sample448
# Sample449
# Sample450
# Sample451
# Sample452
# Sample453
# Sample454
# Sample455
# Sample456
# Sample457
# Sample458
# Sample459
# Sample460
# Sample461
# Sample462
# Sample463
# Sample464
# Sample465
# Sample466
# Sample467
# Sample468
# Sample469
# Sample470
# Sample471
# Sample472
# Sample473
# Sample474
# Sample475
# Sample476
# Sample477
# Sample478
# Sample479
# Sample480
# Sample481
# Sample482
# Sample483
# Sample484
# Sample485
# Sample486
# Sample487
# Sample488
# Sample489
# Sample490
# Sample491
# Sample492
# Sample493
# Sample494
# Sample495
# Sample496
# Sample497
# Sample498
# Sample499
# Sample500
# Sample501
# Sample502
# Sample503
# Sample504
# Sample505
# Sample506
# Sample507
# Sample508
# Sample509
# Sample510
# Sample511
# Sample512
# Sample513
# Sample514
# Sample515
# Sample516
# Sample517
# Sample518
# Sample519
# Sample520
# Sample521
# Sample522
# Sample523
# Sample524
# Sample525
# Sample526
# Sample527
# Sample528
# Sample529
# Sample530
# Sample531
# Sample532
# Sample533
# Sample534
# Sample535
# Sample536
# Sample537
# Sample538
# Sample539
# Sample540
# Sample541
# Sample542
# Sample543
# Sample544
# Sample545
# Sample546
# Sample547
# Sample548
# Sample549
# Sample550
# Sample551
# Sample552
# Sample553
# Sample554
# Sample555
# Sample556
# Sample557
# Sample558
# Sample559
# Sample560
# Sample561
# Sample562
# Sample563
# Sample564
# Sample565
# Sample566
# Sample567
# Sample568
# Sample569
# Sample570
# Sample571
# Sample572
# Sample573
# Sample574
# Sample575
# Sample576
# Sample577
# Sample578
# Sample579
# Sample580
# Sample581
# Sample582
# Sample583
# Sample584
# Sample585
# Sample586
# Sample587
# Sample588
# Sample589
# Sample590
# Sample591
# Sample592
# Sample593
# Sample594
# Sample595
# Sample596
# Sample597
# Sample598
# Sample599
# Sample600
# Sample601
# Sample602
# Sample603
# Sample604
# Sample605
# Sample606
# Sample607
# Sample608
# Sample609
# Sample610
# Sample611
# Sample612
# Sample613
# Sample614
# Sample615
# Sample616
# Sample617
# Sample618
# Sample619
# Sample620
# Sample621
# Sample622
# Sample623
# Sample624
# Sample625
# Sample626
# Sample627
# Sample628
# Sample629
# Sample630
# Sample631
# Sample632
# Sample633
# Sample634
# Sample635
# Sample636
# Sample637
# Sample638
# Sample639
# Sample640
# Sample641
# Sample642
# Sample643
# Sample644
# Sample645
# Sample646
# Sample647
# Sample648
# Sample649
# Sample650
# Sample651
# Sample652
# Sample653
# Sample654
# Sample655
# Sample656
# Sample657
# Sample658
# Sample659
# Sample660
# Sample661
# Sample662
# Sample663
# Sample664
# Sample665
# Sample666
# Sample667
# Sample668
# Sample669
# Sample670
# Sample671
# Sample672
# Sample673
# Sample674
# Sample675
# Sample676
# Sample677
# Sample678
# Sample679
# Sample680
# Sample681
# Sample682
# Sample683
# Sample684
# Sample685
# Sample686
# Sample687
# Sample688
# Sample689
# Sample690
# Sample691
# Sample692
# Sample693
# Sample694
# Sample695
# Sample696
# Sample697
# Sample698
# Sample699
# Sample700
# Sample701
# Sample702
# Sample703
# Sample704
# Sample705
# Sample706
# Sample707
# Sample708
# Sample709
# Sample710
# Sample711
# Sample712
# Sample713
# Sample714
# Sample715
# Sample716
# Sample717
# Sample718
# Sample719
# Sample720
# Sample721
# Sample722
# Sample723
# Sample724
# Sample725
# Sample726
# Sample727
# Sample728
# Sample729
# Sample730
# Sample731
# Sample732
# Sample733
# Sample734
# Sample735
# Sample736
# Sample737
# Sample738
# Sample739
# Sample740
# Sample741
# Sample742
# Sample743
# Sample744
# Sample745
# Sample746
# Sample747
# Sample748
# Sample749
# Sample750
# Sample751
# Sample752
# Sample753
# Sample754
# Sample755
# Sample756
# Sample757
# Sample758
# Sample759
# Sample760
# Sample761
# Sample762
# Sample763
# Sample764
# Sample765
# Sample766
# Sample767
# Sample768
# Sample769
# Sample770
# Sample771
# Sample772
# Sample773
# Sample774
# Sample775
# Sample776
# Sample777
# Sample778
# Sample779
# Sample780
# Sample781
# Sample782
# Sample783
# Sample784
# Sample785
# Sample786
# Sample787
# Sample788
# Sample789
# Sample790
# Sample791
# Sample792
# Sample793
# Sample794
# Sample795
# Sample796
# Sample797
# Sample798
# Sample799
# Sample800
# Sample801
# Sample802
# Sample803
# Sample804
# Sample805
# Sample806
# Sample807
# Sample808
# Sample809
# Sample810
# Sample811
# Sample812
# Sample813
# Sample814
# Sample815
# Sample816
# Sample817
# Sample818
# Sample819
# Sample820
# Sample821
# Sample822
# Sample823
# Sample824
# Sample825
# Sample826
# Sample827
# Sample828
# Sample829
# Sample830
# Sample831
# Sample832
# Sample833
# Sample834
# Sample835
# Sample836
# Sample837
# Sample838
# Sample839
# Sample840
# Sample841
# Sample842
# Sample843
# Sample844
# Sample845
# Sample846
# Sample847
# Sample848
# Sample849
# Sample850
# Sample851
# Sample852
# Sample853
# Sample854
# Sample855
# Sample856
# Sample857
# Sample858
# Sample859
# Sample860
# Sample861
# Sample862
# Sample863
# Sample864
# Sample865
# Sample866
# Sample867
# Sample868
# Sample869
# Sample870
# Sample871
# Sample872
# Sample873
# Sample874
# Sample875
# Sample876
# Sample877
# Sample878
# Sample879
# Sample880
# Sample881
# Sample882
# Sample883
# Sample884
# Sample885
# Sample886
# Sample887
# Sample888
# Sample889
# Sample890
# Sample891
# Sample892
# Sample893
# Sample894
# Sample895
# Sample896
# Sample897
# Sample898
# Sample899
# Sample900
# Sample901
# Sample902
# Sample903
# Sample904
# Sample905
# Sample906
# Sample907
# Sample908
# Sample909
# Sample910
# Sample911
# Sample912
# Sample913
# Sample914
# Sample915
# Sample916
# Sample917
# Sample918
# Sample919
# Sample920
# Sample921
# Sample922
# Sample923
# Sample925
# Sample926
# Sample927
# Sample928
# Sample929
# Sample930
# Sample931
# Sample932
# Sample933
# Sample934
# Sample935
# Sample936
# Sample937
# Sample938
# Sample939
# Sample940
# Sample941
# Sample942
# Sample943
# Sample944
# Sample945
# Sample946
# Sample947
# Sample948
# Sample949
# Sample950
# Sample951
# Sample952
# Sample953
# Sample954
# Sample955
# Sample956
# Sample957
# Sample958
# Sample959
# Sample960
# Sample961
# Sample962
# Sample963
# Sample964
# Sample965
# Sample966
# Sample967
# Sample968
# Sample969
# Sample970
# Sample971
# Sample972
# Sample973
# Sample974
# Sample975
# Sample976
# Sample977
# Sample978
# Sample979
# Sample980
# Sample981
# Sample982
# Sample983
# Sample984
# Sample985
# Sample986
# Sample987
# Sample988
# Sample989
# Sample990
# Sample991
# Sample992
# Sample993
# Sample994
# Sample995
# Sample996
# Sample997
# Sample998
# Sample999

# %%
div_curve = pd.DataFrame.from_dict(slope_area_montecarlo_dict, orient='index')

# %%
div_k_exclusion = []
for index, row in div_curve.iterrows():
    if row[1] > 1:
        print('index: ',index, 'value: ', (row[1]))
        div_k_exclusion.append(index)

div_b_exclusion = []
for index, row in div_curve.iterrows():
    if row[0] > 1:
        print('index: ',index, 'value: ', (row[0]))
        div_b_exclusion.append(index)
# Out:
# index:  Sample165 value:  1.34711428213
# index:  Sample432 value:  1.11043471546
# index:  Sample546 value:  1.26541047504
# index:  Sample806 value:  1.22093646568
# index:  Sample856 value:  1.81495733409

# %%
corrected_div_k = div_curve[1].drop(div_k_exclusion, axis='index')
corrected_div_b = div_curve[0].drop(div_b_exclusion, axis='index')

# %%
mean_div = np.round(np.mean(div_curve[0]),5)
div_standard_error = np.round(sem(div_curve[0]),5)
mean_div_int = np.round(np.mean(div_curve[1]),5)
div_standard_error_int = np.round(sem(div_curve[1]),5)
standard_deviation_divergent = np.std(np.array(corrected_div_b))
standard_deviation_divergent_int = np.std(np.array(corrected_div_k))

# %%
conv_curve = pd.DataFrame.from_dict(slope_area_montecarlo_dict, orient='index')

# %%
conv_k_exclusion = []
for index, row in conv_curve.iterrows():
    if row[1] > 1:
        conv_k_exclusion.append(index)
        
conv_b_exclusion = []
for index, row in conv_curve.iterrows():
    if row[0] > 1:
        conv_b_exclusion.append(index)

# %%
corrected_conv_k = conv_curve[1].drop(conv_k_exclusion, axis='index')
corrected_conv_b = conv_curve[0].drop(conv_b_exclusion, axis='index')

# %%
mean_conv = np.round(np.mean(conv_curve[0]),5)
conv_standard_error = np.round(sem(conv_curve[0]),5)
mean_conv_int = np.round(np.mean(conv_curve[1]),5)
conv_standard_error_int = np.round(sem(conv_curve[1]),5)
standard_deviation_convergent = np.std(np.array(corrected_conv_b))
standard_deviation_convergent_int = np.std(np.array(corrected_conv_k))

# %%
variance_over_df_conv_b = (np.std(np.array(conv_curve[0]))**2) / len(c_list)
variance_over_df_div_b = (np.std(np.array(div_curve[0]))**2) / len(d_list)
variance_over_df_conv_k = (np.std(np.array(conv_curve[1]))**2) / len(c_list)
variance_over_df_div_k = (np.std(np.array(div_curve[1]))**2) / len(d_list)
denominator_b = np.sqrt(variance_over_df_conv_b + variance_over_df_div_b)
denominator_k = np.sqrt(variance_over_df_conv_k + variance_over_df_div_k)
numerator_b = mean_conv - mean_div
numerator_k = mean_conv_int - mean_div_int
t_value_b = numerator_b / denominator_b
t_value_k = numerator_k / denominator_k

# %%
print('div stdev b: ', standard_deviation_divergent)
print('div stdev k: ', standard_deviation_divergent_int)
print('conv stdev b: ', standard_deviation_convergent)
print('conv stdev k: ', standard_deviation_convergent_int)
# Out:
# div stdev b:  0.159388433705
# div stdev k:  0.0042523313415
# conv stdev b:  0.159388433705
# conv stdev k:  0.0042523313415

# %%
degrees_of_freedom = np.min([len(c_list), len(d_list)]) - 1

# %%
degrees_of_freedom
# Out:
# 222

# %%
test_of_significance_b = t.sf(t_value_b, degrees_of_freedom) * 2
test_of_significance_k = t.sf(t_value_k, degrees_of_freedom) * 2
print('Significant difference b: ', test_of_significance_b)
print('Significant difference k: ', test_of_significance_k)
# Out:
# Significant difference b:  1.0
# Significant difference k:  1.0

# %%
if test_of_significance_b < 0.0005:
    b_significance = '(***)'
elif test_of_significance_b < 0.005:
    b_significance = '(**)'
elif test_of_significance_b < 0.05:
    b_significance = '(*)'
else:
    b_significance= '(ns)'

# %%
if test_of_significance_k < 0.0005:
    k_significance = '(***)'
elif test_of_significance_k < 0.005:
    k_significance = '(**)'
elif test_of_significance_k < 0.05:
    k_significance = '(*)'
else:
    k_significance = '(ns)'

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (8, 5))
sns.distplot(corrected_conv_b, color = 'xkcd:royal blue', kde = False, hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 0.8}, bins = 600)
ax1.set_ylabel('Count', fontsize=20)
#ax1.lines[0].set_linestyle("--")
ax1.set_ylim(0, 1000)
ax1.set_xlabel(str(method) + ' estimate of exponent (b)', fontsize = 20)
ax1.legend(['Convergent: $\mu$ = '+str(np.round(mean_conv,3))+' $\pm$'+str(np.round(conv_standard_error,3))],
           bbox_to_anchor=(0.5, 0.6, 0.5, 0.4),fontsize = 14)
ax1.set_xlim(-0.2, 1)
ax2 = ax1.twinx()
ax2.set_ylim(0, 1000)
ax2.set_xlim(-0.2, 1)
ax2.axes.yaxis.set_visible(False)
sns.distplot(corrected_div_b,  color='xkcd:burnt orange', kde = False,hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 0.8}, bins = 600)
#ax2.set_ylabel('PC (rad / 100m)', fontsize = 15)
ax2.legend(['Divergent: $\mu$ = '+str(np.round(mean_div,3))+' $\pm$'+str(np.round(div_standard_error,3))],
           bbox_to_anchor=(0.5, 0.47, 0.5, 0.4),fontsize = 14)
plt.axvline(x=mean_div, linewidth=1, color = 'xkcd:burnt orange', alpha = 1, linestyle = '--')
plt.axvline(x=mean_conv, linewidth=1, color = 'xkcd:royal blue', alpha = 1, linestyle = '--')
ax1.text(0.59, 650, r'$H_0$: $\mu_{conv}$  $\neq$ $\mu_{div}$ ' + b_significance, fontsize=15, rotation = 0)

#plt.title('Estimate of exponent (b)', fontsize = 12)
# Out:
# Text(0.59, 650, '$H_0$: $\\mu_{conv}$  $\\neq$ $\\mu_{div}$ (ns)')

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (8, 5))
sns.distplot(corrected_conv_k, color = 'xkcd:royal blue', kde = False, hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 0.8}, bins = 400)
ax1.set_ylabel('Count', fontsize=20)
#ax1.lines[0].set_linestyle("--")
ax1.set_ylim(0, 1000)
ax1.set_xlabel(str(method) + ' estimate of threshold coefficient (k)', fontsize = 20)
ax1.legend(['Convergent: $\mu$ = '+str(np.round(mean_conv_int, 3))+' $\pm$'+str(np.round(conv_standard_error_int, 3))],
           bbox_to_anchor=(0.5, 0.6, 0.5, 0.4),fontsize = 14)
ax1.set_xlim(0, .1)
ax2 = ax1.twinx()
ax2.set_ylim(0, 1000)
ax2.set_xlim(0, .1)
ax2.axes.yaxis.set_visible(False)
sns.distplot(corrected_div_k,  color='xkcd:burnt orange', kde = False,hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 0.8}, bins = 900)
#ax2.set_ylabel('PC (rad / 100m)', fontsize = 15)
ax2.legend(['Divergent: $\mu$ = '+str(np.round(mean_div_int,3))+' $\pm$'+str(np.round(div_standard_error_int, 3))],
           bbox_to_anchor=(0.5, 0.47, 0.5, 0.4),fontsize = 14)
plt.axvline(x=mean_div_int, linewidth=1, color = 'xkcd:burnt orange', alpha = 1, linestyle = '--')
plt.axvline(x=mean_conv_int, linewidth=1, color = 'xkcd:royal blue', alpha = 1, linestyle = '--')
ax1.text(0.065, 650, r'$H_0$: $\mu_{conv}$  $\neq$ $\mu_{div}$ '+ k_significance, fontsize=15, rotation = 0)
#plt.title('Estimate of exponent (b)', fontsize = 12)
# Out:
# Text(0.065, 650, '$H_0$: $\\mu_{conv}$  $\\neq$ $\\mu_{div}$ (ns)')

# %%
np.round(div_standard_error_int, 4)
# Out:
# 0.0001

# %%
#divergent_gully = random.choice(d_list)
divergent_gully = 62358126
divergent_gully_2 = 61694828
gully_sample = random.sample(c_list, 20)
gully_sample.append(divergent_gully)
gully_sample.append(divergent_gully_2)
sample_gullies = pd.DataFrame(gully_sample) 
sample_gullies.rename(columns={0: 'node_id'}, inplace=True)
gully_sample_set = pd.merge(sample_gullies, all_data_1m_dataframe, on=['node_id'], how='inner')

# %%
gully_sample_set['DC'].iloc[21] = 2
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
method = 'M4'

# %%
gully_sample_set['log_area'] = np.log10(gully_sample_set[method])
gully_sample_set['log_slope'] = np.log10(gully_sample_set['SA'])
test_m = ols('log_slope ~ log_area',gully_sample_set).fit()
test_intercept = test_m.params[0]
test_slope = test_m.params[1]

# %%
above_model_line = []
for i in range(0, len(gully_sample_set)):
    measured_slope = gully_sample_set['log_slope'].iloc[i]
    model_slope = test_slope * gully_sample_set['log_area'].iloc[i] + test_intercept
    if  measured_slope > model_slope:
        above_model_line.append(i)
    else:
        pass

# %%
corrected_set = gully_sample_set.drop(above_model_line, axis='index')

# %%
lowest_points_m = ols('log_slope ~ log_area',corrected_set).fit()
l_intercept = lowest_points_m.params[0]
l_slope = lowest_points_m.params[1]

# %%
index_position_list = []
for index, row in corrected_set.iterrows():
    index_position_list.append(index)

# %%
above_second_model_line = []
for i in range(0, len(corrected_set)):
    measured_slope = corrected_set['log_slope'].iloc[i]
    model_slope = l_slope * corrected_set['log_area'].iloc[i] + l_intercept
    if  measured_slope > model_slope:
        above_second_model_line.append(index_position_list[i])
    else:
        pass

# %%
corrected_set_2 = corrected_set.drop(above_second_model_line, axis='index')

# %%
corrected_set_2
# Out:
#      node_id      D4      D8      Dinf        M4        M8  DC     Slope  \
# 4   19773222  0.5414  0.4586  0.548668  0.563276  0.391804   0  0.038368
# 8   11990044  1.8907  1.4418  1.505202  1.656440  1.097853   0  0.042033
# 13  15042582  0.4758  0.9800  1.097947  0.525898  0.770192   0  0.049103
# 14  20469523  0.2345  0.3500  0.323861  0.262384  0.277183   0  0.042840
# 15  26245796  2.9624  4.1559  4.250717  4.128208  3.931495   0  0.012479
# 16   9554350  0.6048  0.4195  0.383138  0.443018  0.425322   0  0.047751
#
#           SA  Resolution  Flow  log_area  log_slope
# 4   0.029852           1   223 -0.249279  -1.525030
# 8   0.011064           1   223  0.219176  -1.956075
# 13  0.028624           1   223 -0.279098  -1.543276
# 14  0.045827           1   223 -0.581063  -1.338879
# 15  0.007911           1   223  0.615762  -2.101745
# 16  0.033654           1   223 -0.353579  -1.472957

# %% [markdown]
# ## Write the estimated slope and intercept parameters to variables.
# Note: The returned intercept will be in log10(a) form so we need to take the exponential $10^{k}$ to get back to the non-log10 value of the assumed function $s \geq kA^{-b}$.

# %%
second_lowest_points_m = ols('log_slope ~ log_area',corrected_set_2).fit()
sl_intercept = second_lowest_points_m.params[0]
sl_slope = second_lowest_points_m.params[1]

# %%
print('All data intercept: ', 10**test_intercept)
print('All data slope: ', test_slope * -1)
# Out:
# All data intercept:  0.03227575147
# All data slope:  0.379332748384

# %%
print('Lowest data intercept: ', 10**l_intercept)
print('Lowest data slope: ', l_slope * -1)
# Out:
# Lowest data intercept:  0.0226863224931
# Lowest data slope:  0.484818279994

# %%
print('Second lowest data intercept: ', 10**sl_intercept)
print('Second lowest data slope: ', sl_slope * -1)
# Out:
# Second lowest data intercept:  0.0204144012354
# Second lowest data slope:  0.448027693454

# %% [markdown]
# ## Second model can either be l_slope or sl_slope.

# %%
generate_area_values = np.arange(0.2, 10, 0.00001)
model_slope = (10**test_intercept) * generate_area_values**(test_slope)
model_slope_alt = (10**sl_intercept) * generate_area_values**(sl_slope)
df_model_area = pd.DataFrame(generate_area_values)
df_model_area.rename(columns={0: method}, inplace=True)

# %% [markdown]
# ## Reshape the slope array so we can put it into a pandas dataframe.

# %%
reshaped_model_slope = model_slope.reshape(-1,1)
df_model_slope = pd.DataFrame(reshaped_model_slope)
df_model_slope.rename(columns={0: 'SA'}, inplace=True)
df_model = pd.concat([df_model_slope, df_model_area], axis=1, sort=False)
df_model['DC'] = 3

# %%
reshaped_model_slope_alt = model_slope_alt.reshape(-1,1)
df_model_slope_alt = pd.DataFrame(reshaped_model_slope_alt)
df_model_slope_alt.rename(columns={0: 'SA'}, inplace=True)
df_model_alt = pd.concat([df_model_slope_alt, df_model_area], axis=1, sort=False)
df_model_alt['DC'] = 4

# %%
gully_sample_set['Size'] = 1000
df_model['Size'] = 1
df_model_alt['Size'] = 1
df_all_1 = df_model.append(df_model_alt)
df_all_2 = df_all_1.append(gully_sample_set)

# %%
gully_sample_set
# Out:
#      node_id      D4      D8      Dinf        M4        M8  DC     Slope  \
# 0   16220664  0.1995  0.3686  0.403715  0.291498  0.318233   0  0.048709
# 1   25124277  0.6461  0.6177  0.652118  0.662310  0.642413   0  0.044021
# 2   29212508  0.0751  1.9215  1.235804  0.675020  0.523530   0  0.040467
# 3   19818369  0.4804  0.2123  0.266725  0.295278  0.253618   0  0.043905
# 4   39065506  0.4803  0.5375  0.723522  0.880631  0.808729   0  0.032697
# 5   30180099  0.1665  0.2141  0.172060  0.170093  0.267787   0  0.035109
# 6   25209505  0.9121  0.3345  0.319888  0.414416  0.379147   0  0.041142
# 7   16337765  0.9722  0.5060  0.510846  0.571189  0.533762   0  0.050517
# 8   28277398  0.0375  0.9085  0.862621  0.456927  0.523668   0  0.049789
# 9   23207073  1.3072  1.4257  1.438698  1.443556  0.931692   0  0.044552
# 10  48539817  0.5418  0.3724  0.389620  0.232920  0.400515   0  0.038412
# 11  52018612  1.1442  0.0636  0.134750  1.178811  1.186514   0  0.040352
# 12  21839390  0.2966  0.1082  0.188251  0.295864  0.270312   0  0.031485
# 13  33802785  0.4316  1.1001  1.039734  0.723608  0.442023   0  0.029756
# 14  19187086  0.4152  1.2226  1.054630  0.738585  0.892290   0  0.047220
# 15  27083193  3.6396  2.4946  2.216100  2.660927  2.131098   0  0.053712
# 16  50746769  0.3924  0.7880  0.755605  0.650614  0.525184   0  0.021006
# 17  52007747  0.1275  1.8609  3.054549  0.663644  1.131070   0  0.037095
# 18  51391096  0.6098  0.8669  0.583436  0.740520  0.663911   0  0.049684
# 19  34897377  1.3565  1.3895  1.329326  1.333900  1.104801   0  0.051511
# 20  62358126  6.8406  6.8139  7.328270  4.734601  6.335984   1  0.040167
# 21  61694828  0.3509  0.2872  0.287591  3.441643  1.500452   2  0.032520
#
#           SA  Resolution  Flow  log_area  log_slope  Size
# 0   0.044548           1   223 -0.535364  -1.351168  1000
# 1   0.053263           1   223 -0.178939  -1.273573  1000
# 2   0.035167           1   223 -0.170683  -1.453870  1000
# 3   0.095669           1   223 -0.529769  -1.019231  1000
# 4   0.044452           1   223 -0.055206  -1.352110  1000
# 5   0.045367           1   223 -0.769314  -1.343261  1000
# 6   0.082503           1   223 -0.382563  -1.083532  1000
# 7   0.031976           1   223 -0.243220  -1.495176  1000
# 8   0.037359           1   223 -0.340153  -1.427608  1000
# 9   0.050934           1   223  0.159434  -1.292991  1000
# 10  0.060203           1   223 -0.632792  -1.220383  1000
# 11  0.019355           1   223  0.071444  -1.713216  1000
# 12  0.031525           1   223 -0.528908  -1.501352  1000
# 13  0.034842           1   223 -0.140497  -1.457900  1000
# 14  0.056619           1   223 -0.131599  -1.247038  1000
# 15  0.013092           1   223  0.425033  -1.883004  1000
# 16  0.027917           1   223 -0.186677  -1.554128  1000
# 17  0.037840           1   223 -0.178065  -1.422047  1000
# 18  0.023924           1   223 -0.130463  -1.621170  1000
# 19  0.036340           1   223  0.125123  -1.439614  1000
# 20  0.031095           1   259  0.675283  -1.507310  1000
# 21  0.011130           1   259  0.536766  -1.953507  1000

# %%
df_all_2
# Out:
#           SA        M4  DC  Size     node_id      D4      D8      Dinf  \
# 0   0.059432  0.200000   3     1         NaN     NaN     NaN       NaN
# 1   0.059431  0.200010   3     1         NaN     NaN     NaN       NaN
# 2   0.059430  0.200020   3     1         NaN     NaN     NaN       NaN
# 3   0.059428  0.200030   3     1         NaN     NaN     NaN       NaN
# 4   0.059427  0.200040   3     1         NaN     NaN     NaN       NaN
# ..       ...       ...  ..   ...         ...     ...     ...       ...
# 17  0.037840  0.663644   0  1000  52007747.0  0.1275  1.8609  3.054549
# 18  0.023924  0.740520   0  1000  51391096.0  0.6098  0.8669  0.583436
# 19  0.036340  1.333900   0  1000  34897377.0  1.3565  1.3895  1.329326
# 20  0.031095  4.734601   1  1000  62358126.0  6.8406  6.8139  7.328270
# 21  0.011130  3.441643   2  1000  61694828.0  0.3509  0.2872  0.287591
#
#           M8     Slope  Resolution   Flow  log_area  log_slope
# 0        NaN       NaN         NaN    NaN       NaN        NaN
# 1        NaN       NaN         NaN    NaN       NaN        NaN
# 2        NaN       NaN         NaN    NaN       NaN        NaN
# 3        NaN       NaN         NaN    NaN       NaN        NaN
# 4        NaN       NaN         NaN    NaN       NaN        NaN
# ..       ...       ...         ...    ...       ...        ...
# 17  1.131070  0.037095         1.0  223.0 -0.178065  -1.422047
# 18  0.663911  0.049684         1.0  223.0 -0.130463  -1.621170
# 19  1.104801  0.051511         1.0  223.0  0.125123  -1.439614
# 20  6.335984  0.040167         1.0  259.0  0.675283  -1.507310
# 21  1.500452  0.032520         1.0  259.0  0.536766  -1.953507
#
# [1960022 rows x 14 columns]

# %%
sns.set_style('whitegrid', {'grid.linestyle': '--'})
data = df_all_2
colours = {0:'xkcd:ultramarine', 1:'xkcd:orange', 2:'xkcd:scarlet', 3:'xkcd:black', 4:'xkcd:forest green'}
x_axis = method
x_axis_label = x_axis + ' Area (ha)'
y_axis = 'SA'
fig = sns.relplot(x=x_axis, y=y_axis,  palette = colours, hue = 'DC', 
                 data=data, alpha = 0.8, legend = False, edgecolor="k", 
                  style = 'DC', size = 'Size', sizes = (0.1,100), markers =['^','s', 'o', '.', '.'])

ax = fig.axes[0,0]

ax.set_xlabel(x_axis, fontsize = 20)
ax.set_ylabel(y_axis, fontsize = 20)

fig.set(xlim = (0.1, 20))
fig.set(ylim = (0.001, 0.2))

leg = fig._legend
plt.rcParams["axes.edgecolor"] = "0.15"

g1 = Line2D([], [], color='xkcd:orange', marker='s', linestyle='None',
                          markersize=15, label='Gully head 1 (divergent)')

rs = Line2D([], [], color='xkcd:royal blue', marker='^', linestyle='None',
                          markersize=15, label='Random sample (convergent)')

g2 = Line2D([], [], color='xkcd:scarlet', marker='o', linestyle='None',
                          markersize=15, label='Gully head 2 (divergent)')

#ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel(x_axis_label, fontsize = 15)
ax.set_ylabel(('Slope (m$\cdot$m$^{-1}$)'), fontsize = 15)

plt.legend(bbox_to_anchor=(1.05, 1),  borderaxespad=0.,fontsize='12')
plt.setp(ax.get_legend().get_title(), fontsize='12') # for legend title
plt.legend(handles=[rs, g1, g2],fontsize=13, loc=3)

ax.text(0.12, 0.005,'k = ' + str(np.round(10**sl_intercept, 2)), fontsize=15) 
ax.text(0.12, 0.004,'b = ' + str(np.round(sl_slope*-1, 2)), fontsize=15)  

ax.set_xscale('log')
ax.set_yscale('log')
fig.fig.set_size_inches(5,5)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## End of this section. Below is stuff that I think is duplicated in other notebooks.

# %%
fig, ax = plt.subplots(figsize = (8, 8))
g0 = sns.scatterplot(x="M8", y="SA", marker = 'x', edgecolor= 'xkcd:royal blue', legend = False, 
                     linewidth = 1,data=gsc)
g1 = sns.scatterplot(x="M8", y="SA", marker = 'o',alpha=0.4, color='xkcd:orange', edgecolor= 'xkcd:black', 
                     linewidth = 1, data=gsd, s = 60, legend = False)
g2 = sns.scatterplot(x="D8", y="SA", marker = 'D',alpha=0.4, color='xkcd:merlot', edgecolor= 'xkcd:black', 
                     linewidth = 1, data=gsd, s = 60, legend = False)
g2 = sns.scatterplot(x="D8", y="SA", marker = 'D',alpha=0.4, color='xkcd:merlot', edgecolor= 'xkcd:black', 
                     linewidth = 1, data=gsd, s = 60, legend = False)
g2 = sns.scatterplot(x="D8", y="SA", marker = 'D',alpha=0.4, color='xkcd:merlot', edgecolor= 'xkcd:black', 
                     linewidth = 1, data=gsd, s = 60, legend = False)
g2 = sns.scatterplot(x="D8", y="SA", marker = 'D',alpha=0.4, color='xkcd:merlot', edgecolor= 'xkcd:black', 
                     linewidth = 1, data=gsd, s = 60, legend = False)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = '',fontsize='15')
plt.setp(ax.get_legend().get_title(), fontsize='15') # for legend title
#plt.plot([0, 10], [0, 10], linestyle='--', color = 'xkcd:apricot')
#ax.set_ylim(-0.1,2)
#ax.set_xlim(-0.1,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-4ddc997dc59a> in <module>
#       1 fig, ax = plt.subplots(figsize = (8, 8))
#       2 g0 = sns.scatterplot(x="M8", y="SA", marker = 'x', edgecolor= 'xkcd:royal blue', legend = False,
# ----> 3                      linewidth = 1,data=gsc)
#       4 g1 = sns.scatterplot(x="M8", y="SA", marker = 'o',alpha=0.4, color='xkcd:orange', edgecolor= 'xkcd:black',
#       5                      linewidth = 1, data=gsd, s = 60, legend = False)
#
# NameError: name 'gsc' is not defined

# %%
corr_1m_divergent = all_data_1m.loc[(all_data_1m['DC'] == 1)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
corr_1m_convergent = all_data_1m.loc[(all_data_1m['DC'] == 0)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()

corr_2m_divergent = all_data_2m.loc[(all_data_2m['DC'] == 1)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
corr_2m_convergent = all_data_2m.loc[(all_data_2m['DC'] == 0)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()

corr_3m_divergent = all_data_3m.loc[(all_data_3m['DC'] == 1)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
corr_3m_convergent = all_data_3m.loc[(all_data_3m['DC'] == 0)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()

corr_4m_divergent = all_data_4m.loc[(all_data_4m['DC'] == 1)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
corr_4m_convergent = all_data_4m.loc[(all_data_4m['DC'] == 0)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()

corr_5m_divergent = all_data_5m.loc[(all_data_5m['DC'] == 1)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
corr_5m_convergent = all_data_5m.loc[(all_data_5m['DC'] == 0)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-3eaa7038b779> in <module>
#       2 corr_1m_convergent = all_data_1m.loc[(all_data_1m['DC'] == 0)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
#       3
# ----> 4 corr_2m_divergent = all_data_2m.loc[(all_data_2m['DC'] == 1)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
#       5 corr_2m_convergent = all_data_2m.loc[(all_data_2m['DC'] == 0)].drop(columns = ['node_id', 'DC', 'Slope', 'Resolution']).corr()
#       6
#
# NameError: name 'all_data_2m' is not defined

# %%
corr_1m_divergent
# Out:
#             D4        D8      Dinf        M4        M8        SA
# D4    1.000000  0.561744  0.476232  0.920948  0.711853 -0.061860
# D8    0.561744  1.000000  0.962689  0.634685  0.728168 -0.044816
# Dinf  0.476232  0.962689  1.000000  0.585034  0.770414 -0.047999
# M4    0.920948  0.634685  0.585034  1.000000  0.852839 -0.071035
# M8    0.711853  0.728168  0.770414  0.852839  1.000000 -0.084463
# SA   -0.061860 -0.044816 -0.047999 -0.071035 -0.084463  1.000000

# %%
corr_1m_convergent
# Out:
#             D4        D8      Dinf        M4        M8        SA
# D4    1.000000  0.836853  0.838524  0.939502  0.820455  0.080459
# D8    0.836853  1.000000  0.995597  0.933564  0.979784 -0.004036
# Dinf  0.838524  0.995597  1.000000  0.935794  0.984131  0.009722
# M4    0.939502  0.933564  0.935794  1.000000  0.921194  0.061545
# M8    0.820455  0.979784  0.984131  0.921194  1.000000  0.049680
# SA    0.080459 -0.004036  0.009722  0.061545  0.049680  1.000000

# %%
corr_2m_divergent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-1dc333b340bd> in <module>
# ----> 1 corr_2m_divergent
#
# NameError: name 'corr_2m_divergent' is not defined

# %%
corr_1m_convergent
# Out:
#             D4        D8      Dinf        M4        M8        SA
# D4    1.000000  0.836853  0.838524  0.939502  0.820455  0.080459
# D8    0.836853  1.000000  0.995597  0.933564  0.979784 -0.004036
# Dinf  0.838524  0.995597  1.000000  0.935794  0.984131  0.009722
# M4    0.939502  0.933564  0.935794  1.000000  0.921194  0.061545
# M8    0.820455  0.979784  0.984131  0.921194  1.000000  0.049680
# SA    0.080459 -0.004036  0.009722  0.061545  0.049680  1.000000

# %%
sns.set(style = 'ticks')

data = corr_1m_convergent

mask = np.triu(np.ones_like(data, dtype=np.bool))

comparison = sns.heatmap(data, xticklabels=data.columns, mask=mask,
                         yticklabels=data.columns, annot = True,
            cmap=sns.diverging_palette(220, 10, as_cmap=True), vmin = 0.5, vmax = 1, linecolor = 'white', linewidths = 3)

comparison.set_xticklabels(comparison.get_xticklabels(), rotation=45)
comparison.set_yticklabels(comparison.get_yticklabels(), rotation=0)
# Out:
# [Text(0, 0.5, 'D4'),
#  Text(0, 1.5, 'D8'),
#  Text(0, 2.5, 'Dinf'),
#  Text(0, 3.5, 'M4'),
#  Text(0, 4.5, 'M8'),
#  Text(0, 5.5, 'SA')]

# %%
sns.set(style = 'ticks')

data = corr_1m_divergent

mask = np.triu(np.ones_like(data, dtype=np.bool))

comparison = sns.heatmap(data, xticklabels=data.columns, mask=mask,
                         yticklabels=data.columns, annot = True,
            cmap=sns.diverging_palette(220, 10, as_cmap=True), vmin = 0.5, vmax = 1, linecolor = 'white', linewidths = 3)

comparison.set_xticklabels(comparison.get_xticklabels(), rotation=45)
comparison.set_yticklabels(comparison.get_yticklabels(), rotation=0)
# Out:
# [Text(0, 0.5, 'D4'),
#  Text(0, 1.5, 'D8'),
#  Text(0, 2.5, 'Dinf'),
#  Text(0, 3.5, 'M4'),
#  Text(0, 4.5, 'M8'),
#  Text(0, 5.5, 'SA')]

# %%
correlation_dict_convergent = {}
correlation_dict_divergent = {}

# %%
correlation_dict_convergent['D4-M8'] = [corr_1m_convergent.iloc[4,0], 
                             corr_2m_convergent.iloc[4,0], corr_3m_convergent.iloc[4,0], 
                             corr_4m_convergent.iloc[4,0], corr_5m_convergent.iloc[4,0]]

correlation_dict_convergent['D8-M8'] = [corr_1m_convergent.iloc[4,1], 
                             corr_2m_convergent.iloc[4,1], corr_3m_convergent.iloc[4,1], 
                             corr_4m_convergent.iloc[4,1], corr_5m_convergent.iloc[4,1]]

correlation_dict_convergent['Dinf-M8'] = [corr_1m_convergent.iloc[4,2], 
                               corr_2m_convergent.iloc[4,2], corr_3m_convergent.iloc[4,2], 
                               corr_4m_convergent.iloc[4,2], corr_5m_convergent.iloc[4,2]]
correlation_dict_convergent['M4-M8'] = [corr_1m_convergent.iloc[4,3], 
                             corr_2m_convergent.iloc[4,3], corr_3m_convergent.iloc[4,3], 
                             corr_4m_convergent.iloc[4,3], corr_5m_convergent.iloc[4,3]]

correlation_dict_divergent['D4-M8'] = [corr_1m_divergent.iloc[4,0], 
                             corr_2m_divergent.iloc[4,0], corr_3m_divergent.iloc[4,0], 
                             corr_4m_divergent.iloc[4,0], corr_5m_divergent.iloc[4,0]]

correlation_dict_divergent['D8-M8'] = [corr_1m_divergent.iloc[4,1], 
                             corr_2m_divergent.iloc[4,1], corr_3m_divergent.iloc[4,1], 
                             corr_4m_divergent.iloc[4,1], corr_5m_divergent.iloc[4,1]]

correlation_dict_divergent['Dinf-M8'] = [corr_1m_divergent.iloc[4,2], 
                               corr_2m_divergent.iloc[4,2], corr_3m_divergent.iloc[4,2], 
                               corr_4m_divergent.iloc[4,2], corr_5m_divergent.iloc[4,2]]
correlation_dict_divergent['M4-M8'] = [corr_1m_divergent.iloc[4,3], 
                             corr_2m_divergent.iloc[4,3], corr_3m_divergent.iloc[4,3], 
                             corr_4m_divergent.iloc[4,3], corr_5m_divergent.iloc[4,3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-dcccfa0cb41f> in <module>
#       1 correlation_dict_convergent['D4-M8'] = [corr_1m_convergent.iloc[4,0],
# ----> 2                              corr_2m_convergent.iloc[4,0], corr_3m_convergent.iloc[4,0],
#       3                              corr_4m_convergent.iloc[4,0], corr_5m_convergent.iloc[4,0]]
#       4
#       5 correlation_dict_convergent['D8-M8'] = [corr_1m_convergent.iloc[4,1],
#
# NameError: name 'corr_2m_convergent' is not defined

# %%
correlation_convergent_dataframe = pd.DataFrame.from_dict(correlation_dict_convergent, orient='index')
correlation_divergent_dataframe = pd.DataFrame.from_dict(correlation_dict_divergent, orient='index')

# %%
correlation_convergent_dataframe.columns = ['1m', '2m', '3m', '4m', '5m']
correlation_divergent_dataframe.columns = ['1m', '2m', '3m', '4m', '5m']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-3e70330d38a0> in <module>
# ----> 1 correlation_convergent_dataframe.columns = ['1m', '2m', '3m', '4m', '5m']
#       2 correlation_divergent_dataframe.columns = ['1m', '2m', '3m', '4m', '5m']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 5 elements

# %%
correlation_convergent_dataframe['Comparison'] = correlation_convergent_dataframe.index
correlation_divergent_dataframe['Comparison'] = correlation_divergent_dataframe.index

# %%
melted_convergent_correlations = pd.melt(correlation_convergent_dataframe, id_vars=['Comparison'], var_name='Resolution')
convergent_correlations = melted_convergent_correlations.rename(columns={'value': 'Correlation'})

melted_divergent_correlations = pd.melt(correlation_divergent_dataframe, id_vars=['Comparison'], var_name='Resolution')
divergent_correlations = melted_divergent_correlations.rename(columns={'value': 'Correlation'})

# %%
from matplotlib.lines import Line2D

# %%
sns.set(style = 'ticks')
fig, ax = plt.subplots(figsize = (7, 7))
jitter = 0.15
data = convergent_correlations
ylim_min = .2
ylim_max = 1
#plt.clf()
D4p = data[(data['Comparison']=='D4-M8')]
colors = ['burnt yellow']
m = sns.stripplot('Resolution','Correlation',hue='Comparison',
                  marker='o',data=D4p, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)
m.set(ylim = (ylim_min, ylim_max))
D8p = data[(data['Comparison']=='D8-M8')]
colors = ['merlot']
n = sns.stripplot('Resolution','Correlation',hue='Comparison',
                  marker='v',data=D8p, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

Dinfp = data[(data['Comparison']=='Dinf-M8')]
colors = ['dark sea green']
o = sns.stripplot('Resolution','Correlation',hue='Comparison',
                  marker='s',data=Dinfp, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

M4p = data[(data['Comparison']=='M4-M8')]
colors = ['cobalt blue']
p = sns.stripplot('Resolution','Correlation',hue='Comparison',
                  marker='D',data=M4p, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

plt.grid(linestyle='--')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set(ylim = (ylim_min, ylim_max))
ax.set_xlabel('Resolution', fontsize = 15)
ax.set_ylabel('Correlation', fontsize = 15)
plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='22') # for legend title

D4l = Line2D([], [], color='xkcd:burnt yellow', marker='o', linestyle='None',
                          markersize=15, label='D4-M8')
D8l = Line2D([], [], color='xkcd:merlot', marker='v', linestyle='None',
                          markersize=15, label='D8-M8')
Dinfl = Line2D([], [], color='xkcd:dark sea green', marker='s', linestyle='None',
                          markersize=15, label='Dinf-M8')
M4l = Line2D([], [], color='xkcd:cobalt blue', marker='D', linestyle='None',
                          markersize=15, label='M4-M8')

ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel('Resolution', fontsize = 20)
ax.set_ylabel('Correlation', fontsize = 20)


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = 'Algorithm comparisons',fontsize='15')
plt.setp(ax.get_legend().get_title(), fontsize='15') # for legend title
plt.legend(handles=[D4l, D8l, Dinfl,M4l],fontsize=15)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\seaborn\categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-849b5e1f76a3> in <module>
#      11                   marker='o',data=D4p, jitter=jitter,
#      12                   palette=sns.xkcd_palette(colors),
# ---> 13                   split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)
#      14 m.set(ylim = (ylim_min, ylim_max))
#      15 D8p = data[(data['Comparison']=='D8-M8')]
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2782
#    2783     plotter = _StripPlotter(x, y, hue, data, order, hue_order,
# -> 2784                             jitter, dodge, orient, color, palette)
#    2785     if ax is None:
#    2786         ax = plt.gca()
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette)
#    1127         """Initialize the plotter."""
#    1128         self.establish_variables(x, y, hue, data, orient, order, hue_order)
# -> 1129         self.establish_colors(color, palette, 1)
#    1130
#    1131         # Set object attributes
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_colors(self, color, palette, saturation)
#     314         # Determine the gray color to use for the lines framing the plot
#     315         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 316         lum = min(light_vals) * .6
#     317         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     318
#
# ValueError: min() arg is an empty sequence

# %%
exponent_b_divergent = pd.read_excel('exponent_b_divergent.xlsx')
exponent_b_divergent['Flow'] = 'Divergent'
exponent_b_convergent = pd.read_excel('exponent_b_convergent.xlsx')
exponent_b_convergent['Flow'] = 'Convergent'

# %%
d4_mean = np.mean([exponent_b_convergent['D4'].to_numpy(),exponent_b_divergent['D4'].to_numpy()], axis = 0)
d8_mean = np.mean([exponent_b_convergent['D8'].to_numpy(),exponent_b_divergent['D8'].to_numpy()], axis = 0)
dinf_mean = np.mean([exponent_b_convergent['Dinf'].to_numpy(),exponent_b_divergent['Dinf'].to_numpy()], axis = 0)
m4_mean = np.mean([exponent_b_convergent['M4'].to_numpy(),exponent_b_divergent['M4'].to_numpy()], axis = 0)
m8_mean = np.mean([exponent_b_convergent['M8'].to_numpy(),exponent_b_divergent['M8'].to_numpy()], axis = 0)

# %%
exponent_b_mean = exponent_b_divergent.copy()

# %%
exponent_b_mean['D4'] = d4_mean
exponent_b_mean['D8'] = d8_mean
exponent_b_mean['Dinf'] = dinf_mean
exponent_b_mean['M4'] = m4_mean
exponent_b_mean['M8'] = m8_mean

# %%
mean_dataframe = pd.melt(exponent_b_mean, id_vars=['Resolution', 'Flow'], 
                               value_vars=['D4', 'D8', 'Dinf', 'M4', 'M8'], var_name = 'Method', value_name = 'b')

# %%
flow_datasets = [exponent_b_convergent, exponent_b_divergent]

# %%
conv_and_div = pd.concat(flow_datasets)

# %%
conv_dataframe = pd.melt(exponent_b_convergent, id_vars=['Resolution', 'Flow'], 
                               value_vars=['D4', 'D8', 'Dinf', 'M4', 'M8'], var_name = 'Method', value_name = 'b')

# %%
div_dataframe = pd.melt(exponent_b_divergent, id_vars=['Resolution', 'Flow'], 
                               value_vars=['D4', 'D8', 'Dinf', 'M4', 'M8'], var_name = 'Method', value_name = 'b')

# %%
scalar_k_divergent = pd.read_excel('scalar_k_divergent.xlsx')
scalar_k_divergent['Flow'] = 'Divergent'
scalar_k_convergent = pd.read_excel('scalar_k_convergent.xlsx')
scalar_k_convergent['Flow'] = 'Convergent'

# %%
flow_datasets_k = [scalar_k_convergent, scalar_k_divergent]
conv_and_div_k = pd.concat(flow_datasets_k)

# %%
conv_dataframe_k = pd.melt(scalar_k_convergent, id_vars=['Resolution', 'Flow'], 
                               value_vars=['D4', 'D8', 'Dinf', 'M4', 'M8'], var_name = 'Method', value_name = 'k')

# %%
div_dataframe_k = pd.melt(scalar_k_divergent, id_vars=['Resolution', 'Flow'], 
                               value_vars=['D4', 'D8', 'Dinf', 'M4', 'M8'], var_name = 'Method', value_name = 'k')

# %%
sns.set(style = 'ticks')
fig, ax = plt.subplots(figsize = (7, 7))
jitter = 0.15
parameter = 'k'
data = div_dataframe_k
ylim_min = 0
ylim_max = .05
#plt.clf()
D4p = data[(data['Method']=='D4')]
colors = ['burnt yellow']
m = sns.stripplot('Resolution',parameter,hue='Flow',
                  marker='o',data=D4p, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)
m.set(ylim = (ylim_min, ylim_max))
D8p = data[(data['Method']=='D8')]
colors = ['merlot']
n = sns.stripplot('Resolution',parameter,hue='Flow',
                  marker='v',data=D8p, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

Dinfp = data[(data['Method']=='Dinf')]
colors = ['dark sea green']
o = sns.stripplot('Resolution',parameter,hue='Flow',
                  marker='s',data=Dinfp, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

M4p = data[(data['Method']=='M4')]
colors = ['cobalt blue']
p = sns.stripplot('Resolution',parameter,hue='Flow',
                  marker='D',data=M4p, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

M8p = data[(data['Method']=='M8')]
colors = ['dusty pink']
p = sns.stripplot('Resolution',parameter,hue='Flow',
                  marker='p',data=M8p, jitter=jitter, 
                  palette=sns.xkcd_palette(colors),
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

plt.grid(linestyle='--')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set(ylim = (ylim_min, ylim_max))
ax.set_xlabel('Resolution', fontsize = 15)
ax.set_ylabel('Correlation', fontsize = 15)
plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='22') # for legend title

D4l = Line2D([], [], color='xkcd:burnt yellow', marker='o', linestyle='None',
                          markersize=15, label='D4')
D8l = Line2D([], [], color='xkcd:merlot', marker='v', linestyle='None',
                          markersize=15, label='D8')
Dinfl = Line2D([], [], color='xkcd:dark sea green', marker='s', linestyle='None',
                          markersize=15, label='Dinf')
M4l = Line2D([], [], color='xkcd:cobalt blue', marker='D', linestyle='None',
                          markersize=15, label='M4')
M8l = Line2D([], [], color='xkcd:dusty pink', marker='p', linestyle='None',
                          markersize=15, label='M8')


ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel('Resolution', fontsize = 20)
ax.set_ylabel('Scalar (k)', fontsize = 20)


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='15')
plt.setp(ax.get_legend().get_title(), fontsize='15') # for legend title
plt.legend(handles=[D4l, D8l, Dinfl,M4l,M8l],fontsize=15)
plt.title('Divergent', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Divergent')

# %%
sns.set(style = 'ticks')
fig, ax = plt.subplots(figsize = (12, 7))
jitter = 0.15
data = conv_and_div_dataframe
ylim_min = 0
ylim_max = .4
#plt.clf()
D4p = data[(data['Method']=='D4')]
m = sns.stripplot('Resolution','b',
                  marker='o',data=D4p, jitter=jitter, 
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)
m.set(ylim = (ylim_min, ylim_max))

D8p = data[(data['Method']=='D8')]
n = sns.stripplot('Resolution','b',
                  marker='v',data=D8p, jitter=jitter, 
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

Dinfp = data[(data['Method']=='Dinf')]
o = sns.stripplot('Resolution','b',
                  marker='s',data=Dinfp, jitter=jitter, 
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

M4p = data[(data['Method']=='M4')]
p = sns.stripplot('Resolution','b',
                  marker='D',data=M4p, jitter=jitter, 
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

M8p = data[(data['Method']=='M8')]
p = sns.stripplot('Resolution','b',
                  marker='p',data=M8p, jitter=jitter, 
                  split=True,linewidth=2,edgecolor="black", size = 15, alpha = 0.7)

plt.grid(linestyle='--')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
ax.set(ylim = (ylim_min, ylim_max))
ax.set_xlabel('Resolution', fontsize = 15)
ax.set_ylabel('Correlation', fontsize = 15)
plt.setp(ax.get_legend().get_texts(), fontsize='15') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='22') # for legend title

D4l = Line2D([], [], color='xkcd:burnt yellow', marker='o', linestyle='None',
                          markersize=15, label='D4')
D8l = Line2D([], [], color='xkcd:merlot', marker='v', linestyle='None',
                          markersize=15, label='D8')
Dinfl = Line2D([], [], color='xkcd:dark sea green', marker='s', linestyle='None',
                          markersize=15, label='Dinf')
M4l = Line2D([], [], color='xkcd:cobalt blue', marker='D', linestyle='None',
                          markersize=15, label='M4')
M8l = Line2D([], [], color='xkcd:dusty pink', marker='p', linestyle='None',
                          markersize=15, label='M8')


ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel('Resolution', fontsize = 20)
ax.set_ylabel('Correlation', fontsize = 20)


plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = 'Algorithm comparisons',fontsize='15')
plt.setp(ax.get_legend().get_title(), fontsize='15') # for legend title
plt.legend(handles=[D4l, D8l, Dinfl,M4l,M8l],fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-060d14c6db52> in <module>
#       2 fig, ax = plt.subplots(figsize = (12, 7))
#       3 jitter = 0.15
# ----> 4 data = conv_and_div_dataframe
#       5 ylim_min = 0
#       6 ylim_max = .4
#
# NameError: name 'conv_and_div_dataframe' is not defined

# %%
j = all_data_1m.loc[(all_data_1m['DC'] == 1)].drop(columns = ['node_id', 'Slope', 'Resolution'])

# %%
r = all_data_1m[all_data_1m.DC != 'not enough grid cells'].drop(columns = ['node_id', 'Slope', 'Resolution'])
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
r
# Out:
#               D4       D8       Dinf         M4         M8  DC        SA
# 6369407   0.7936   0.4192   0.432222   0.584626   0.481259   0  0.044079
# 8000074   0.5183   0.9929   1.024181   0.900704   0.962416   1  0.040577
# 8402506   0.5654   0.5344   0.504951   0.546750   0.482315   0  0.056838
# 9130277   0.8072   0.7289   0.728331   0.757537   0.464273   0  0.022517
# 9183765   0.4843   0.8293   0.723900   0.759752   0.470430   0  0.040390
# ...          ...      ...        ...        ...        ...  ..       ...
# 62794131  0.0023  22.0751  22.088686  10.974792  15.353873   0  0.022314
# 64129981  0.1730   0.0239   0.186611   0.294549   0.289628   1  0.012048
# 65836953  2.1117   1.8009   1.801514   1.964746   1.910864   1  0.032858
# 66631077  1.4384   1.5663   1.529028   1.505315   1.519280   1  0.033483
# 67555056  0.7541   1.5150   1.146929   0.821596   0.597361   0  0.035534
#
# [482 rows x 7 columns]

# %%
dr = r.drop(['SA'], axis=1).rename(columns = {'D4': 'D4 (ha)', 'D8': 'D8 (ha)', 'Dinf': 'Dinf (ha)',
                                             'M4': 'M4 (ha)', 'M8': 'M8 (ha)'}, inplace = False)

# %%
sns.set(style = "ticks")
colors = ["xkcd:royal blue", "xkcd:pumpkin"]
data = dr
def plot_unity(xdata, ydata, **kwargs):
    mn = min(xdata.min(), ydata.min())
    mx = max(xdata.max(), ydata.max())
    points = np.linspace(mn, mx, 100)
    plt.gca().plot(points, points, color = 'xkcd:chocolate', marker=None,
            linestyle='--', linewidth=1.0)

fig = sns.pairplot(data, palette = colors, hue = 'DC', markers=['x', 'o'])

handles = fig._legend_data.values()
labels = ['Convergent', 'Divergent']

fig.fig.legend(handles=handles, labels=labels, loc='upper right', ncol=3, fontsize = 15)
fig.fig.subplots_adjust(top=0.92, bottom=0.08)

sns.plotting_context()
fig.map_offdiag(plot_unity)

fig.set(ylim=(-0.5,10))
fig.set(xlim=(-0.5,10))
plt.rcParams["axes.labelsize"] = 15
for ax in plt.gcf().axes:
    l = ax.get_xlabel()
    m = ax.get_ylabel()
    ax.set_xlabel(l, fontsize=15)
    ax.set_ylabel(m, fontsize=15)

# %%
sns.set(font_scale = 1.5)
sns.set_style("whitegrid", {'grid.linestyle': '--'})
fig, ax = plt.subplots(figsize = (10, 5))
data = merge_correlation_means
colors = ['xkcd:pumpkin', 'xkcd:very light blue']
# Draw a nested barplot to show survival for class and sex

sns.barplot(x="Method", y="Correlation", hue="Flow", data=data,
                  palette=colors, alpha = 0.8,linewidth=2,edgecolor="black",)

ax.set_ylabel("Correlation", fontsize = 20)
ax.set_xlabel("Routing method", fontsize = 20)
ax.set(ylim = (0.2, 1))

#fig.set_xlabel("X Label",fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='15')
#ax.set_yticklabels(ax.get_yticks(), size = 15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-666c7350079d> in <module>
#       2 sns.set_style("whitegrid", {'grid.linestyle': '--'})
#       3 fig, ax = plt.subplots(figsize = (10, 5))
# ----> 4 data = merge_correlation_means
#       5 colors = ['xkcd:pumpkin', 'xkcd:very light blue']
#       6 # Draw a nested barplot to show survival for class and sex
#
# NameError: name 'merge_correlation_means' is not defined

# %%
sns.set_style('ticks', {'grid.linestyle': '--'})
data = r
colours = {0:'xkcd:mid blue', 1:'xkcd:pale pink'}
x_axis = 'M8'
y_axis = 'M4'
fig = sns.relplot(x=x_axis, y=y_axis, palette = colours, hue = 'DC',
                 data=data, alpha = 0.7, legend = 'brief', edgecolor="k", style = 'DC')

ax = fig.axes[0,0]
ax.set_xlim(-0.1,6)
ax.set_ylim(-0.1,6)
ax.set_xlabel(x_axis, fontsize = 20)
ax.set_ylabel(y_axis, fontsize = 20)
leg = fig._legend
plt.rcParams["axes.edgecolor"] = "0.15"
plt.plot([0, 10], [0, 10], linestyle='--', color = 'xkcd:chocolate', alpha = 0.5)

# %%
frames = [all_data_1m_dataframe, all_data_2m_dataframe, 
          all_data_3m_dataframe, all_data_4m_dataframe, 
          all_data_5m_dataframe]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-f25a89304815> in <module>
# ----> 1 frames = [all_data_1m_dataframe, all_data_2m_dataframe,
#       2           all_data_3m_dataframe, all_data_4m_dataframe,
#       3           all_data_5m_dataframe]
#
# NameError: name 'all_data_2m_dataframe' is not defined

# %%
all_resolutions = pd.concat(frames)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-a7aeb0f74305> in <module>
# ----> 1 all_resolutions = pd.concat(frames)
#
# NameError: name 'frames' is not defined

# %%
all_resolutions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-149-46cfb9e65a81> in <module>
# ----> 1 all_resolutions
#
# NameError: name 'all_resolutions' is not defined

# %%
gully_head_dataframe = pd.melt(all_resolutions, id_vars=['node_id', 'DC', 'Slope', 'Resolution', 'SA', 'Flow'], 
                               value_vars=['D4', 'D8', 'Dinf', 'M4', 'M8'], var_name = 'Method', value_name = 'Area')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-150-d0da470d5b5e> in <module>
# ----> 1 gully_head_dataframe = pd.melt(all_resolutions, id_vars=['node_id', 'DC', 'Slope', 'Resolution', 'SA', 'Flow'],
#       2                                value_vars=['D4', 'D8', 'Dinf', 'M4', 'M8'], var_name = 'Method', value_name = 'Area')
#
# NameError: name 'all_resolutions' is not defined

# %%
gully_head_dataframe

# %%
sns.set(font_scale = 1.5)
sns.set_style("whitegrid", {'grid.linestyle': '--'})
fig, ax = plt.subplots(figsize = (10, 5))
data = gully_head_dataframe
colors = ['xkcd:very light blue', 'xkcd:pumpkin']
# Draw a nested barplot to show survival for class and sex

sns.barplot(x="Resolution", y = 'Flow', hue="DC", data=data,
                  palette=colors, alpha = 0.8,linewidth=2,edgecolor="black",)

ax.set_ylabel("Number of gullies", fontsize = 20)
ax.set_xlabel("Resolution", fontsize = 20)
ax.set(ylim = (0, 500))

Div = Line2D([], [], color='xkcd:apricot', marker='s', linestyle='None',
                          markersize=15, label='Divergent')
Conv = Line2D([], [], color='xkcd:very light blue', marker='s', linestyle='None',
                          markersize=15, label='Convergent')

#fig.set_xlabel("X Label",fontsize=30)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize='15')

plt.setp(ax.get_legend().get_title(), fontsize='12') # for legend title
plt.legend(handles=[Conv, Div],fontsize=13)

#ax.set_yticklabels(ax.get_yticks(), size = 15)

# %%
m8_only = gully_head_dataframe.loc[(gully_head_dataframe['Method'] == 'M8')]

# %%
dinf_only = gully_head_dataframe.loc[(gully_head_dataframe['Method'] == 'Dinf')]

# %%
d8_only = gully_head_dataframe.loc[(gully_head_dataframe['Method'] == 'D8')]

# %%
m4_only = gully_head_dataframe.loc[(gully_head_dataframe['Method'] == 'M4')]

# %%
d4_only = gully_head_dataframe.loc[(gully_head_dataframe['Method'] == 'D4')]

# %%
m8_1m_only = m8_only.loc[(m8_only['Resolution'] == 1)]

# %%
m8_2m_only = m8_only.loc[(m8_only['Resolution'] == 2)]

# %%
m8_3m_only = m8_only.loc[(m8_only['Resolution'] == 3)]

# %%
m8_4m_only = m8_only.loc[(m8_only['Resolution'] == 4)]

# %%
m8_5m_only = m8_only.loc[(m8_only['Resolution'] == 5)]

# %%
m8_only.head()

# %%
d8_only = gully_head_dataframe.loc[(gully_head_dataframe['Method'] == 'D8')]

# %%
np.random.seed(8)

remove_n = 1000

drop_indices = np.random.choice(m4_only.index, remove_n, replace=False)
df_subset = m8_only.drop(drop_indices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-c60f5efd5c25> in <module>
#       3 remove_n = 1000
#       4
# ----> 5 drop_indices = np.random.choice(m4_only.index, remove_n, replace=False)
#       6 df_subset = m8_only.drop(drop_indices)
#
# NameError: name 'm4_only' is not defined

# %%
sns.set_style('whitegrid', {'grid.linestyle': '--'})
# baby blue, pale pink
data = df_subset
colours = {0:'xkcd:very light blue', 1:'xkcd:pumpkin'}
x_axis = 'Area'
y_axis = 'SA'

fig = sns.relplot(x=x_axis, y=y_axis,  palette = colours, hue = 'DC',
                 data=data, alpha = 0.6,  edgecolor='xkcd:black', 
                  style = 'DC', markers=['o', 'o'], size = 'Resolution', sizes=(20,200))

ax = fig.axes[0,0]
ax.set_xlim(0.1,100)
ax.set_ylim(0.001,1)
ax.set_xlabel(x_axis, fontsize = 20)
ax.set_ylabel(y_axis, fontsize = 20)
leg = fig._legend
plt.rcParams["axes.edgecolor"] = "0.15"


Div = Line2D([], [], color='xkcd:apricot', marker='o', linestyle='None',
                          markersize=15, label='Divergent')
Conv = Line2D([], [], color='xkcd:very light blue', marker='o', linestyle='None',
                          markersize=15, label='Convergent')

#ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel('Area (ha)', fontsize = 15)
ax.set_ylabel(('Slope (m$\cdot$m$^{-1}$)'), fontsize = 15)
ax.set(xscale="log", yscale="log")
#ax.set(xscale="log")

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.,fontsize='12')
plt.setp(ax.get_legend().get_title(), fontsize='12') # for legend title
plt.legend(handles=[Conv, Div],fontsize=13)
fig.fig.set_size_inches(12,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-ea71e32effa8> in <module>
#       1 sns.set_style('whitegrid', {'grid.linestyle': '--'})
#       2 # baby blue, pale pink
# ----> 3 data = df_subset
#       4 colours = {0:'xkcd:very light blue', 1:'xkcd:pumpkin'}
#       5 x_axis = 'Area'
#
# NameError: name 'df_subset' is not defined

# %%
data = m8_only
ax = sns.regplot(x="log_area", y="log_s", data=data, marker = '+')

# %%
v = gully_head_dataframe.loc[(gully_head_dataframe.Resolution == 1)&(gully_head_dataframe['Method'] == 'M8')]

# %%
v.drop(v.loc[v['DC']=='not enough grid cells'].index, inplace=True)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# C:\Users\sjwal\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data = gully_head_dataframe
colours = {0:'xkcd:powder blue', 1:'xkcd:mango'}
g = sns.catplot(x="Area", y="DC", row="Resolution",
                kind="box", orient="h", height=1.5, aspect=4,
                data=data, ax = ax, palette = colours)
g.set(xlim=(-1, 7))
plt.xlabel('Area (ha)', fontsize=15)
for ax in g.axes.flat:
    ax.set_ylabel('Divergence', fontsize=15)
    ax.set(yticklabels=['no', 'yes'])
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try boxplot
#   warnings.warn(msg, UserWarning)

# %%
gully_head_dataframe
# Out:
#        node_id  DC     Slope  Resolution        SA Method      Area
# 0      6369407   0  0.043334           1  0.044079     D4  0.793600
# 1      8000074   1  0.043282           1  0.040577     D4  0.518300
# 2      8402506   0  0.048987           1  0.056838     D4  0.565400
# 3      9130277   0  0.049699           1  0.022517     D4  0.807200
# 4      9183765   0  0.048443           1  0.040390     D4  0.484300
# ...        ...  ..       ...         ...       ...    ...       ...
# 11375  2510461   1  0.008467           5  0.022358     M8  5.029630
# 11376  2564530   0  0.023924           5  0.024667     M8  0.283214
# 11377  2634112   0  0.039369           5  0.046443     M8  1.641589
# 11378  2664641   1  0.044791           5  0.034251     M8  0.994660
# 11379  2701571   0  0.030548           5  0.029576     M8  1.231684
#
# [11380 rows x 7 columns]

# %%
data = gully_head_dataframe
colours = {0:'xkcd:powder blue', 1:'xkcd:mango'}
g = sns.catplot(x="SA", y="DC", row="Resolution",
                kind="box", orient="h", height=1.5, aspect=4,
                data=data, palette = colours)
g.set(xlim=(0, 0.1))
plt.xlabel('Slope (m$\cdot$m$^{-1}$)', fontsize=15)
for ax in g.axes.flat:
    ax.set_ylabel('Divergence', fontsize=15)
    ax.set(yticklabels=['no', 'yes'])

# %%
all_data_1m_dataframe
# Out:
#               D4       D8       Dinf         M4         M8   node_id  DC  \
# 6369407   0.7936   0.4192   0.432222   0.584626   0.481259   6369407   0
# 8000074   0.5183   0.9929   1.024181   0.900704   0.962416   8000074   1
# 8402506   0.5654   0.5344   0.504951   0.546750   0.482315   8402506   0
# 9130277   0.8072   0.7289   0.728331   0.757537   0.464273   9130277   0
# 9183765   0.4843   0.8293   0.723900   0.759752   0.470430   9183765   0
# ...          ...      ...        ...        ...        ...       ...  ..
# 62794131  0.0023  22.0751  22.088686  10.974792  15.353873  62794131   0
# 64129981  0.1730   0.0239   0.186611   0.294549   0.289628  64129981   1
# 65836953  2.1117   1.8009   1.801514   1.964746   1.910864  65836953   1
# 66631077  1.4384   1.5663   1.529028   1.505315   1.519280  66631077   1
# 67555056  0.7541   1.5150   1.146929   0.821596   0.597361  67555056   0
#
#              Slope        SA  Resolution
# 6369407   0.043334  0.044079           1
# 8000074   0.043282  0.040577           1
# 8402506   0.048987  0.056838           1
# 9130277   0.049699  0.022517           1
# 9183765   0.048443  0.040390           1
# ...            ...       ...         ...
# 62794131  0.029851  0.022314           1
# 64129981  0.026624  0.012048           1
# 65836953  0.042981  0.032858           1
# 66631077  0.047670  0.033483           1
# 67555056  0.033607  0.035534           1
#
# [482 rows x 10 columns]

# %%
conv_area = all_data_5m_dataframe.loc[all_data_5m_dataframe['DC'] == 0]['D4'].to_numpy()
div_area = all_data_5m_dataframe.loc[all_data_5m_dataframe['DC'] == 1]['D4'].to_numpy()
mean_conv_a = np.round(np.mean(conv_area),5)
mean_div_a = np.round(np.mean(div_area),5)

standard_deviation_convergent = np.std(np.array(conv_area))
standard_deviation_divergent = np.std(np.array(div_area))

# %%
print('Mean div: ', np.round(mean_div_a, 2), 'stdev: ', np.round(standard_deviation_divergent, 2))
print('Mean conv: ', np.round(mean_conv_a, 2), 'stdev: ', np.round(standard_deviation_convergent, 2))
# Out:
# Mean div:  3.44 stdev:  10.51
# Mean conv:  1.86 stdev:  4.74

# %%
stat, p = mannwhitneyu(conv_area, div_area)

# %%
if p < 0.0005:
    p = '(***)'
elif p < 0.005:
    p = '(**)'
elif p < 0.05:
    p = '(*)'
else:
    p= '(ns)'

p
# Out:
# '(ns)'

# %%
# generate non-normal data (exponential) 
original_data = conv_slope
  
# transform training data & save lambda value 
fitted_data, fitted_lambda = stats.boxcox(v) 
  
# creating axes to draw plots 
fig, ax = plt.subplots(1, 2) 
  
# plotting the original data(non-normal) and  
# fitted data (normal) 
sns.distplot(original_data, hist = True, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "Non-Normal", color ="green", ax = ax[0]) 
  
sns.distplot(fitted_data, hist = True, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "Normal", color ="green", ax = ax[1]) 
  
# adding legends to the subplots 
plt.legend(loc = "upper right") 
  
# rescaling the subplots 
fig.set_figheight(5) 
fig.set_figwidth(10) 
  
print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-473-06a445c800e0> in <module>
#       1 # generate non-normal data (exponential)
# ----> 2 original_data = conv_slope
#       3
#       4 # transform training data & save lambda value
#       5 fitted_data, fitted_lambda = stats.boxcox(v)
#
# NameError: name 'conv_slope' is not defined

# %%
from scipy.stats import normaltest

# %%
from scipy.stats import mannwhitneyu

# %%
stat, p = normaltest(md)

# %%
stat, p = mannwhitneyu(conv_area, div_area)

# %%
p
# Out:
# 2.184049614799961e-08

# %%
# generate non-normal data (exponential) 
original_data = div_area
  
# transform training data & save lambda value 
fitted_data, fitted_lambda = stats.boxcox(original_data) 
  
# creating axes to draw plots 
fig, ax = plt.subplots(1, 2) 
  
# plotting the original data(non-normal) and  
# fitted data (normal) 
sns.distplot(original_data, hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "Non-Normal", color ="purple", ax = ax[0]) 
  
sns.distplot(fitted_data, hist = False, kde = True, 
            kde_kws = {'shade': True, 'linewidth': 2},  
            label = "Normal", color ="purple", ax = ax[1]) 
  
# adding legends to the subplots 
plt.legend(loc = "upper right") 
  
# rescaling the subplots 
fig.set_figheight(5) 
fig.set_figwidth(10) 
  
print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# Lambda value used for Transformation: -0.47148259571228596

# %%
stats.shapiro(fitted_data)
# Out:
# (0.9603593945503235, 1.5058583358040778e-06)

# %%
degrees_of_freedom = np.min([len(conv_area), len(div_area)]) - 1

# %%
test_of_significance_b = t.sf(t_value_b, degrees_of_freedom) * 2
test_of_significance_k = t.sf(t_value_k, degrees_of_freedom) * 2
print('Significant difference b: ', test_of_significance_b)
print('Significant difference k: ', test_of_significance_k)

# %%
from statsmodels.graphics.gofplots import qqplot

# %% [markdown]
# ### $H_0$: $\mu_{conv}$  = $\mu_{div}$

# %%
qqplot(div_area, line='s')
plt.show()

# %%
catchment_areas_1m_divergent = gully_head_dataframe.loc[(gully_head_dataframe['DC'] == 1) & (gully_head_dataframe['Resolution'] == 1)]

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('grid_nodes_5m.tif', input_geotiff, grid_nodes_float, grid_nodes_float.dtype)
