# %%
# %%capture
from jupyterthemes import jtplot
jtplot.style()
import numpy as np
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from landlab.plot.imshow import imshow_grid 
# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, FlowRouter, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure

from landlab.components.overland_flow import OverlandFlow

from landlab.plot.colors import water_colormap

# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120)
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()

# %%
location = (r'C:/PhD/junk')
os.chdir(location)

input_geotiff = gdal.Open('fann_2013_1m0.tif')
initial_resolution = 1
x = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())
input_DEM = x[1800:2000,1100:1300]

input_outlets = gdal.Open('g1_grid.tif')
initial_resolution = 1
o = np.array(input_outlets.GetRasterBand(1).ReadAsArray())
outlets = 1 - (o[1800:2000,1100:1300])

# %%
plt.imshow(input_DEM, cmap="gist_earth_r");
plt.colorbar();

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def slopeWindow(DEM_slope, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM_slope[0]; b = DEM_slope[1]; c = DEM_slope[2]
    d = DEM_slope[3]; e = DEM_slope[4]; f = DEM_slope[5]
    g = DEM_slope[6]; h = DEM_slope[7]; i = DEM_slope[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but askinh for both causes it to throw and error.
    return slope_percent
# The 'extra_arguments' variable requires a value that represents r in the PCTL function defined above.
# The reason it need to be assigned to a seperate variable is that the generic_filter function only allows the
# input function (PCTL in this case) to take one argument (S1). Then, if the input function normally 
# takes more than one argument the 'extra_arguments' variable needs to be defined as a tuple 
# (hence (3,) instead of (3)).
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def planCurvature(DEM, cellsize):
    """This process is taken from Change (2014, Introduction to Geographic Information
    systems, Page 284)."""
    Z1 = DEM[0]; Z2 = DEM[1]; Z3 = DEM[2]
    Z4 = DEM[3]; Z0 = DEM[4]; Z5 = DEM[5]
    Z6 = DEM[6]; Z7 = DEM[7]; Z8 = DEM[8]
    D = (((Z4 + Z5)/2) - Z0) / cellsize**2
    E = (((Z2 + Z7)/2) - Z0) / cellsize**2
    F = (Z3 - Z1 + Z6 - Z8)/ (4 * cellsize**2)
    G = (Z5 - Z4) / (2 * cellsize)
    H = (Z2 - Z7) / (2 * cellsize)
    plan_curvature = (2 * (D*(H**2) + E*(G**2) - (F*G*H))) / (G**2 + H**2)
    return plan_curvature
def profileCurvature(DEM, cellsize):
    """This process is taken from Change (2014, Introduction to Geographic Information
       systems, Page 284)."""
    Z1 = DEM[0]; Z2 = DEM[1]; Z3 = DEM[2]
    Z4 = DEM[3]; Z0 = DEM[4]; Z5 = DEM[5]
    Z6 = DEM[6]; Z7 = DEM[7]; Z8 = DEM[8]
    D = (((Z4 + Z5)/2) - Z0) / cellsize**2
    E = (((Z2 + Z7)/2) - Z0) / cellsize**2
    F = (Z3 - Z1 + Z6 - Z8)/ (4 * cellsize**2)
    G = (Z5 - Z4) / (2 * cellsize)
    H = (Z2 - Z7) / (2 * cellsize)
    profile_curvature = (-2 * (D*(G**2) + E*(H**2) + (F*G*H))) / (G**2 + H**2)
    return profile_curvature
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def DFME(elev):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = elev[central_value]                        
    mean = np.nanmean(elev)#Count number of values greater than centroid value
    diff = centroid - mean
    return diff
def PCTL(x):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = x[central_value]                        
    y = np.sum(x < centroid)/num_values#Count number of values greater than centroid value
    return y
def TWI(slope, As):
    """Calculates Topographic Wetness Index (TWI) taking a slope layer in degrees,
    the catchment area of the cell calculated using a chosen flow routing algorithm and 
    the cell resolution of the slope and catchment area layers input as an integer."""
    tolerance = 1e-16
    slope_radians = np.deg2rad(slope)
    tanB = np.tan(slope_radians)
    tanB[tanB < tolerance] = tolerance
    sca = np.asarray(As)
    sca[sca < tolerance] = tolerance
    W = np.log(np.divide(sca, tanB))
    TWI = np.asarray(W)
    TWI[TWI < tolerance] = 0
    return TWI
def SPI(slope, As):
    """Calculates Compound Topographic Index (TWI) taking a slope layer in degrees and
    the catchment area of the cell calculated using a chosen flow routing algorithm."""
    tolerance = 1e-16
    slope_radians = np.deg2rad(slope)
    tanB = np.tan(slope_radians)
    tanB[tanB < tolerance] = tolerance
    C = np.multiply(As, tanB)
    C_N = np.nan_to_num(C)
    return C_N
def flow_dir_dataset(flow_receivers, grid_node_values, drainage_area,
                     grid_x_axis_length, grid_resolution, grid_shape):
    """Decomposes flow directions into 8 grids of single direction and uses those 
    grids to calculate specific catchment area."""
    array_direction = xr.Dataset();
    # In order - East, North, West, South, Nothwest, Northeast, Southwest, Southeast.
    possible_directions = [1, grid_x_axis_length, -1, -grid_x_axis_length,
                          grid_x_axis_length + 1, grid_x_axis_length - 1,
                            -(grid_x_axis_length + 1), -(grid_x_axis_length -1)]
    for i in range(0,8):
        # Reset the flow_direction grid for each run.
        flow_direction = np.subtract(flow_receivers, grid_node_values);
        # Extract only grids cells with a specific flow direction.
        isolate_direction = flow_direction == possible_directions[i]
        reshape_direction = isolate_direction.reshape(grid_shape)
        weighted_direction = xr.DataArray((np.multiply(drainage_area, reshape_direction)), 
                                          dims = ['lat', 'lon'])
        array_direction[direction_list[i]] = weighted_direction
        
    E, N, W, S, NE, NW, SW, SE = (array_direction['East'],array_direction['North'], 
                                  array_direction['West'], array_direction['South'], 
                                  array_direction['North East'], array_direction['North West'],
                                  array_direction['South West'],array_direction['South East'])

    flow_dirs = xr.concat([E, N, W, S, NE, NW, SW, SE], 'direction')
    flow_dirs.name = 'flow_directions'
    flow_dirs.attrs['grid cell resolution'] = grid_resolution
    flow_directions = flow_dirs.assign_coords(direction=(['East','North','West','South',
                                   'North East', 'North West','South West', 'South East']))
    return flow_directions
def calculate_specific_catchment_area(dir_list):
    sca_dataset = xr.Dataset()
    dir_dicts = [{'Direction': 'East', 'x1': 1, 'x2': -1, 'y1': 2, 'y2': None}, 
                {'Direction': 'North','x1': 2, 'x2': None, 'y1': 1, 'y2': -1},
                {'Direction': 'West' , 'x1': 1, 'x2': -1, 'y1': None, 'y2': -2},
                {'Direction': 'South' ,'x1': None, 'x2': -2, 'y1': 1, 'y2': -1} ,
                {'Direction': 'North East' , 'x1': 2, 'x2': None, 'y1': 2, 'y2': None},
                {'Direction': 'North West' , 'x1': 2, 'x2': None, 'y1': None, 'y2': -2},
                {'Direction': 'South West' , 'x1': None, 'x2': -2, 'y1': None, 'y2': -2},
                {'Direction': 'South East', 'x1': None, 'x2': -2, 'y1': 2, 'y2': None}]

    for varname, ds in catchment_area_grids.data_vars.items():
        loop_temp_ds = xr.Dataset();
        for i in range(0,8):
                buffer = ds.sel(direction = dir_list[i]);
                resolution = buffer.attrs['grid cell resolution'];
                if i < 4:
                    flow_width_factor = np.divide(1, np.float(resolution));
                else: 
                    flow_width_factor = np.divide(1, math.sqrt(2) * resolution);
                
                lat = buffer.shape[0]; lon = buffer.shape[1];
                exp = np.zeros((lat + 2,lon + 2));
                exp[dir_dicts[i]['x1']:dir_dicts[i]['x2'],
                dir_dicts[i]['y1']:dir_dicts[i]['y2']] = np.multiply(buffer, flow_width_factor);
                spca_shell = np.flip(exp [1:-1,1:-1], 0);
                spca = xr.DataArray(spca_shell, dims = ['lat', 'lon']);
                loop_temp_ds[dir_list[i]] = spca
                
        E, N, W, S, NE, NW, SW, SE = (loop_temp_ds['East'], loop_temp_ds['North'],
                                loop_temp_ds['West'], loop_temp_ds['South'],
                                loop_temp_ds['North East'], loop_temp_ds['North West'],
                                loop_temp_ds['South West'], loop_temp_ds['South East']);

        spca_dirs = xr.concat([E, N, W, S, NE, NW, SW, SE], 'direction');
        specific_ca = spca_dirs.sum('direction');
        specific_ca.attrs['grid cell resolution'] = resolution
        sca_dataset['sca' + '_' + varname] = specific_ca
        
    return sca_dataset
def compile_flow_width_grid(flow_direction_grids, resolution, grid_shape):
    discharge_factor = np.zeros(grid_shape)
    for i in range(0, 8):
        if i < 4:
            flow_width_factor = np.divide(1, np.float(resolution));
        else: 
            flow_width_factor = np.divide(1, math.sqrt(2) * resolution);
        isolate_direction = flow_direction_grids[i,:,:] != 0;
        flow_width = np.multiply(isolate_direction, flow_width_factor);
        discharge_factor += flow_width
    return discharge_factor

# %% [markdown]
# ## First clip out the watershed

# %%
flow_acc_surf = np.copy(input_DEM).astype('float64');
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

# %%
sfb = SinkFillerBarnes(mg, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();
fa = FlowAccumulator(mg,
                    surface = 'topographic__elevation',
                    flow_director = 'FlowDirectorD8');
(flow_acc, q) = fa.accumulate_flow();
fd = FlowDirectorD8(mg, 'topographic__elevation');
fd.direct_flow();

# %%
grid_nodes_outlet = np.array(mg.nodes.reshape(mg.shape))
drainage_area = np.array(mg.at_node['drainage_area']).reshape(mg.shape).astype('float64');

# %%
find_outlet_ids = grid_nodes_outlet * outlets

# %%
outlet_id = np.unique(find_outlet_ids)[1]

# %%
watershed_mask = np.array(get_watershed_mask(mg, outlet_id).reshape(mg.shape).astype(int))

# %%
watershed_D8 = np.multiply(watershed_mask, drainage_area)

# %%
plt.imshow(watershed_D8, cmap="gist_earth_r", vmax = 100);
plt.colorbar();

# %%
watershed_dem = np.multiply(watershed_mask, input_DEM)

# %%
plt.imshow(watershed_dem, cmap="gist_earth_r", vmin = 240);
plt.colorbar();

# %%
flow_acc_surf = np.copy(watershed_dem).astype('float64');
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg2 = RasterModelGrid((rows,cols), 1);
z2 = mg2.add_field('topographic__elevation', flow_acc_surf, at = 'node');

# %%
mg2.set_watershed_boundary_condition(z2,0)

# %%
imshow_grid(mg2, mg2.status_at_node, color_for_closed='blue')

# %%
sfb = SinkFillerBarnes(mg2, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();

# %%
run_time = 1800          # duration of run, (s)
storm_duration = 1200.0
h_init = 0.0001              # initial thin layer of water (m)
n = 0.01                  # roughness coefficient, (s/m^(1/3))
g = 9.8                   # gravity (m/s^2)
alpha = 0.7               # time-step factor (nondimensional; from Bates et al., 2010)
u = 0.4                   # constant velocity (m/s, de Almeida et al., 2012)
run_time_slices = (300,600,1200)

# %%
elapsed_time = 0.0

# %%
#for stability in steeper environments, set the steep_slopes flag to True
#
rain_mm_p_h = 20
of = OverlandFlow(mg2, steep_slopes=True , rainfall_intensity = rain_mm_p_h/3600/1000)

# %%
outlet_link = mg2.links_at_node[outlet_id][0]

# %%
outlet_id
# Out:
# 35234

# %%
mg2.nodes_at_link[outlet_link]
# Out:
# array([35234, 35235])

# %%
mg2.at_node.keys()
# Out:
# dict_keys(['topographic__elevation', 'sediment_fill__depth', 'surface_water__depth'])

# %%
hydrograph_time = []
discharge_at_outlet = []
water_depth_at_outlet = []

# %%
while elapsed_time < run_time:
    hydrograph_time.append(elapsed_time / 3600.)  # convert seconds to hours
    # First, we calculate our time step.
    dt = of.calc_time_step()
    if elapsed_time < (storm_duration):
        of.rainfall_intensity =  rain_mm_p_h/3600/1000
    else:
            of.rainfall_intensity = 0.0
    # Now, we can generate overland flow.
    of.overland_flow()
    discharge_at_outlet.append(np.abs(of.q[outlet_link]) * mg2.dx) # append discharge in m^3/s
    water_depth_at_outlet.append(np.abs(mg2.at_node['surface_water__depth'][35235])) 
    # append depth in m.
    # Increased elapsed time
    print('Elapsed time: ', elapsed_time)
    elapsed_time += dt
# Out:
# Elapsed time:  0.0
# Elapsed time:  0.986876124875
# Elapsed time:  1.9303584626
# Elapsed time:  2.85854127576
# Elapsed time:  3.80329811184
# Elapsed time:  4.78363938642
# Elapsed time:  5.77263660949
# Elapsed time:  6.76551666454
# Elapsed time:  7.76650470298
# Elapsed time:  8.76108799003
# Elapsed time:  9.74147931743
# Elapsed time:  10.7156155876
# Elapsed time:  11.6919945721
# Elapsed time:  12.6760370448
# Elapsed time:  13.6682763594
# Elapsed time:  14.664759452
# Elapsed time:  15.6624072457
# Elapsed time:  16.6569719279
# Elapsed time:  17.6474581645
# Elapsed time:  18.6354407038
# Elapsed time:  19.6233422544
# Elapsed time:  20.6133467123
# Elapsed time:  21.6062594908
# Elapsed time:  22.6017425787
# Elapsed time:  23.5984869811
# Elapsed time:  24.5952987419
# Elapsed time:  25.5914002057
# Elapsed time:  26.5869532832
# Elapsed time:  27.5824846287
# Elapsed time:  28.5787868787
# Elapsed time:  29.5762169326
# Elapsed time:  30.5749090476
# Elapsed time:  31.574492315
# Elapsed time:  32.5746432573
# Elapsed time:  33.5749467748
# Elapsed time:  34.575378452
# Elapsed time:  35.575931978
# Elapsed time:  36.5768784262
# Elapsed time:  37.5782799256
# Elapsed time:  38.5802794318
# Elapsed time:  39.5827208802
# Elapsed time:  40.5855651328
# Elapsed time:  41.5885821738
# Elapsed time:  42.5917794099
# Elapsed time:  43.5950388717
# Elapsed time:  44.598480352
# Elapsed time:  45.6020441661
# Elapsed time:  46.6058450486
# Elapsed time:  47.609772862
# Elapsed time:  48.6138855328
# Elapsed time:  49.6180374355
# Elapsed time:  50.6222874878
# Elapsed time:  51.626517623
# Elapsed time:  52.6308247472
# Elapsed time:  53.6351188974
# Elapsed time:  54.6395074857
# Elapsed time:  55.6438933656
# Elapsed time:  56.6483692699
# Elapsed time:  57.6528248654
# Elapsed time:  58.6573488259
# Elapsed time:  59.6618355302
# Elapsed time:  60.6663840854
# Elapsed time:  61.6708986677
# Elapsed time:  62.6754840611
# Elapsed time:  63.6800443022
# Elapsed time:  64.6846803324
# Elapsed time:  65.6892911725
# Elapsed time:  66.6939745199
# Elapsed time:  67.6986286721
# Elapsed time:  68.703352925
# Elapsed time:  69.7080477917
# Elapsed time:  70.7128141554
# Elapsed time:  71.717552533
# Elapsed time:  72.7223624609
# Elapsed time:  73.7271423652
# Elapsed time:  74.7319898712
# Elapsed time:  75.7368021783
# Elapsed time:  76.7416764762
# Elapsed time:  77.7465100274
# Elapsed time:  78.7514000917
# Elapsed time:  79.7562437519
# Elapsed time:  80.7611376121
# Elapsed time:  81.7659779129
# Elapsed time:  82.770860264
# Elapsed time:  83.7756802141
# Elapsed time:  84.7805327907
# Elapsed time:  85.7853133653
# Elapsed time:  86.7901166971
# Elapsed time:  87.7948381097
# Elapsed time:  88.799571985
# Elapsed time:  89.8042134818
# Elapsed time:  90.8088564952
# Elapsed time:  91.8133960881
# Elapsed time:  92.8179257979
# Elapsed time:  93.8223408402
# Elapsed time:  94.8267345597
# Elapsed time:  95.8310024925
# Elapsed time:  96.8352378314
# Elapsed time:  97.8393364985
# Elapsed time:  98.8433915389
# Elapsed time:  99.8472993554
# Elapsed time:  100.851152915
# Elapsed time:  101.854849252
# Elapsed time:  102.858481348
# Elapsed time:  103.861947006
# Elapsed time:  104.865339277
# Elapsed time:  105.868556819
# Elapsed time:  106.871692781
# Elapsed time:  107.874646754
# Elapsed time:  108.877512012
# Elapsed time:  109.880189159
# Elapsed time:  110.882771632
# Elapsed time:  111.885161109
# Elapsed time:  112.887451203
# Elapsed time:  113.889544705
# Elapsed time:  114.891535398
# Elapsed time:  115.893327198
# Elapsed time:  116.895014046
# Elapsed time:  117.896500983
# Elapsed time:  118.897882085
# Elapsed time:  119.899063505
# Elapsed time:  120.900139421
# Elapsed time:  121.901017068
# Elapsed time:  122.901790685
# Elapsed time:  123.90236854
# Elapsed time:  124.902844882
# Elapsed time:  125.903128957
# Elapsed time:  126.903314975
# Elapsed time:  127.903313091
# Elapsed time:  128.903217427
# Elapsed time:  129.902938974
# Elapsed time:  130.902571709
# Elapsed time:  131.902027382
# Elapsed time:  132.901399771
# Elapsed time:  133.9006013
# Elapsed time:  134.899725489
# Elapsed time:  135.898685345
# Elapsed time:  136.897574077
# Elapsed time:  137.896305185
# Elapsed time:  138.894971514
# Elapsed time:  139.893486973
# Elapsed time:  140.891944001
# Elapsed time:  141.890256837
# Elapsed time:  142.888530492
# Elapsed time:  143.886677392
# Elapsed time:  144.884779151
# Elapsed time:  145.882746998
# Elapsed time:  146.880673612
# Elapsed time:  147.878473334
# Elapsed time:  148.876248611
# Elapsed time:  149.873912886
# Elapsed time:  150.871547989
# Elapsed time:  151.869065801
# Elapsed time:  152.866570342
# Elapsed time:  153.863973453
# Elapsed time:  154.861352641
# Elapsed time:  155.858619798
# Elapsed time:  156.855880661
# Elapsed time:  157.853048443
# Elapsed time:  158.850199724
# Elapsed time:  159.847259758
# Elapsed time:  160.844317488
# Elapsed time:  161.841277726
# Elapsed time:  162.838235622
# Elapsed time:  163.835106163
# Elapsed time:  164.831981372
# Elapsed time:  165.828769936
# Elapsed time:  166.825550037
# Elapsed time:  167.822247855
# Elapsed time:  168.818948466
# Elapsed time:  169.815570265
# Elapsed time:  170.812192824
# Elapsed time:  171.808724371
# Elapsed time:  172.805261181
# Elapsed time:  173.801717283
# Elapsed time:  174.798181013
# Elapsed time:  175.794562243
# Elapsed time:  176.790952434
# Elapsed time:  177.787262143
# Elapsed time:  178.783580444
# Elapsed time:  179.779816675
# Elapsed time:  180.776061264
# Elapsed time:  181.772224417
# Elapsed time:  182.768396443
# Elapsed time:  183.76448722
# Elapsed time:  184.760587194
# Elapsed time:  185.756606161
# Elapsed time:  186.752634353
# Elapsed time:  187.748581422
# Elapsed time:  188.744537763
# Elapsed time:  189.740413206
# Elapsed time:  190.736298266
# Elapsed time:  191.732102813
# Elapsed time:  192.727917376
# Elapsed time:  193.723651805
# Elapsed time:  194.719396576
# Elapsed time:  195.715061523
# Elapsed time:  196.710737126
# Elapsed time:  197.706333277
# Elapsed time:  198.701940481
# Elapsed time:  199.697468671
# Elapsed time:  200.693008343
# Elapsed time:  201.688469433
# Elapsed time:  202.683942397
# Elapsed time:  203.679337167
# Elapsed time:  204.67474416
# Elapsed time:  205.670073316
# Elapsed time:  206.665415023
# Elapsed time:  207.660679221
# Elapsed time:  208.655956253
# Elapsed time:  209.651156044
# Elapsed time:  210.646368875
# Elapsed time:  211.64150464
# Elapsed time:  212.636653552
# Elapsed time:  213.631725472
# Elapsed time:  214.626810544
# Elapsed time:  215.62181859
# Elapsed time:  216.616839678
# Elapsed time:  217.611783581
# Elapsed time:  218.606740285
# Elapsed time:  219.601619509
# Elapsed time:  220.596511154
# Elapsed time:  221.591324879
# Elapsed time:  222.586150501
# Elapsed time:  223.580897621
# Elapsed time:  224.575655973
# Elapsed time:  225.570335099
# Elapsed time:  226.565024649
# Elapsed time:  227.559634108
# Elapsed time:  228.554253046
# Elapsed time:  229.548790895
# Elapsed time:  230.543337148
# Elapsed time:  231.537801188
# Elapsed time:  232.532272438
# Elapsed time:  233.526660237
# Elapsed time:  234.521053943
# Elapsed time:  235.51536286
# Elapsed time:  236.509676284
# Elapsed time:  237.503903495
# Elapsed time:  238.498133733
# Elapsed time:  239.492276261
# Elapsed time:  240.48642027
# Elapsed time:  241.480475016
# Elapsed time:  242.47452965
# Elapsed time:  243.468493427
# Elapsed time:  244.462455464
# Elapsed time:  245.45632503
# Elapsed time:  246.450191207
# Elapsed time:  247.443963288
# Elapsed time:  248.437730329
# Elapsed time:  249.431401651
# Elapsed time:  250.425066287
# Elapsed time:  251.418633597
# Elapsed time:  252.412192591
# Elapsed time:  253.405652673
# Elapsed time:  254.399102832
# Elapsed time:  255.392452523
# Elapsed time:  256.385790711
# Elapsed time:  257.379026905
# Elapsed time:  258.372250047
# Elapsed time:  259.365369705
# Elapsed time:  260.358474792
# Elapsed time:  261.351474938
# Elapsed time:  262.344459024
# Elapsed time:  263.337336746
# Elapsed time:  264.330196949
# Elapsed time:  265.322949394
# Elapsed time:  266.315682887
# Elapsed time:  267.308307256
# Elapsed time:  268.300911264
# Elapsed time:  269.293404807
# Elapsed time:  270.285876598
# Elapsed time:  271.278236603
# Elapsed time:  272.270573481
# Elapsed time:  273.26279727
# Elapsed time:  274.254996569
# Elapsed time:  275.247081487
# Elapsed time:  276.239140559
# Elapsed time:  277.231083968
# Elapsed time:  278.223000179
# Elapsed time:  279.214799448
# Elapsed time:  280.206570167
# Elapsed time:  281.198222666
# Elapsed time:  282.189845257
# Elapsed time:  283.181348346
# Elapsed time:  284.172820162
# Elapsed time:  285.164171187
# Elapsed time:  286.15548956
# Elapsed time:  287.146685843
# Elapsed time:  288.137848079
# Elapsed time:  289.12888691
# Elapsed time:  290.119890282
# Elapsed time:  291.110768916
# Elapsed time:  292.101610656
# Elapsed time:  293.092326305
# Elapsed time:  294.0830036
# Elapsed time:  295.073553428
# Elapsed time:  296.064063417
# Elapsed time:  297.054444536
# Elapsed time:  298.044784302
# Elapsed time:  299.034993769
# Elapsed time:  300.025160339
# Elapsed time:  301.015195154
# Elapsed time:  302.005185495
# Elapsed time:  302.995042597
# Elapsed time:  303.984853616
# Elapsed time:  304.974529883
# Elapsed time:  305.964158427
# Elapsed time:  306.953650676
# Elapsed time:  307.943093531
# Elapsed time:  308.932398519
# Elapsed time:  309.921652409
# Elapsed time:  310.910766834
# Elapsed time:  311.899828432
# Elapsed time:  312.888748945
# Elapsed time:  313.877614884
# Elapsed time:  314.866338113
# Elapsed time:  315.85500502
# Elapsed time:  316.843527597
# Elapsed time:  317.831992103
# Elapsed time:  318.820310663
# Elapsed time:  319.808569401
# Elapsed time:  320.796680571
# Elapsed time:  321.784730157
# Elapsed time:  322.77263054
# Elapsed time:  323.760467552
# Elapsed time:  324.748153698
# Elapsed time:  325.735774652
# Elapsed time:  326.723243044
# Elapsed time:  327.710644386
# Elapsed time:  328.697891436
# Elapsed time:  329.685069545
# Elapsed time:  330.672091608
# Elapsed time:  331.659042812
# Elapsed time:  332.645836189
# Elapsed time:  333.63255676
# Elapsed time:  334.619117707
# Elapsed time:  335.605603886
# Elapsed time:  336.591928634
# Elapsed time:  337.578176649
# Elapsed time:  338.564261431
# Elapsed time:  339.550267513
# Elapsed time:  340.536108559
# Elapsed time:  341.52186893
# Elapsed time:  342.50746246
# Elapsed time:  343.49297334
# Elapsed time:  344.478315577
# Elapsed time:  345.46357319
# Elapsed time:  346.448660365
# Elapsed time:  347.433660944
# Elapsed time:  348.418489291
# Elapsed time:  349.403229063
# Elapsed time:  350.387794805
# Elapsed time:  351.37226999
# Elapsed time:  352.356569354
# Elapsed time:  353.340776187
# Elapsed time:  354.32480542
# Elapsed time:  355.308740154
# Elapsed time:  356.292495519
# Elapsed time:  357.276154423
# Elapsed time:  358.259632197
# Elapsed time:  359.24301156
# Elapsed time:  360.226208055
# Elapsed time:  361.209304213
# Elapsed time:  362.192215797
# Elapsed time:  363.17502515
# Elapsed time:  364.157648263
# Elapsed time:  365.140167288
# Elapsed time:  366.122498455
# Elapsed time:  367.104723724
# Elapsed time:  368.086775045
# Elapsed time:  369.068717648
# Elapsed time:  370.050472386
# Elapsed time:  371.032127223
# Elapsed time:  372.013594139
# Elapsed time:  372.994946626
# Elapsed time:  373.976118493
# Elapsed time:  374.957191301
# Elapsed time:  375.938069728
# Elapsed time:  376.918828266
# Elapsed time:  377.899403392
# Elapsed time:  378.879874936
# Elapsed time:  379.86016312
# Elapsed time:  380.840341604
# Elapsed time:  381.820335995
# Elapsed time:  382.800219926
# Elapsed time:  383.779914626
# Elapsed time:  384.759492938
# Elapsed time:  385.738879583
# Elapsed time:  386.718148372
# Elapsed time:  387.697223487
# Elapsed time:  388.676177876
# Elapsed time:  389.654935917
# Elapsed time:  390.633570119
# Elapsed time:  391.612004821
# Elapsed time:  392.590312283
# Elapsed time:  393.568417629
# Elapsed time:  394.546393141
# Elapsed time:  395.524164275
# Elapsed time:  396.50180305
# Elapsed time:  397.479235173
# Elapsed time:  398.456532337
# Elapsed time:  399.433620547
# Elapsed time:  400.410571226
# Elapsed time:  401.387310788
# Elapsed time:  402.363910482
# Elapsed time:  403.340297101
# Elapsed time:  404.316541698
# Elapsed time:  405.292571436
# Elapsed time:  406.268457124
# Elapsed time:  407.244126292
# Elapsed time:  408.219649503
# Elapsed time:  409.194954666
# Elapsed time:  410.170112137
# Elapsed time:  411.145050226
# Elapsed time:  412.119839103
# Elapsed time:  413.094407494
# Elapsed time:  414.068825376
# Elapsed time:  415.043021893
# Elapsed time:  416.01706684
# Elapsed time:  416.990889801
# Elapsed time:  417.964560435
# Elapsed time:  418.938008817
# Elapsed time:  419.911304523
# Elapsed time:  420.884378174
# Elapsed time:  421.857299297
# Elapsed time:  422.829999094
# Elapsed time:  423.802547064
# Elapsed time:  424.774875022
# Elapsed time:  425.747052462
# Elapsed time:  426.71901184
# Elapsed time:  427.690822641
# Elapsed time:  428.66241797
# Elapsed time:  429.633867273
# Elapsed time:  430.605104279
# Elapsed time:  431.57619834
# Elapsed time:  432.547083767
# Elapsed time:  433.517829737
# Elapsed time:  434.488371077
# Elapsed time:  435.458776694
# Elapsed time:  436.42898185
# Elapsed time:  437.399055081
# Elapsed time:  438.368931993
# Elapsed time:  439.338680647
# Elapsed time:  440.308236897
# Elapsed time:  441.27766823
# Elapsed time:  442.246910648
# Elapsed time:  443.216030984
# Elapsed time:  444.184965349
# Elapsed time:  445.153779801
# Elapsed time:  446.122410549
# Elapsed time:  447.090955413
# Elapsed time:  448.059380868
# Elapsed time:  449.027759934
# Elapsed time:  449.996023609
# Elapsed time:  450.96424311
# Elapsed time:  451.932367346
# Elapsed time:  452.900471299
# Elapsed time:  453.868495146
# Elapsed time:  454.836494218
# Elapsed time:  455.804388563
# Elapsed time:  456.772223246
# Elapsed time:  457.739925159
# Elapsed time:  458.707548349
# Elapsed time:  459.675027556
# Elapsed time:  460.642414955
# Elapsed time:  461.609639067
# Elapsed time:  462.576744391
# Elapsed time:  463.543655692
# Elapsed time:  464.510417882
# Elapsed time:  465.476961768
# Elapsed time:  466.443337063
# Elapsed time:  467.409481084
# Elapsed time:  468.375444401
# Elapsed time:  469.341165846
# Elapsed time:  470.306693832
# Elapsed time:  471.27196803
# Elapsed time:  472.237036259
# Elapsed time:  473.201841426
# Elapsed time:  474.166432214
# Elapsed time:  475.130755361
# Elapsed time:  476.094858987
# Elapsed time:  477.058692241
# Elapsed time:  478.022301012
# Elapsed time:  478.985636243
# Elapsed time:  479.94874162
# Elapsed time:  480.911570598
# Elapsed time:  481.874165206
# Elapsed time:  482.836481905
# Elapsed time:  483.7985608
# Elapsed time:  484.760361147
# Elapsed time:  485.721920432
# Elapsed time:  486.683200566
# Elapsed time:  487.644236123
# Elapsed time:  488.604991957
# Elapsed time:  489.565499786
# Elapsed time:  490.525727757
# Elapsed time:  491.485704628
# Elapsed time:  492.445402006
# Elapsed time:  493.404845385
# Elapsed time:  494.364009945
# Elapsed time:  495.322917671
# Elapsed time:  496.281547528
# Elapsed time:  497.239917856
# Elapsed time:  498.198011631
# Elapsed time:  499.155843387
# Elapsed time:  500.113400279
# Elapsed time:  501.07069279
# Elapsed time:  502.027712439
# Elapsed time:  502.984465412
# Elapsed time:  503.94094784
# Elapsed time:  504.897161421
# Elapsed time:  505.853107111
# Elapsed time:  506.808781936
# Elapsed time:  507.764191823
# Elapsed time:  508.719328905
# Elapsed time:  509.674195977
# Elapsed time:  510.628774004
# Elapsed time:  511.583077014
# Elapsed time:  512.537090502
# Elapsed time:  513.490839596
# Elapsed time:  514.444308176
# Elapsed time:  515.397529325
# Elapsed time:  516.350480977
# Elapsed time:  517.303190294
# Elapsed time:  518.255619674
# Elapsed time:  519.207805875
# Elapsed time:  520.159714432
# Elapsed time:  521.11139384
# Elapsed time:  522.062807843
# Elapsed time:  523.014005778
# Elapsed time:  523.964938632
# Elapsed time:  524.915663656
# Elapsed time:  525.86613052
# Elapsed time:  526.816405144
# Elapsed time:  527.766435519
# Elapsed time:  528.716283248
# Elapsed time:  529.665887306
# Elapsed time:  530.615313178
# Elapsed time:  531.564503176
# Elapsed time:  532.513525829
# Elapsed time:  533.462323364
# Elapsed time:  534.41095746
# Elapsed time:  535.359361557
# Elapsed time:  536.307599772
# Elapsed time:  537.255609631
# Elapsed time:  538.203457522
# Elapsed time:  539.151081559
# Elapsed time:  540.098540793
# Elapsed time:  541.045765247
# Elapsed time:  541.992816125
# Elapsed time:  542.939628206
# Elapsed time:  543.886256797
# Elapsed time:  544.832631568
# Elapsed time:  545.7788151
# Elapsed time:  546.724745608
# Elapsed time:  547.670479334
# Elapsed time:  548.615947364
# Elapsed time:  549.561211214
# Elapsed time:  550.506209284
# Elapsed time:  551.45099594
# Elapsed time:  552.395502753
# Elapsed time:  553.339790306
# Elapsed time:  554.283798474
# Elapsed time:  555.227581143
# Elapsed time:  556.171071588
# Elapsed time:  557.114330119
# Elapsed time:  558.057298797
# Elapsed time:  559.00003205
# Elapsed time:  559.942465973
# Elapsed time:  560.884662497
# Elapsed time:  561.826566787
# Elapsed time:  562.768234906
# Elapsed time:  563.709605679
# Elapsed time:  564.650742129
# Elapsed time:  565.591591493
# Elapsed time:  566.532210399
# Elapsed time:  567.47253915
# Elapsed time:  568.412640656
# Elapsed time:  569.352462818
# Elapsed time:  570.292061367
# Elapsed time:  571.231376483
# Elapsed time:  572.170469511
# Elapsed time:  573.109287641
# Elapsed time:  574.047884633
# Elapsed time:  574.986199625
# Elapsed time:  575.924291829
# Elapsed time:  576.862107262
# Elapsed time:  577.79969755
# Elapsed time:  578.737000697
# Elapsed time:  579.674073964
# Elapsed time:  580.610862433
# Elapsed time:  581.547416072
# Elapsed time:  582.483672249
# Elapsed time:  583.419686953
# Elapsed time:  584.355404479
# Elapsed time:  585.290873251
# Elapsed time:  586.226030033
# Elapsed time:  587.160929865
# Elapsed time:  588.095517473
# Elapsed time:  589.029841613
# Elapsed time:  589.963839756
# Elapsed time:  590.897567117
# Elapsed time:  591.830969263
# Elapsed time:  592.764095432
# Elapsed time:  593.696884155
# Elapsed time:  594.629383252
# Elapsed time:  595.561533104
# Elapsed time:  596.49339006
# Elapsed time:  597.424903291
# Elapsed time:  598.356126678
# Elapsed time:  599.287004826
# Elapsed time:  600.217596618
# Elapsed time:  601.14785137
# Elapsed time:  602.077819448
# Elapsed time:  603.007441867
# Elapsed time:  603.936766786
# Elapsed time:  604.865736901
# Elapsed time:  605.794409143
# Elapsed time:  606.722735188
# Elapsed time:  607.650769268
# Elapsed time:  608.578457463
# Elapsed time:  609.505849923
# Elapsed time:  610.432890587
# Elapsed time:  611.359635388
# Elapsed time:  612.286035879
# Elapsed time:  613.212145113
# Elapsed time:  614.137909778
# Elapsed time:  615.06338006
# Elapsed time:  615.988501271
# Elapsed time:  616.91332943
# Elapsed time:  617.837816949
# Elapsed time:  618.762016456
# Elapsed time:  619.685875172
# Elapsed time:  620.609442797
# Elapsed time:  621.532665376
# Elapsed time:  622.455598628
# Elapsed time:  623.378195822
# Elapsed time:  624.300509147
# Elapsed time:  625.222486413
# Elapsed time:  626.144176478
# Elapsed time:  627.065525653
# Elapsed time:  627.986588537
# Elapsed time:  628.907318537
# Elapsed time:  629.827766681
# Elapsed time:  630.747880927
# Elapsed time:  631.667708963
# Elapsed time:  632.587197219
# Elapsed time:  633.506391314
# Elapsed time:  634.425238458
# Elapsed time:  635.343794785
# Elapsed time:  636.262017567
# Elapsed time:  637.179958454
# Elapsed time:  638.097566809
# Elapsed time:  639.014888974
# Elapsed time:  639.931871356
# Elapsed time:  640.848557363
# Elapsed time:  641.764894233
# Elapsed time:  642.680928979
# Elapsed time:  643.596613396
# Elapsed time:  644.511996857
# Elapsed time:  645.427032926
# Elapsed time:  646.341771338
# Elapsed time:  647.256166565
# Elapsed time:  648.170268124
# Elapsed time:  649.084031775
# Elapsed time:  649.997507469
# Elapsed time:  650.910652659
# Elapsed time:  651.823517351
# Elapsed time:  652.736089411
# Elapsed time:  653.648434589
# Elapsed time:  654.560511641
# Elapsed time:  655.472368063
# Elapsed time:  656.383969905
# Elapsed time:  657.295363335
# Elapsed time:  658.206499672
# Elapsed time:  659.117411762
# Elapsed time:  660.028048179
# Elapsed time:  660.938439398
# Elapsed time:  661.848533749
# Elapsed time:  662.758363864
# Elapsed time:  663.667884677
# Elapsed time:  664.577132061
# Elapsed time:  665.486063041
# Elapsed time:  666.394712582
# Elapsed time:  667.303038236
# Elapsed time:  668.211073558
# Elapsed time:  669.118776801
# Elapsed time:  670.026181265
# Elapsed time:  670.933247261
# Elapsed time:  671.84000818
# Elapsed time:  672.746425773
# Elapsed time:  673.652532658
# Elapsed time:  674.558291408
# Elapsed time:  675.463733597
# Elapsed time:  676.36882275
# Elapsed time:  677.27358985
# Elapsed time:  678.177999882
# Elapsed time:  679.082083539
# Elapsed time:  679.985807294
# Elapsed time:  680.889201419
# Elapsed time:  681.792233682
# Elapsed time:  682.694933806
# Elapsed time:  683.597270823
# Elapsed time:  684.499273988
# Elapsed time:  685.400913684
# Elapsed time:  686.302218775
# Elapsed time:  687.203160974
# Elapsed time:  688.103768724
# Elapsed time:  689.004015051
# Elapsed time:  689.903928165
# Elapsed time:  690.803482777
# Elapsed time:  691.70270745
# Elapsed time:  692.601579091
# Elapsed time:  693.500126942
# Elapsed time:  694.398330067
# Elapsed time:  695.296218118
# Elapsed time:  696.193771888
# Elapsed time:  697.091021076
# Elapsed time:  697.987947839
# Elapsed time:  698.884581627
# Elapsed time:  699.780905496
# Elapsed time:  700.676948117
# Elapsed time:  701.572692763
# Elapsed time:  702.468165645
# Elapsed time:  703.363349427
# Elapsed time:  704.258267222
# Elapsed time:  705.152900913
# Elapsed time:  706.047270812
# Elapsed time:  706.941358304
# Elapsed time:  707.835180922
# Elapsed time:  708.728719216
# Elapsed time:  709.621987768
# Elapsed time:  710.514966332
# Elapsed time:  711.407667064
# Elapsed time:  712.300069645
# Elapsed time:  713.192184782
# Elapsed time:  714.083992853
# Elapsed time:  714.975503754
# Elapsed time:  715.866698785
# Elapsed time:  716.757587188
# Elapsed time:  717.648151116
# Elapsed time:  718.538399223
# Elapsed time:  719.428314514
# Elapsed time:  720.317905231
# Elapsed time:  721.207155308
# Elapsed time:  722.096072739
# Elapsed time:  722.984642407
# Elapsed time:  723.872872055
# Elapsed time:  724.760747164
# Elapsed time:  725.648274928
# Elapsed time:  726.5354415
# Elapsed time:  727.4222543
# Elapsed time:  728.308700808
# Elapsed time:  729.194788644
# Elapsed time:  730.08050587
# Elapsed time:  730.965859751
# Elapsed time:  731.850839044
# Elapsed time:  732.735451483
# Elapsed time:  733.619687285
# Elapsed time:  734.503554908
# Elapsed time:  735.387045664
# Elapsed time:  736.270168271
# Elapsed time:  737.152914875
# Elapsed time:  738.035294577
# Elapsed time:  738.91730059
# Elapsed time:  739.798942578
# Elapsed time:  740.680214761
# Elapsed time:  741.5611272
# Elapsed time:  742.441674872
# Elapsed time:  743.321868055
# Elapsed time:  744.201702339
# Elapsed time:  745.081188158
# Elapsed time:  745.960321642
# Elapsed time:  746.839113336
# Elapsed time:  747.717559809
# Elapsed time:  748.595671623
# Elapsed time:  749.47344565
# Elapsed time:  750.350892363
# Elapsed time:  751.228008828
# Elapsed time:  752.104805371
# Elapsed time:  752.981279188
# Elapsed time:  753.857440425
# Elapsed time:  754.733286357
# Elapsed time:  755.608826924
# Elapsed time:  756.484059444
# Elapsed time:  757.358993648
# Elapsed time:  758.233626894
# Elapsed time:  759.107968737
# Elapsed time:  759.982016608
# Elapsed time:  760.855783238
# Elapsed time:  761.729266015
# Elapsed time:  762.60247382
# Elapsed time:  763.475402037
# Elapsed time:  764.348060169
# Elapsed time:  765.220444802
# Elapsed time:  766.09256601
# Elapsed time:  766.9644213
# Elapsed time:  767.836021331
# Elapsed time:  768.707363479
# Elapsed time:  769.578457485
# Elapsed time:  770.449300088
# Elapsed time:  771.319900582
# Elapsed time:  772.190255588
# Elapsed time:  773.060374197
# Elapsed time:  773.930252988
# Elapsed time:  774.799900722
# Elapsed time:  775.669313524
# Elapsed time:  776.53849937
# Elapsed time:  777.407453672
# Elapsed time:  778.276183577
# Elapsed time:  779.144683841
# Elapsed time:  780.012960878
# Elapsed time:  780.881008864
# Elapsed time:  781.748833497
# Elapsed time:  782.616428322
# Elapsed time:  783.483798274
# Elapsed time:  784.35093626
# Elapsed time:  785.217846509
# Elapsed time:  786.084521402
# Elapsed time:  786.950964604
# Elapsed time:  787.81716812
# Elapsed time:  788.683135196
# Elapsed time:  789.548857581
# Elapsed time:  790.414338222
# Elapsed time:  791.279568735
# Elapsed time:  792.144551901
# Elapsed time:  793.009279345
# Elapsed time:  793.873753827
# Elapsed time:  794.737967126
# Elapsed time:  795.601922115
# Elapsed time:  796.465610845
# Elapsed time:  797.32903641
# Elapsed time:  798.192191226
# Elapsed time:  799.055078694
# Elapsed time:  799.917691677
# Elapsed time:  800.780033951
# Elapsed time:  801.642098884
# Elapsed time:  802.50389068
# Elapsed time:  803.36540325
# Elapsed time:  804.22664125
# Elapsed time:  805.087599149
# Elapsed time:  805.948282059
# Elapsed time:  806.808685008
# Elapsed time:  807.668813556
# Elapsed time:  808.52866327
# Elapsed time:  809.388240138
# Elapsed time:  810.247540237
# Elapsed time:  811.106569949
# Elapsed time:  811.965325823
# Elapsed time:  812.823814592
# Elapsed time:  813.682033231
# Elapsed time:  814.539988779
# Elapsed time:  815.397678588
# Elapsed time:  816.255109948
# Elapsed time:  817.112280538
# Elapsed time:  817.969197852
# Elapsed time:  818.825859838
# Elapsed time:  819.682274146
# Elapsed time:  820.538438945
# Elapsed time:  821.394361987
# Elapsed time:  822.250041612
# Elapsed time:  823.105485633
# Elapsed time:  823.960692515
# Elapsed time:  824.815670088
# Elapsed time:  825.670416899
# Elapsed time:  826.524940759
# Elapsed time:  827.379240259
# Elapsed time:  828.233322406
# Elapsed time:  829.087183311
# Elapsed time:  829.940826128
# Elapsed time:  830.794243663
# Elapsed time:  831.647437387
# Elapsed time:  832.50040011
# Elapsed time:  833.353134345
# Elapsed time:  834.205634637
# Elapsed time:  835.057905302
# Elapsed time:  835.909942282
# Elapsed time:  836.761750557
# Elapsed time:  837.613326484
# Elapsed time:  838.464675733
# Elapsed time:  839.315796459
# Elapsed time:  840.166696863
# Elapsed time:  841.017377593
# Elapsed time:  841.867848504
# Elapsed time:  842.718110875
# Elapsed time:  843.568174313
# Elapsed time:  844.418039782
# Elapsed time:  845.267716869
# Elapsed time:  846.117207102
# Elapsed time:  846.966520818
# Elapsed time:  847.815660178
# Elapsed time:  848.664635661
# Elapsed time:  849.513449095
# Elapsed time:  850.362110156
# Elapsed time:  851.210619779
# Elapsed time:  852.058986759
# Elapsed time:  852.907211406
# Elapsed time:  853.75530203
# Elapsed time:  854.60325857
# Elapsed time:  855.451088863
# Elapsed time:  856.298792206
# Elapsed time:  857.146375489
# Elapsed time:  857.993837049
# Elapsed time:  858.84118293
# Elapsed time:  859.688410911
# Elapsed time:  860.535526653
# Elapsed time:  861.382527722
# Elapsed time:  862.229419572
# Elapsed time:  863.076199463
# Elapsed time:  863.922872275
# Elapsed time:  864.76943466
# Elapsed time:  865.615891001
# Elapsed time:  866.462237755
# Elapsed time:  867.308479311
# Elapsed time:  868.154612198
# Elapsed time:  869.000640696
# Elapsed time:  869.846561105
# Elapsed time:  870.692377404
# Elapsed time:  871.538085693
# Elapsed time:  872.383689871
# Elapsed time:  873.229186115
# Elapsed time:  874.074578332
# Elapsed time:  874.919862607
# Elapsed time:  875.765042759
# Elapsed time:  876.610115
# Elapsed time:  877.455083333
# Elapsed time:  878.299944071
# Elapsed time:  879.144701235
# Elapsed time:  879.989351312
# Elapsed time:  880.833898675
# Elapsed time:  881.678340342
# Elapsed time:  882.522681174
# Elapsed time:  883.366918561
# Elapsed time:  884.211057638
# Elapsed time:  885.055096137
# Elapsed time:  885.899039592
# Elapsed time:  886.742886228
# Elapsed time:  887.586642032
# Elapsed time:  888.430305623
# Elapsed time:  889.273883292
# Elapsed time:  890.117373949
# Elapsed time:  890.960784105
# Elapsed time:  891.804112877
# Elapsed time:  892.64736691
# Elapsed time:  893.490545394
# Elapsed time:  894.33365495
# Elapsed time:  895.176694707
# Elapsed time:  896.019671108
# Elapsed time:  896.862583054
# Elapsed time:  897.705436672
# Elapsed time:  898.548230417
# Elapsed time:  899.39096978
# Elapsed time:  900.233652623
# Elapsed time:  901.076284009
# Elapsed time:  901.918861433
# Elapsed time:  902.761389316
# Elapsed time:  903.603864259
# Elapsed time:  904.446289855
# Elapsed time:  905.288662261
# Elapsed time:  906.130984806
# Elapsed time:  906.973253157
# Elapsed time:  907.815469702
# Elapsed time:  908.65762903
# Elapsed time:  909.499732734
# Elapsed time:  910.341775099
# Elapsed time:  911.18375768
# Elapsed time:  912.025674661
# Elapsed time:  912.867527226
# Elapsed time:  913.709309066
# Elapsed time:  914.551020956
# Elapsed time:  915.392656432
# Elapsed time:  916.234216319
# Elapsed time:  917.075694316
# Elapsed time:  917.917091397
# Elapsed time:  918.758401385
# Elapsed time:  919.599625335
# Elapsed time:  920.440757169
# Elapsed time:  921.281798058
# Elapsed time:  922.122742106
# Elapsed time:  922.963590717
# Elapsed time:  923.804338295
# Elapsed time:  924.644986567
# Elapsed time:  925.485530282
# Elapsed time:  926.325971471
# Elapsed time:  927.16630518
# Elapsed time:  928.006533703
# Elapsed time:  928.846652361
# Elapsed time:  929.686663719
# Elapsed time:  930.526563405
# Elapsed time:  931.366354288
# Elapsed time:  932.206032314
# Elapsed time:  933.045600641
# Elapsed time:  933.885055501
# Elapsed time:  934.724400293
# Elapsed time:  935.563631493
# Elapsed time:  936.40275271
# Elapsed time:  937.241760645
# Elapsed time:  938.08065911
# Elapsed time:  938.919445024
# Elapsed time:  939.758122384
# Elapsed time:  940.596688297
# Elapsed time:  941.43514691
# Elapsed time:  942.273495481
# Elapsed time:  943.11173827
# Elapsed time:  943.949872656
# Elapsed time:  944.78790299
# Elapsed time:  945.625826754
# Elapsed time:  946.463648375
# Elapsed time:  947.301365418
# Elapsed time:  948.138982361
# Elapsed time:  948.976496824
# Elapsed time:  949.813913309
# Elapsed time:  950.651229471
# Elapsed time:  951.488449818
# Elapsed time:  952.325572022
# Elapsed time:  953.162600585
# Elapsed time:  953.999533187
# Elapsed time:  954.836374309
# Elapsed time:  955.673121625
# Elapsed time:  956.509779587
# Elapsed time:  957.346345846
# Elapsed time:  958.182824813
# Elapsed time:  959.019214114
# Elapsed time:  959.855518113
# Elapsed time:  960.691734404
# Elapsed time:  961.527867303
# Elapsed time:  962.363914369
# Elapsed time:  963.199879864
# Elapsed time:  964.035761312
# Elapsed time:  964.87156292
# Elapsed time:  965.707282172
# Elapsed time:  966.542923225
# Elapsed time:  967.378483523
# Elapsed time:  968.213967172
# Elapsed time:  969.049371585
# Elapsed time:  969.884700816
# Elapsed time:  970.719952246
# Elapsed time:  971.555129886
# Elapsed time:  972.390231087
# Elapsed time:  973.225259817
# Elapsed time:  974.060213401
# Elapsed time:  974.895095771
# Elapsed time:  975.729904232
# Elapsed time:  976.564642681
# Elapsed time:  977.399308406
# Elapsed time:  978.233905277
# Elapsed time:  979.068430565
# Elapsed time:  979.902888118
# Elapsed time:  980.737275196
# Elapsed time:  981.571595626
# Elapsed time:  982.40584666
# Elapsed time:  983.24003211
# Elapsed time:  984.074149223
# Elapsed time:  984.908201797
# Elapsed time:  985.742187079
# Elapsed time:  986.576108853
# Elapsed time:  987.409964369
# Elapsed time:  988.243757402
# Elapsed time:  989.077485204
# Elapsed time:  989.911151542
# Elapsed time:  990.744753673
# Elapsed time:  991.57829536
# Elapsed time:  992.411773862
# Elapsed time:  993.245192938
# Elapsed time:  994.078549855
# Elapsed time:  994.911848366
# Elapsed time:  995.745085744
# Elapsed time:  996.57826574
# Elapsed time:  997.411385631
# Elapsed time:  998.244449165
# Elapsed time:  999.077453626
# Elapsed time:  999.910402758
# Elapsed time:  1000.74329385
# Elapsed time:  1001.57613064
# Elapsed time:  1002.40891042
# Elapsed time:  1003.24163693
# Elapsed time:  1004.07430747
# Elapsed time:  1004.90692576
# Elapsed time:  1005.7394891
# Elapsed time:  1006.57200122
# Elapsed time:  1007.40445941
# Elapsed time:  1008.2368674
# Elapsed time:  1009.06922248
# Elapsed time:  1009.90152837
# Elapsed time:  1010.73378235
# Elapsed time:  1011.56598814
# Elapsed time:  1012.39814302
# Elapsed time:  1013.23025069
# Elapsed time:  1014.06230843
# Elapsed time:  1014.89431993
# Elapsed time:  1015.72628247
# Elapsed time:  1016.55819972
# Elapsed time:  1017.39006896
# Elapsed time:  1018.22189384
# Elapsed time:  1019.05367163
# Elapsed time:  1019.88540598
# Elapsed time:  1020.71709415
# Elapsed time:  1021.54873976
# Elapsed time:  1022.38034008
# Elapsed time:  1023.2118987
# Elapsed time:  1024.04341288
# Elapsed time:  1024.87488621
# Elapsed time:  1025.70631592
# Elapsed time:  1026.5377056
# Elapsed time:  1027.36905247
# Elapsed time:  1028.20036008
# Elapsed time:  1029.03162566
# Elapsed time:  1029.86285275
# Elapsed time:  1030.69403855
# Elapsed time:  1031.52518659
# Elapsed time:  1032.35629406
# Elapsed time:  1033.18736447
# Elapsed time:  1034.018395
# Elapsed time:  1034.84938915
# Elapsed time:  1035.68034408
# Elapsed time:  1036.51126328
# Elapsed time:  1037.3421439
# Elapsed time:  1038.17298939
# Elapsed time:  1039.00379692
# Elapsed time:  1039.83456992
# Elapsed time:  1040.66530553
# Elapsed time:  1041.49600718
# Elapsed time:  1042.326672
# Elapsed time:  1043.1573034
# Elapsed time:  1043.9878985
# Elapsed time:  1044.8184607
# Elapsed time:  1045.64898711
# Elapsed time:  1046.47948112
# Elapsed time:  1047.30993982
# Elapsed time:  1048.14036659
# Elapsed time:  1048.97075853
# Elapsed time:  1049.80111899
# Elapsed time:  1050.63144507
# Elapsed time:  1051.46174011
# Elapsed time:  1052.2920012
# Elapsed time:  1053.12223168
# Elapsed time:  1053.95242861
# Elapsed time:  1054.78259534
# Elapsed time:  1055.61272894
# Elapsed time:  1056.44283272
# Elapsed time:  1057.27290376
# Elapsed time:  1058.10294537
# Elapsed time:  1058.93295461
# Elapsed time:  1059.7629348
# Elapsed time:  1060.59288299
# Elapsed time:  1061.42280249
# Elapsed time:  1062.25269035
# Elapsed time:  1063.08254987
# Elapsed time:  1063.9123781
# Elapsed time:  1064.74217833
# Elapsed time:  1065.57194762
# Elapsed time:  1066.40168926
# Elapsed time:  1067.23140029
# Elapsed time:  1068.061084
# Elapsed time:  1068.89073743
# Elapsed time:  1069.72036387
# Elapsed time:  1070.54996036
# Elapsed time:  1071.37953017
# Elapsed time:  1072.20907036
# Elapsed time:  1073.03858419
# Elapsed time:  1073.8680687
# Elapsed time:  1074.69752718
# Elapsed time:  1075.52695665
# Elapsed time:  1076.35636039
# Elapsed time:  1077.18573544
# Elapsed time:  1078.01508506
# Elapsed time:  1078.84440629
# Elapsed time:  1079.67370238
# Elapsed time:  1080.5029704
# Elapsed time:  1081.33221358
# Elapsed time:  1082.16142897
# Elapsed time:  1082.99061982
# Elapsed time:  1083.81978318
# Elapsed time:  1084.64892229
# Elapsed time:  1085.4780342
# Elapsed time:  1086.30712214
# Elapsed time:  1087.13618317
# Elapsed time:  1087.96522052
# Elapsed time:  1088.79423123
# Elapsed time:  1089.62321855
# Elapsed time:  1090.45217952
# Elapsed time:  1091.28111737
# Elapsed time:  1092.11002914
# Elapsed time:  1092.93891807
# Elapsed time:  1093.76778119
# Elapsed time:  1094.59662174
# Elapsed time:  1095.42543676
# Elapsed time:  1096.25422947
# Elapsed time:  1097.08299691
# Elapsed time:  1097.91174232
# Elapsed time:  1098.74046271
# Elapsed time:  1099.56916133
# Elapsed time:  1100.3978352
# Elapsed time:  1101.22648755
# Elapsed time:  1102.0551154
# Elapsed time:  1102.88372199
# Elapsed time:  1103.71230433
# Elapsed time:  1104.54086565
# Elapsed time:  1105.36940298
# Elapsed time:  1106.19791953
# Elapsed time:  1107.02641233
# Elapsed time:  1107.8548846
# Elapsed time:  1108.68333335
# Elapsed time:  1109.51176181
# Elapsed time:  1110.34016699
# Elapsed time:  1111.1685521
# Elapsed time:  1111.99691418
# Elapsed time:  1112.82525641
# Elapsed time:  1113.65357583
# Elapsed time:  1114.48187563
# Elapsed time:  1115.31015284
# Elapsed time:  1116.13841065
# Elapsed time:  1116.9666461
# Elapsed time:  1117.79486237
# Elapsed time:  1118.62305648
# Elapsed time:  1119.45123163
# Elapsed time:  1120.27938483
# Elapsed time:  1121.10751928
# Elapsed time:  1121.935632
# Elapsed time:  1122.76372616
# Elapsed time:  1123.59179879
# Elapsed time:  1124.41985308
# Elapsed time:  1125.24788603
# Elapsed time:  1126.07590084
# Elapsed time:  1126.90389452
# Elapsed time:  1127.73187024
# Elapsed time:  1128.55982504
# Elapsed time:  1129.38776207
# Elapsed time:  1130.21567836
# Elapsed time:  1131.04357708
# Elapsed time:  1131.87145525
# Elapsed time:  1132.69931603
# Elapsed time:  1133.52715646
# Elapsed time:  1134.35497968
# Elapsed time:  1135.18278274
# Elapsed time:  1136.01056877
# Elapsed time:  1136.83833482
# Elapsed time:  1137.66608403
# Elapsed time:  1138.49381344
# Elapsed time:  1139.32152619
# Elapsed time:  1140.14921931
# Elapsed time:  1140.97689596
# Elapsed time:  1141.80455316
# Elapsed time:  1142.63219406
# Elapsed time:  1143.45981569
# Elapsed time:  1144.2874212
# Elapsed time:  1145.11500761
# Elapsed time:  1145.94257808
# Elapsed time:  1146.77012963
# Elapsed time:  1147.59766541
# Elapsed time:  1148.42518244
# Elapsed time:  1149.25268388
# Elapsed time:  1150.08016675
# Elapsed time:  1150.90763419
# Elapsed time:  1151.73508324
# Elapsed time:  1152.56251703
# Elapsed time:  1153.3899326
# Elapsed time:  1154.21733309
# Elapsed time:  1155.04471553
# Elapsed time:  1155.87208306
# Elapsed time:  1156.69943271
# Elapsed time:  1157.52676762
# Elapsed time:  1158.35408482
# Elapsed time:  1159.18138746
# Elapsed time:  1160.00867256
# Elapsed time:  1160.83594326
# Elapsed time:  1161.66319659
# Elapsed time:  1162.4904357
# Elapsed time:  1163.31765761
# Elapsed time:  1164.14486546
# Elapsed time:  1164.97205628
# Elapsed time:  1165.79923321
# Elapsed time:  1166.62639328
# Elapsed time:  1167.45353962
# Elapsed time:  1168.28066928
# Elapsed time:  1169.10778537
# Elapsed time:  1169.93488495
# Elapsed time:  1170.76197113
# Elapsed time:  1171.58904095
# Elapsed time:  1172.41609755
# Elapsed time:  1173.24313795
# Elapsed time:  1174.0701653
# Elapsed time:  1174.89717661
# Elapsed time:  1175.72417503
# Elapsed time:  1176.55115758
# Elapsed time:  1177.37812739
# Elapsed time:  1178.20508151
# Elapsed time:  1179.03202304
# Elapsed time:  1179.85894904
# Elapsed time:  1180.68586262
# Elapsed time:  1181.51276082
# Elapsed time:  1182.33964676
# Elapsed time:  1183.16651747
# Elapsed time:  1183.99337609
# Elapsed time:  1184.82021964
# Elapsed time:  1185.64705125
# Elapsed time:  1186.47386794
# Elapsed time:  1187.30067285
# Elapsed time:  1188.12746299
# Elapsed time:  1188.9542415
# Elapsed time:  1189.7810054
# Elapsed time:  1190.60775782
# Elapsed time:  1191.43449578
# Elapsed time:  1192.26122241
# Elapsed time:  1193.08793473
# Elapsed time:  1193.91463586
# Elapsed time:  1194.74132283
# Elapsed time:  1195.56799875
# Elapsed time:  1196.39466067
# Elapsed time:  1197.22131168
# Elapsed time:  1198.04794883
# Elapsed time:  1198.87457522
# Elapsed time:  1199.70118788
# Elapsed time:  1200.52778992
# Elapsed time:  1201.35437838
# Elapsed time:  1202.18098232
# Elapsed time:  1203.00761004
# Elapsed time:  1203.83427196
# Elapsed time:  1204.66096546
# Elapsed time:  1205.48769192
# Elapsed time:  1206.31444814
# Elapsed time:  1207.14124013
# Elapsed time:  1207.96807007
# Elapsed time:  1208.79494746
# Elapsed time:  1209.62187543
# Elapsed time:  1210.44886106
# Elapsed time:  1211.27590385
# Elapsed time:  1212.1030074
# Elapsed time:  1212.93017015
# Elapsed time:  1213.75739659
# Elapsed time:  1214.58468708
# Elapsed time:  1215.41204786
# Elapsed time:  1216.23948013
# Elapsed time:  1217.06698977
# Elapsed time:  1217.89457692
# Elapsed time:  1218.72224643
# Elapsed time:  1219.54999789
# Elapsed time:  1220.37783615
# Elapsed time:  1221.20576119
# Elapsed time:  1222.03377832
# Elapsed time:  1222.86188775
# Elapsed time:  1223.69009471
# Elapsed time:  1224.51839907
# Elapsed time:  1225.34680571
# Elapsed time:  1226.17531421
# Elapsed time:  1227.00392933
# Elapsed time:  1227.83265064
# Elapsed time:  1228.66148293
# Elapsed time:  1229.49042576
# Elapsed time:  1230.31948384
# Elapsed time:  1231.1486566
# Elapsed time:  1231.97794861
# Elapsed time:  1232.80735912
# Elapsed time:  1233.63689259
# Elapsed time:  1234.4665482
# Elapsed time:  1235.29633036
# Elapsed time:  1236.12623814
# Elapsed time:  1236.95627589
# Elapsed time:  1237.78644259
# Elapsed time:  1238.61674251
# Elapsed time:  1239.44717451
# Elapsed time:  1240.27774278
# Elapsed time:  1241.10844612
# Elapsed time:  1241.93928866
# Elapsed time:  1242.77026914
# Elapsed time:  1243.60139165
# Elapsed time:  1244.43265487
# Elapsed time:  1245.26406285
# Elapsed time:  1246.09561421
# Elapsed time:  1246.927313
# Elapsed time:  1247.7591578
# Elapsed time:  1248.59115263
# Elapsed time:  1249.42329607
# Elapsed time:  1250.25559215
# Elapsed time:  1251.08803942
# Elapsed time:  1251.92064196
# Elapsed time:  1252.75339829
# Elapsed time:  1253.58631253
# Elapsed time:  1254.41938323
# Elapsed time:  1255.25261455
# Elapsed time:  1256.08600512
# Elapsed time:  1256.91955943
# Elapsed time:  1257.75327656
# Elapsed time:  1258.58716129
# Elapsed time:  1259.42121254
# Elapsed time:  1260.25543461
# Elapsed time:  1261.0898262
# Elapsed time:  1261.92439198
# Elapsed time:  1262.75913128
# Elapsed time:  1263.59404926
# Elapsed time:  1264.42914516
# Elapsed time:  1265.26442373
# Elapsed time:  1266.09988378
# Elapsed time:  1266.93553004
# Elapsed time:  1267.77136174
# Elapsed time:  1268.6073841
# Elapsed time:  1269.44359649
# Elapsed time:  1270.28000397
# Elapsed time:  1271.11660551
# Elapsed time:  1271.9534059
# Elapsed time:  1272.79040404
# Elapsed time:  1273.6276048
# Elapsed time:  1274.46500714
# Elapsed time:  1275.30261591
# Elapsed time:  1276.14042991
# Elapsed time:  1276.97845383
# Elapsed time:  1277.81668628
# Elapsed time:  1278.6551319
# Elapsed time:  1279.4937892
# Elapsed time:  1280.33266281
# Elapsed time:  1281.17175121
# Elapsed time:  1282.01105899
# Elapsed time:  1282.85058454
# Elapsed time:  1283.69033241
# Elapsed time:  1284.53030089
# Elapsed time:  1285.37049451
# Elapsed time:  1286.21091152
# Elapsed time:  1287.05155644
# Elapsed time:  1287.89242747
# Elapsed time:  1288.73352914
# Elapsed time:  1289.57485958
# Elapsed time:  1290.41642333
# Elapsed time:  1291.25821846
# Elapsed time:  1292.10024948
# Elapsed time:  1292.94251443
# Elapsed time:  1293.78501781
# Elapsed time:  1294.62775758
# Elapsed time:  1295.47073824
# Elapsed time:  1296.3139577
# Elapsed time:  1297.15742042
# Elapsed time:  1298.00112423
# Elapsed time:  1298.84507358
# Elapsed time:  1299.68926623
# Elapsed time:  1300.53370659
# Elapsed time:  1301.37839232
# Elapsed time:  1302.22332781
# Elapsed time:  1303.06851065
# Elapsed time:  1303.91394516
# Elapsed time:  1304.75962884
# Elapsed time:  1305.60556592
# Elapsed time:  1306.45175382
# Elapsed time:  1307.2981967
# Elapsed time:  1308.1448919
# Elapsed time:  1308.99184357
# Elapsed time:  1309.83904895
# Elapsed time:  1310.68651214
# Elapsed time:  1311.53423029
# Elapsed time:  1312.38220742
# Elapsed time:  1313.23044055
# Elapsed time:  1314.07893368
# Elapsed time:  1314.92768373
# Elapsed time:  1315.77669464
# Elapsed time:  1316.62596323
# Elapsed time:  1317.47549339
# Elapsed time:  1318.32528185
# Elapsed time:  1319.17533245
# Elapsed time:  1320.02564179
# Elapsed time:  1320.87621368
# Elapsed time:  1321.72704461
# Elapsed time:  1322.57813837
# Elapsed time:  1323.42949133
# Elapsed time:  1324.28110724
# Elapsed time:  1325.13298238
# Elapsed time:  1325.98512047
# Elapsed time:  1326.83751767
# Elapsed time:  1327.69017768
# Elapsed time:  1328.54309658
# Elapsed time:  1329.39627802
# Elapsed time:  1330.249718
# Elapsed time:  1331.10342015
# Elapsed time:  1331.95738038
# Elapsed time:  1332.81160231
# Elapsed time:  1333.66608176
# Elapsed time:  1334.52082234
# Elapsed time:  1335.37581978
# Elapsed time:  1336.23107769
# Elapsed time:  1337.08659174
# Elapsed time:  1337.94236552
# Elapsed time:  1338.79839463
# Elapsed time:  1339.65468269
# Elapsed time:  1340.5112252
# Elapsed time:  1341.36802581
# Elapsed time:  1342.22507996
# Elapsed time:  1343.08239131
# Elapsed time:  1343.93995524
# Elapsed time:  1344.79777542
# Elapsed time:  1345.6558472
# Elapsed time:  1346.51417427
# Elapsed time:  1347.37275191
# Elapsed time:  1348.23158386
# Elapsed time:  1349.09066535
# Elapsed time:  1349.95000015
# Elapsed time:  1350.80958346
# Elapsed time:  1351.66941907
# Elapsed time:  1352.52950225
# Elapsed time:  1353.38983707
# Elapsed time:  1354.25041904
# Elapsed time:  1355.11125241
# Elapsed time:  1355.97233261
# Elapsed time:  1356.83366379
# Elapsed time:  1357.69524117
# Elapsed time:  1358.55706907
# Elapsed time:  1359.4191431
# Elapsed time:  1360.28146809
# Elapsed time:  1361.14403966
# Elapsed time:  1362.00686213
# Elapsed time:  1362.86993038
# Elapsed time:  1363.73324861
# Elapsed time:  1364.5968122
# Elapsed time:  1365.46062611
# Elapsed time:  1366.32468601
# Elapsed time:  1367.18899662
# Elapsed time:  1368.05355285
# Elapsed time:  1368.91835895
# Elapsed time:  1369.78340969
# Elapsed time:  1370.6487095
# Elapsed time:  1371.51425325
# Elapsed time:  1372.38004534
# Elapsed time:  1373.24608025
# Elapsed time:  1374.11236199
# Elapsed time:  1374.97888459
# Elapsed time:  1375.8456518
# Elapsed time:  1376.71265738
# Elapsed time:  1377.57990495
# Elapsed time:  1378.44738799
# Elapsed time:  1379.31510992
# Elapsed time:  1380.1830639
# Elapsed time:  1381.05125309
# Elapsed time:  1381.91967035
# Elapsed time:  1382.78831869
# Elapsed time:  1383.65719077
# Elapsed time:  1384.52628957
# Elapsed time:  1385.39560765
# Elapsed time:  1386.26514807
# Elapsed time:  1387.13490337
# Elapsed time:  1388.00487676
# Elapsed time:  1388.87506089
# Elapsed time:  1389.74545922
# Elapsed time:  1390.61606464
# Elapsed time:  1391.48688097
# Elapsed time:  1392.35790145
# Elapsed time:  1393.22913678
# Elapsed time:  1394.10058591
# Elapsed time:  1394.97225825
# Elapsed time:  1395.844146
# Elapsed time:  1396.71625443
# Elapsed time:  1397.58857291
# Elapsed time:  1398.46110628
# Elapsed time:  1399.33384548
# Elapsed time:  1400.20680522
# Elapsed time:  1401.07998528
# Elapsed time:  1401.95339991
# Elapsed time:  1402.82704198
# Elapsed time:  1403.70092028
# Elapsed time:  1404.57502362
# Elapsed time:  1405.44935875
# Elapsed time:  1406.32391512
# Elapsed time:  1407.1987031
# Elapsed time:  1408.07371563
# Elapsed time:  1408.94896721
# Elapsed time:  1409.82445607
# Elapsed time:  1410.70019694
# Elapsed time:  1411.57618182
# Elapsed time:  1412.45241887
# Elapsed time:  1413.328896
# Elapsed time:  1414.20562005
# Elapsed time:  1415.08257988
# Elapsed time:  1415.95978549
# Elapsed time:  1416.83722918
# Elapsed time:  1417.71492871
# Elapsed time:  1418.59288196
# Elapsed time:  1419.47110316
# Elapsed time:  1420.34958204
# Elapsed time:  1421.22832704
# Elapsed time:  1422.10732484
# Elapsed time:  1422.98658303
# Elapsed time:  1423.86608997
# Elapsed time:  1424.74586248
# Elapsed time:  1425.62589724
# Elapsed time:  1426.50620944
# Elapsed time:  1427.38678822
# Elapsed time:  1428.26764268
# Elapsed time:  1429.14875816
# Elapsed time:  1430.03014758
# Elapsed time:  1430.91180269
# Elapsed time:  1431.79373739
# Elapsed time:  1432.67593999
# Elapsed time:  1433.55842103
# Elapsed time:  1434.44116603
# Elapsed time:  1435.32418901
# Elapsed time:  1436.20748071
# Elapsed time:  1437.0910547
# Elapsed time:  1437.97489772
# Elapsed time:  1438.85902042
# Elapsed time:  1439.74340768
# Elapsed time:  1440.62807453
# Elapsed time:  1441.51301154
# Elapsed time:  1442.39823326
# Elapsed time:  1443.28372583
# Elapsed time:  1444.16950029
# Elapsed time:  1445.05554049
# Elapsed time:  1445.94186167
# Elapsed time:  1446.82845342
# Elapsed time:  1447.71533058
# Elapsed time:  1448.60247831
# Elapsed time:  1449.48991354
# Elapsed time:  1450.37762408
# Elapsed time:  1451.26562217
# Elapsed time:  1452.1538886
# Elapsed time:  1453.04243846
# Elapsed time:  1453.93125767
# Elapsed time:  1454.82035877
# Elapsed time:  1455.70972207
# Elapsed time:  1456.59936361
# Elapsed time:  1457.48926866
# Elapsed time:  1458.37945005
# Elapsed time:  1459.26988704
# Elapsed time:  1460.16059612
# Elapsed time:  1461.05156216
# Elapsed time:  1461.94279914
# Elapsed time:  1462.83428653
# Elapsed time:  1463.72604229
# Elapsed time:  1464.61805154
# Elapsed time:  1465.51032954
# Elapsed time:  1466.40285582
# Elapsed time:  1467.29564959
# Elapsed time:  1468.18869606
# Elapsed time:  1469.08201189
# Elapsed time:  1469.97557686
# Elapsed time:  1470.8694116
# Elapsed time:  1471.76350158
# Elapsed time:  1472.65786474
# Elapsed time:  1473.55248098
# Elapsed time:  1474.44737211
# Elapsed time:  1475.34252354
# Elapsed time:  1476.23795437
# Elapsed time:  1477.13364434
# Elapsed time:  1478.02961631
# Elapsed time:  1478.92585549
# Elapsed time:  1479.82238185
# Elapsed time:  1480.71917476
# Elapsed time:  1481.61625788
# Elapsed time:  1482.51361586
# Elapsed time:  1483.41126938
# Elapsed time:  1484.30919715
# Elapsed time:  1485.20742344
# Elapsed time:  1486.10593214
# Elapsed time:  1487.00474449
# Elapsed time:  1487.90383832
# Elapsed time:  1488.80323839
# Elapsed time:  1489.70292764
# Elapsed time:  1490.60292773
# Elapsed time:  1491.50321532
# Elapsed time:  1492.40381524
# Elapsed time:  1493.30470857
# Elapsed time:  1494.20591611
# Elapsed time:  1495.10741163
# Elapsed time:  1496.0092183
# Elapsed time:  1496.91131385
# Elapsed time:  1497.81371754
# Elapsed time:  1498.71640021
# Elapsed time:  1499.61938403
# Elapsed time:  1500.52264485
# Elapsed time:  1501.42620758
# Elapsed time:  1502.33004718
# Elapsed time:  1503.23418323
# Elapsed time:  1504.13858317
# Elapsed time:  1505.0432674
# Elapsed time:  1505.94820776
# Elapsed time:  1506.85343026
# Elapsed time:  1507.75890958
# Elapsed time:  1508.66466892
# Elapsed time:  1509.57067686
# Elapsed time:  1510.47695833
# Elapsed time:  1511.38348661
# Elapsed time:  1512.29029216
# Elapsed time:  1513.19735114
# Elapsed time:  1514.10469169
# Elapsed time:  1515.01228492
# Elapsed time:  1515.92016147
# Elapsed time:  1516.82829693
# Elapsed time:  1517.73672655
# Elapsed time:  1518.64542818
# Elapsed time:  1519.55443471
# Elapsed time:  1520.46372009
# Elapsed time:  1521.37332332
# Elapsed time:  1522.2832281
# Elapsed time:  1523.19348194
# Elapsed time:  1524.10407044
# Elapsed time:  1525.0150343
# Elapsed time:  1525.92634805
# Elapsed time:  1526.83805083
# Elapsed time:  1527.7501203
# Elapsed time:  1528.66260052
# Elapsed time:  1529.57547024
# Elapsed time:  1530.48876752
# Elapsed time:  1531.40246019
# Elapsed time:  1532.31658302
# Elapsed time:  1533.23110341
# Elapsed time:  1534.14605767
# Elapsed time:  1535.06141267
# Elapsed time:  1535.97719977
# Elapsed time:  1536.89337736
# Elapsed time:  1537.80997649
# Elapsed time:  1538.72695699
# Elapsed time:  1539.6443527
# Elapsed time:  1540.56212331
# Elapsed time:  1541.4802985
# Elapsed time:  1542.3988306
# Elapsed time:  1543.317751
# Elapsed time:  1544.23701553
# Elapsed time:  1545.15666063
# Elapsed time:  1546.0766436
# Elapsed time:  1546.99699804
# Elapsed time:  1547.91767457
# Elapsed time:  1548.83870918
# Elapsed time:  1549.76005641
# Elapsed time:  1550.68175791
# Elapsed time:  1551.60377008
# Elapsed time:  1552.52613227
# Elapsed time:  1553.44879431
# Elapsed time:  1554.37179817
# Elapsed time:  1555.29509742
# Elapsed time:  1556.21873957
# Elapsed time:  1557.14267968
# Elapsed time:  1558.06696885
# Elapsed time:  1558.99156053
# Elapsed time:  1559.91649918
# Elapsed time:  1560.8417284
# Elapsed time:  1561.76729563
# Elapsed time:  1562.69315023
# Elapsed time:  1563.61934653
# Elapsed time:  1564.54583709
# Elapsed time:  1565.47267904
# Elapsed time:  1566.39982369
# Elapsed time:  1567.32732538
# Elapsed time:  1568.25513115
# Elapsed time:  1569.18329372
# Elapsed time:  1570.11175914
# Elapsed time:  1571.04058109
# Elapsed time:  1571.96970601
# Elapsed time:  1572.89918875
# Elapsed time:  1573.82897535
# Elapsed time:  1574.75912054
# Elapsed time:  1575.68956918
# Elapsed time:  1576.62037595
# Elapsed time:  1577.55148527
# Elapsed time:  1578.48295253
# Elapsed time:  1579.4147223
# Elapsed time:  1580.34685088
# Elapsed time:  1581.27928276
# Elapsed time:  1582.21207465
# Elapsed time:  1583.14517057
# Elapsed time:  1584.07862744
# Elapsed time:  1585.01238882
# Elapsed time:  1585.94651202
# Elapsed time:  1586.88094031
# Elapsed time:  1587.81573145
# Elapsed time:  1588.75082839
# Elapsed time:  1589.68628921
# Elapsed time:  1590.62205639
# Elapsed time:  1591.55818825
# Elapsed time:  1592.49462677
# Elapsed time:  1593.43143055
# Elapsed time:  1594.36854112
# Elapsed time:  1595.30601742
# Elapsed time:  1596.24380055
# Elapsed time:  1597.18194975
# Elapsed time:  1598.12040571
# Elapsed time:  1599.05922795
# Elapsed time:  1599.9983567
# Elapsed time:  1600.93785183
# Elapsed time:  1601.8776531
# Elapsed time:  1602.81782077
# Elapsed time:  1603.75829419
# Elapsed time:  1604.69913398
# Elapsed time:  1605.64027909
# Elapsed time:  1606.58179052
# Elapsed time:  1607.52360682
# Elapsed time:  1608.46578937
# Elapsed time:  1609.40827633
# Elapsed time:  1610.35112949
# Elapsed time:  1611.29428663
# Elapsed time:  1612.23780993
# Elapsed time:  1613.18163679
# Elapsed time:  1614.12582983
# Elapsed time:  1615.07032607
# Elapsed time:  1616.01518851
# Elapsed time:  1616.96035383
# Elapsed time:  1617.90588542
# Elapsed time:  1618.85171963
# Elapsed time:  1619.79792023
# Elapsed time:  1620.74442325
# Elapsed time:  1621.69129285
# Elapsed time:  1622.63846471
# Elapsed time:  1623.58600342
# Elapsed time:  1624.53384433
# Elapsed time:  1625.48205243
# Elapsed time:  1626.43056278
# Elapsed time:  1627.37944075
# Elapsed time:  1628.32862114
# Elapsed time:  1629.27816973
# Elapsed time:  1630.22802103
# Elapsed time:  1631.17824125
# Elapsed time:  1632.12876468
# Elapsed time:  1633.07965791
# Elapsed time:  1634.03085503
# Elapsed time:  1634.98239572
# Elapsed time:  1635.93419912
# Elapsed time:  1636.88633675
# Elapsed time:  1637.83874269
# Elapsed time:  1638.79148153
# Elapsed time:  1639.74448785
# Elapsed time:  1640.69784128
# Elapsed time:  1641.65148648
# Elapsed time:  1642.60550374
# Elapsed time:  1643.5598349
# Elapsed time:  1644.51455774
# Elapsed time:  1645.46960835
# Elapsed time:  1646.4250583
# Elapsed time:  1647.38083929
# Elapsed time:  1648.33702256
# Elapsed time:  1649.29354006
# Elapsed time:  1650.250464
# Elapsed time:  1651.20772622
# Elapsed time:  1652.16539898
# Elapsed time:  1653.12341278
# Elapsed time:  1654.08183907
# Elapsed time:  1655.04060721
# Elapsed time:  1655.99978903
# Elapsed time:  1656.95931397
# Elapsed time:  1657.91925489
# Elapsed time:  1658.8795414
# Elapsed time:  1659.84024708
# Elapsed time:  1660.80130113
# Elapsed time:  1661.76277738
# Elapsed time:  1662.72460443
# Elapsed time:  1663.68685651
# Elapsed time:  1664.64946191
# Elapsed time:  1665.6124955
# Elapsed time:  1666.57588535
# Elapsed time:  1667.53970689
# Elapsed time:  1668.5038878
# Elapsed time:  1669.46850394
# Elapsed time:  1670.43348247
# Elapsed time:  1671.39889967
# Elapsed time:  1672.36468223
# Elapsed time:  1673.33090698
# Elapsed time:  1674.29750019
# Elapsed time:  1675.26453923
# Elapsed time:  1676.23194994
# Elapsed time:  1677.19981019
# Elapsed time:  1678.16804534
# Elapsed time:  1679.13673376
# Elapsed time:  1680.10580037
# Elapsed time:  1681.07532407
# Elapsed time:  1682.04522932
# Elapsed time:  1683.01559563
# Elapsed time:  1683.98634699
# Elapsed time:  1684.95756348
# Elapsed time:  1685.92916862
# Elapsed time:  1686.90124302
# Elapsed time:  1687.87370953
# Elapsed time:  1688.846649
# Elapsed time:  1689.81998322
# Elapsed time:  1690.79379292
# Elapsed time:  1691.76799868
# Elapsed time:  1692.74268118
# Elapsed time:  1693.71775993
# Elapsed time:  1694.69331582
# Elapsed time:  1695.66926744
# Elapsed time:  1696.64569594
# Elapsed time:  1697.62251905
# Elapsed time:  1698.59981817
# Elapsed time:  1699.57751045
# Elapsed time:  1700.55567775
# Elapsed time:  1701.53423688
# Elapsed time:  1702.51327053
# Elapsed time:  1703.49269527
# Elapsed time:  1704.47259467
# Elapsed time:  1705.45288512
# Elapsed time:  1706.43363469
# Elapsed time:  1707.41476031
# Elapsed time:  1708.39634448
# Elapsed time:  1709.37830947
# Elapsed time:  1710.36073728
# Elapsed time:  1711.34355042
# Elapsed time:  1712.32683377
# Elapsed time:  1713.31050884
# Elapsed time:  1714.29465899
# Elapsed time:  1715.27918357
# Elapsed time:  1716.26415064
# Elapsed time:  1717.24948141
# Elapsed time:  1718.23526783
# Elapsed time:  1719.22143163
# Elapsed time:  1720.20805505
# Elapsed time:  1721.19505424
# Elapsed time:  1722.18251655
# Elapsed time:  1723.17036859
# Elapsed time:  1724.15870901
# Elapsed time:  1725.14746821
# Elapsed time:  1726.13674159
# Elapsed time:  1727.12645213
# Elapsed time:  1728.11669136
# Elapsed time:  1729.10738203
# Elapsed time:  1730.09861947
# Elapsed time:  1731.09032916
# Elapsed time:  1732.08260823
# Elapsed time:  1733.07538017
# Elapsed time:  1734.06873921
# Elapsed time:  1735.06260416
# Elapsed time:  1736.05706662
# Elapsed time:  1737.05204304
# Elapsed time:  1738.04762514
# Elapsed time:  1739.04371441
# Elapsed time:  1740.04040509
# Elapsed time:  1741.03760895
# Elapsed time:  1742.03542344
# Elapsed time:  1743.03375646
# Elapsed time:  1744.03270485
# Elapsed time:  1745.0321765
# Elapsed time:  1746.03226739
# Elapsed time:  1747.03288264
# Elapsed time:  1748.03411795
# Elapsed time:  1749.03587846
# Elapsed time:  1750.03826063
# Elapsed time:  1751.04116887
# Elapsed time:  1752.04469967
# Elapsed time:  1753.04875649
# Elapsed time:  1754.05343566
# Elapsed time:  1755.05863954
# Elapsed time:  1756.06446454
# Elapsed time:  1757.07081245
# Elapsed time:  1758.07778013
# Elapsed time:  1759.08526889
# Elapsed time:  1760.0933758
# Elapsed time:  1761.10200136
# Elapsed time:  1762.11124249
# Elapsed time:  1763.12099861
# Elapsed time:  1764.13136647
# Elapsed time:  1765.14224462
# Elapsed time:  1766.15372989
# Elapsed time:  1767.16572017
# Elapsed time:  1768.17831252
# Elapsed time:  1769.19140427
# Elapsed time:  1770.20509281
# Elapsed time:  1771.21927507
# Elapsed time:  1772.23404897
# Elapsed time:  1773.24931137
# Elapsed time:  1774.26516104
# Elapsed time:  1775.28149503
# Elapsed time:  1776.29841314
# Elapsed time:  1777.31581272
# Elapsed time:  1778.3337947
# Elapsed time:  1779.35225688
# Elapsed time:  1780.3713014
# Elapsed time:  1781.39082649
# Elapsed time:  1782.41093541
# Elapsed time:  1783.43152671
# Elapsed time:  1784.4527047
# Elapsed time:  1785.47436818
# Elapsed time:  1786.49662238
# Elapsed time:  1787.51936613
# Elapsed time:  1788.54270539
# Elapsed time:  1789.56653885
# Elapsed time:  1790.59097309
# Elapsed time:  1791.61590648
# Elapsed time:  1792.64144612
# Elapsed time:  1793.66748998
# Elapsed time:  1794.69414554
# Elapsed time:  1795.72131024
# Elapsed time:  1796.74909188
# Elapsed time:  1797.77738726
# Elapsed time:  1798.80630447
# Elapsed time:  1799.83573961

# %%
plt.plot(hydrograph_time, discharge_at_outlet)
plt.ylabel('Discharge, (m$^3$s$^{-1}$)')
plt.xlabel('Time (hr)')
plt.title('Outlet Hydrograph, Rainfall: ' + str(rain_mm_p_h) + 
          ' mm/hr ' + 'over ' + str((elapsed_time / 3600.).round(1)) + ' hours')
# Out:
# Text(0.5, 1.0, 'Outlet Hydrograph, Rainfall: 20 mm/hr over 0.5 hours')

# %%
plt.plot(hydrograph_time, water_depth_at_outlet)
plt.ylabel('Depth, (m)')
plt.xlabel('Time (hr)')
plt.title('Outlet Depth, Rainfall: ' + str(rain_mm_p_h) + 
          ' mm/hr ' + 'over ' + str((elapsed_time / 3600.).round(1)) + ' hours')
# Out:
# Text(0.5, 1.0, 'Outlet Depth, Rainfall: 20 mm/hr over 0.5 hours')

# %%
imshow_grid(mg2, 'surface_water__depth', plot_name='Water depth at time = 2 hr',
        var_name='Water Depth', var_units='m', grid_units=('m', 'm'), cmap='Blues', vmax = 0.01)

# %%
while elapsed_time < run_time:
    hydrograph_time.append(elapsed_time / 3600.)  # convert seconds to hours
    of.dt = of.calc_time_step()     # Adaptive time step
    if elapsed_time < (storm_duration):
            of.rainfall_intensity =  rainfall_mmhr * (2.777778 * 10**-7)
    else:
            of.rainfall_intensity = 0.0
    of.overland_flow()
    mg2.at_node['surface_water__discharge'] = of.discharge_mapper(of.q, convert_to_volume=True)
    discharge_at_outlet.append(np.abs(of.q[outlet_link]) * mg2.dx) # append discharge in m^3/s
    elapsed_time += of.dt

# %%
swd = np.array(mg2.at_node['surface_water__depth']).reshape(mg.shape).astype('float64');

# %%
san = np.array(mg2.status_at_node).reshape(mg.shape).astype('float64');

# %%
mask_closed_nodes = san != 4

# %%
water_depth = np.multiply(swd, mask_closed_nodes)

# %%
plt.imshow(water_depth, cmap="gist_earth_r", vmax = 0.01);
plt.colorbar();

# %%
imshow_grid(mg2, 'surface_water__depth', cmap='Blues')

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('fann_0_D8_sca.tif', input_geotiff, specific_catchment_area, drainage_area.dtype)
